# %%
from __future__ import division 
import matplotlib.pyplot as plt
# %matplotlib inline
import emotion_analysis
emo = emotion_analysis.EmotionAnalysis()

# %%
inp, lab = emo.prepare_dataset('data')
# Out:
# Read audio file 'data\negative_38.wav', count: 100
# Read audio file 'data\neutral_221.wav', count: 200
# Read audio file 'data\neutral_490.wav', count: 300
# Read audio file 'data\positive_303.wav', count: 400
# Read audio file 'data\positive_55.wav', count: 500

# %%
from random import shuffle
import numpy as np

dataset = zip(inp, lab)
shuffle(dataset)
inp, lab = zip(*dataset)
max_value = max([max(i) for i in inp])
min_value = min([min(i) for i in inp])
#normalised_inp = np.asarray(inp)/max_value
inp = (np.asarray(inp)-min_value)/(max_value-min_value)

# %%
from pybrain.structure.modules import LSTMLayer, SoftmaxLayer, TanhLayer
from pybrain.supervised import RPropMinusTrainer, BackpropTrainer
from pybrain.tools.shortcuts import buildNetwork
from pybrain.datasets import SequenceClassificationDataSet, ClassificationDataSet

# %%
lab_to_int = {'neutral':0, 'positive':1, 'negative':2}
int_to_lab = {0:'neutral', 1:'positive', 2:'negative'}
alldata = ClassificationDataSet(len(inp[0]), 1, nb_classes = 3)
#for i in range(int(len(inp)*3/4)):
for i in range(int(len(inp))):
   alldata.addSample(inp[i],lab_to_int[lab[i]])

# %%
testdata, traindata = alldata.splitWithProportion(0.25)

# %%
len(testdata['input'])
# Out:
# 128

# %%
testdata._convertToOneOfMany()
traindata._convertToOneOfMany()

# %%
rnn = buildNetwork(traindata.indim,158, 105, traindata.outdim, hiddenclass = TanhLayer, outclass = SoftmaxLayer)
trainer = RPropMinusTrainer(rnn, dataset = traindata, verbose = True)
error = []
counter = 0

# %%
for i in range(1000):
    print "Epoch: "+str(counter)
    error.append(trainer.train())
    print ""
    counter += 1
# Out:
# Epoch: 0
# epoch      0  total error      0.21032   avg weight        0.9997
#
# Epoch: 1
# epoch      1  total error      0.20865   avg weight        1.0043
#
# Epoch: 2
# epoch      2  total error      0.22165   avg weight        1.0091
#
# Epoch: 3
# epoch      3  total error      0.23432   avg weight        1.0126
#
# Epoch: 4
# epoch      4  total error      0.20858   avg weight        1.0165
#
# Epoch: 5
# epoch      5  total error      0.22165   avg weight        1.0204
#
# Epoch: 6
# epoch      6  total error      0.20575   avg weight        1.0214
#
# Epoch: 7
# epoch      7  total error      0.23399   avg weight        1.0226
#
# Epoch: 8
# epoch      8  total error      0.20736   avg weight        1.0228
#
# Epoch: 9
# epoch      9  total error         0.19   avg weight        1.0228
#
# Epoch: 10
# epoch     10  total error      0.23275   avg weight        1.0234
#
# Epoch: 11
# epoch     11  total error      0.19829   avg weight        1.0235
#
# Epoch: 12
# epoch     12  total error      0.21199   avg weight        1.0238
#
# Epoch: 13
# epoch     13  total error      0.22043   avg weight        1.0241
#
# Epoch: 14
# epoch     14  total error      0.20518   avg weight        1.0237
#
# Epoch: 15
# epoch     15  total error      0.21918   avg weight         1.024
#
# Epoch: 16
# epoch     16  total error      0.18003   avg weight         1.024
#
# Epoch: 17
# epoch     17  total error      0.13702   avg weight        1.0242
#
# Epoch: 18
# epoch     18  total error      0.19802   avg weight        1.0243
#
# Epoch: 19
# epoch     19  total error      0.12559   avg weight        1.0244
#
# Epoch: 20
# epoch     20  total error      0.13475   avg weight        1.0246
#
# Epoch: 21
# epoch     21  total error      0.12897   avg weight        1.0247
#
# Epoch: 22
# epoch     22  total error      0.13128   avg weight        1.0247
#
# Epoch: 23
# epoch     23  total error      0.11063   avg weight        1.0249
#
# Epoch: 24
# epoch     24  total error      0.12865   avg weight        1.0249
#
# Epoch: 25
# epoch     25  total error      0.12507   avg weight        1.0252
#
# Epoch: 26
# epoch     26  total error      0.10525   avg weight        1.0254
#
# Epoch: 27
# epoch     27  total error      0.14999   avg weight        1.0258
#
# Epoch: 28
# epoch     28  total error      0.15185   avg weight        1.0262
#
# Epoch: 29
# epoch     29  total error      0.10545   avg weight        1.0268
#
# Epoch: 30
# epoch     30  total error      0.11892   avg weight        1.0276
#
# Epoch: 31
# epoch     31  total error      0.10137   avg weight        1.0276
#
# Epoch: 32
# epoch     32  total error      0.10331   avg weight        1.0287
#
# Epoch: 33
# epoch     33  total error      0.10257   avg weight        1.0298
#
# Epoch: 34
# epoch     34  total error     0.099133   avg weight        1.0309
#
# Epoch: 35
# epoch     35  total error     0.098379   avg weight        1.0329
#
# Epoch: 36
# epoch     36  total error     0.098965   avg weight        1.0347
#
# Epoch: 37
# epoch     37  total error     0.097682   avg weight        1.0379
#
# Epoch: 38
# epoch     38  total error     0.096628   avg weight        1.0421
#
# Epoch: 39
# epoch     39  total error     0.097581   avg weight        1.0463
#
# Epoch: 40
# epoch     40  total error     0.096404   avg weight        1.0497
#
# Epoch: 41
# epoch     41  total error     0.096109   avg weight         1.055
#
# Epoch: 42
# epoch     42  total error     0.096082   avg weight         1.054
#
# Epoch: 43
# epoch     43  total error     0.095577   avg weight        1.0572
#
# Epoch: 44
# epoch     44  total error     0.094707   avg weight        1.0609
#
# Epoch: 45
# epoch     45  total error     0.096116   avg weight        1.0583
#
# Epoch: 46
# epoch     46  total error     0.094977   avg weight        1.0593
#
# Epoch: 47
# epoch     47  total error     0.094311   avg weight        1.0615
#
# Epoch: 48
# epoch     48  total error     0.095164   avg weight        1.0603
#
# Epoch: 49
# epoch     49  total error     0.094131   avg weight        1.0629
#
# Epoch: 50
# epoch     50  total error     0.093708   avg weight        1.0657
#
# Epoch: 51
# epoch     51  total error     0.094585   avg weight        1.0707
#
# Epoch: 52
# epoch     52  total error     0.093128   avg weight        1.0773
#
# Epoch: 53
# epoch     53  total error      0.09293   avg weight        1.0828
#
# Epoch: 54
# epoch     54  total error     0.092855   avg weight        1.0918
#
# Epoch: 55
# epoch     55  total error     0.092087   avg weight        1.1024
#
# Epoch: 56
# epoch     56  total error     0.091668   avg weight        1.1052
#
# Epoch: 57
# epoch     57  total error     0.091099   avg weight        1.1086
#
# Epoch: 58
# epoch     58  total error     0.090738   avg weight        1.1156
#
# Epoch: 59
# epoch     59  total error     0.090091   avg weight         1.127
#
# Epoch: 60
# epoch     60  total error     0.093014   avg weight        1.1256
#
# Epoch: 61
# epoch     61  total error     0.095507   avg weight        1.1354
#
# Epoch: 62
# epoch     62  total error     0.089203   avg weight        1.1478
#
# Epoch: 63
# epoch     63  total error     0.094261   avg weight        1.1563
#
# Epoch: 64
# epoch     64  total error     0.088922   avg weight        1.1633
#
# Epoch: 65
# epoch     65  total error     0.088196   avg weight        1.1612
#
# Epoch: 66
# epoch     66  total error     0.087481   avg weight        1.1658
#
# Epoch: 67
# epoch     67  total error      0.08716   avg weight        1.1662
#
# Epoch: 68
# epoch     68  total error     0.086674   avg weight        1.1757
#
# Epoch: 69
# epoch     69  total error     0.086187   avg weight        1.1853
#
# Epoch: 70
# epoch     70  total error     0.086039   avg weight        1.1992
#
# Epoch: 71
# epoch     71  total error     0.087083   avg weight        1.2007
#
# Epoch: 72
# epoch     72  total error     0.086107   avg weight        1.2121
#
# Epoch: 73
# epoch     73  total error     0.085474   avg weight        1.2084
#
# Epoch: 74
# epoch     74  total error       0.0864   avg weight        1.2185
#
# Epoch: 75
# epoch     75  total error     0.085524   avg weight        1.2233
#
# Epoch: 76
# epoch     76  total error     0.084996   avg weight        1.2297
#
# Epoch: 77
# epoch     77  total error     0.085136   avg weight        1.2392
#
# Epoch: 78
# epoch     78  total error     0.084843   avg weight        1.2419
#
# Epoch: 79
# epoch     79  total error     0.084585   avg weight        1.2395
#
# Epoch: 80
# epoch     80  total error       0.0845   avg weight        1.2474
#
# Epoch: 81
# epoch     81  total error     0.084218   avg weight        1.2521
#
# Epoch: 82
# epoch     82  total error     0.083943   avg weight        1.2613
#
# Epoch: 83
# epoch     83  total error     0.083659   avg weight         1.263
#
# Epoch: 84
# epoch     84  total error     0.083548   avg weight        1.2665
#
# Epoch: 85
# epoch     85  total error     0.083304   avg weight        1.2734
#
# Epoch: 86
# epoch     86  total error     0.083102   avg weight        1.2764
#
# Epoch: 87
# epoch     87  total error     0.082818   avg weight        1.2848
#
# Epoch: 88
# epoch     88  total error      0.08273   avg weight        1.2907
#
# Epoch: 89
# epoch     89  total error     0.082474   avg weight        1.2941
#
# Epoch: 90
# epoch     90  total error     0.082353   avg weight        1.2964
#
# Epoch: 91
# epoch     91  total error     0.082116   avg weight        1.3076
#
# Epoch: 92
# epoch     92  total error     0.082024   avg weight        1.3198
#
# Epoch: 93
# epoch     93  total error     0.081474   avg weight        1.3283
#
# Epoch: 94
# epoch     94  total error     0.081287   avg weight        1.3401
#
# Epoch: 95
# epoch     95  total error      0.08094   avg weight        1.3559
#
# Epoch: 96
# epoch     96  total error      0.08069   avg weight        1.3713
#
# Epoch: 97
# epoch     97  total error     0.080467   avg weight        1.3769
#
# Epoch: 98
# epoch     98  total error     0.079907   avg weight        1.3897
#
# Epoch: 99
# epoch     99  total error     0.080062   avg weight        1.3942
#
# Epoch: 100
# epoch    100  total error     0.079353   avg weight        1.4121
#
# Epoch: 101
# epoch    101  total error     0.079072   avg weight        1.4272
#
# Epoch: 102
# epoch    102  total error     0.078725   avg weight        1.4376
#
# Epoch: 103
# epoch    103  total error     0.078025   avg weight        1.4498
#
# Epoch: 104
# epoch    104  total error      0.07776   avg weight         1.469
#
# Epoch: 105
# epoch    105  total error     0.077608   avg weight        1.4885
#
# Epoch: 106
# epoch    106  total error     0.077085   avg weight        1.4963
#
# Epoch: 107
# epoch    107  total error     0.077436   avg weight        1.4899
#
# Epoch: 108
# epoch    108  total error     0.076727   avg weight        1.4948
#
# Epoch: 109
# epoch    109  total error     0.076476   avg weight        1.5013
#
# Epoch: 110
# epoch    110  total error     0.076123   avg weight         1.511
#
# Epoch: 111
# epoch    111  total error     0.075819   avg weight        1.5188
#
# Epoch: 112
# epoch    112  total error     0.075641   avg weight        1.5329
#
# Epoch: 113
# epoch    113  total error     0.075353   avg weight         1.549
#
# Epoch: 114
# epoch    114  total error     0.075093   avg weight        1.5649
#
# Epoch: 115
# epoch    115  total error     0.074689   avg weight        1.5851
#
# Epoch: 116
# epoch    116  total error     0.074437   avg weight        1.5909
#
# Epoch: 117
# epoch    117  total error     0.074306   avg weight        1.6069
#
# Epoch: 118
# epoch    118  total error     0.074051   avg weight        1.6183
#
# Epoch: 119
# epoch    119  total error     0.074054   avg weight        1.6296
#
# Epoch: 120
# epoch    120  total error     0.073696   avg weight        1.6428
#
# Epoch: 121
# epoch    121  total error     0.073393   avg weight        1.6315
#
# Epoch: 122
# epoch    122  total error     0.072965   avg weight        1.6379
#
# Epoch: 123
# epoch    123  total error     0.072588   avg weight        1.6477
#
# Epoch: 124
# epoch    124  total error     0.072405   avg weight        1.6528
#
# Epoch: 125
# epoch    125  total error     0.072459   avg weight        1.6525
#
# Epoch: 126
# epoch    126  total error     0.071977   avg weight        1.6539
#
# Epoch: 127
# epoch    127  total error     0.071751   avg weight        1.6601
#
# Epoch: 128
# epoch    128  total error     0.071463   avg weight        1.6654
#
# Epoch: 129
# epoch    129  total error     0.071301   avg weight        1.6733
#
# Epoch: 130
# epoch    130  total error     0.071168   avg weight        1.6713
#
# Epoch: 131
# epoch    131  total error     0.070921   avg weight        1.6752
#
# Epoch: 132
# epoch    132  total error      0.07078   avg weight         1.683
#
# Epoch: 133
# epoch    133  total error      0.07117   avg weight        1.6899
#
# Epoch: 134
# epoch    134  total error     0.070994   avg weight        1.6938
#
# Epoch: 135
# epoch    135  total error     0.070382   avg weight        1.6983
#
# Epoch: 136
# epoch    136  total error     0.070242   avg weight        1.7016
#
# Epoch: 137
# epoch    137  total error     0.070066   avg weight        1.7104
#
# Epoch: 138
# epoch    138  total error     0.069814   avg weight        1.6993
#
# Epoch: 139
# epoch    139  total error     0.069751   avg weight        1.7036
#
# Epoch: 140
# epoch    140  total error     0.069479   avg weight        1.7138
#
# Epoch: 141
# epoch    141  total error     0.069331   avg weight        1.7196
#
# Epoch: 142
# epoch    142  total error     0.069075   avg weight        1.7282
#
# Epoch: 143
# epoch    143  total error     0.068959   avg weight         1.741
#
# Epoch: 144
# epoch    144  total error     0.068377   avg weight        1.7552
#
# Epoch: 145
# epoch    145  total error     0.072546   avg weight        1.7706
#
# Epoch: 146
# epoch    146  total error     0.068128   avg weight        1.7816
#
# Epoch: 147
# epoch    147  total error     0.068286   avg weight        1.7744
#
# Epoch: 148
# epoch    148  total error     0.067759   avg weight        1.7836
#
# Epoch: 149
# epoch    149  total error     0.067507   avg weight        1.7798
#
# Epoch: 150
# epoch    150  total error     0.067557   avg weight        1.7847
#
# Epoch: 151
# epoch    151  total error     0.067146   avg weight        1.7918
#
# Epoch: 152
# epoch    152  total error     0.066874   avg weight        1.7971
#
# Epoch: 153
# epoch    153  total error     0.068795   avg weight        1.8049
#
# Epoch: 154
# epoch    154  total error     0.067433   avg weight        1.8154
#
# Epoch: 155
# epoch    155  total error      0.06648   avg weight        1.8263
#
# Epoch: 156
# epoch    156  total error     0.066266   avg weight        1.8372
#
# Epoch: 157
# epoch    157  total error     0.066006   avg weight        1.8516
#
# Epoch: 158
# epoch    158  total error     0.066246   avg weight        1.8647
#
# Epoch: 159
# epoch    159  total error     0.065646   avg weight        1.8566
#
# Epoch: 160
# epoch    160  total error     0.065522   avg weight        1.8653
#
# Epoch: 161
# epoch    161  total error     0.065289   avg weight        1.8723
#
# Epoch: 162
# epoch    162  total error     0.064959   avg weight        1.8825
#
# Epoch: 163
# epoch    163  total error     0.067626   avg weight        1.8948
#
# Epoch: 164
# epoch    164  total error     0.064925   avg weight        1.9088
#
# Epoch: 165
# epoch    165  total error     0.064431   avg weight        1.8981
#
# Epoch: 166
# epoch    166  total error     0.066875   avg weight        1.9092
#
# Epoch: 167
# epoch    167  total error     0.064786   avg weight        1.9192
#
# Epoch: 168
# epoch    168  total error     0.063783   avg weight        1.9247
#
# Epoch: 169
# epoch    169  total error     0.065631   avg weight        1.9359
#
# Epoch: 170
# epoch    170  total error     0.064012   avg weight        1.9494
#
# Epoch: 171
# epoch    171  total error     0.063326   avg weight        1.9378
#
# Epoch: 172
# epoch    172  total error     0.063467   avg weight        1.9464
#
# Epoch: 173
# epoch    173  total error     0.063306   avg weight        1.9553
#
# Epoch: 174
# epoch    174  total error     0.062817   avg weight        1.9671
#
# Epoch: 175
# epoch    175  total error     0.062694   avg weight        1.9811
#
# Epoch: 176
# epoch    176  total error     0.062695   avg weight        1.9749
#
# Epoch: 177
# epoch    177  total error     0.062169   avg weight        1.9847
#
# Epoch: 178
# epoch    178  total error     0.061991   avg weight        1.9879
#
# Epoch: 179
# epoch    179  total error     0.062087   avg weight        1.9987
#
# Epoch: 180
# epoch    180  total error     0.061711   avg weight        2.0117
#
# Epoch: 181
# epoch    181  total error     0.061613   avg weight        2.0184
#
# Epoch: 182
# epoch    182  total error     0.061567   avg weight        2.0311
#
# Epoch: 183
# epoch    183  total error     0.061217   avg weight        2.0481
#
# Epoch: 184
# epoch    184  total error     0.061127   avg weight        2.0641
#
# Epoch: 185
# epoch    185  total error     0.060884   avg weight         2.083
#
# Epoch: 186
# epoch    186  total error     0.060631   avg weight        2.0719
#
# Epoch: 187
# epoch    187  total error     0.060579   avg weight        2.0787
#
# Epoch: 188
# epoch    188  total error     0.060039   avg weight        2.0765
#
# Epoch: 189
# epoch    189  total error     0.059916   avg weight        2.0823
#
# Epoch: 190
# epoch    190  total error     0.059573   avg weight        2.0801
#
# Epoch: 191
# epoch    191  total error     0.059565   avg weight        2.0874
#
# Epoch: 192
# epoch    192  total error     0.059382   avg weight        2.0947
#
# Epoch: 193
# epoch    193  total error     0.059193   avg weight        2.0968
#
# Epoch: 194
# epoch    194  total error       0.0591   avg weight        2.1048
#
# Epoch: 195
# epoch    195  total error      0.05895   avg weight        2.1117
#
# Epoch: 196
# epoch    196  total error     0.058702   avg weight        2.1047
#
# Epoch: 197
# epoch    197  total error     0.058491   avg weight        2.1095
#
# Epoch: 198
# epoch    198  total error     0.058253   avg weight        2.1109
#
# Epoch: 199
# epoch    199  total error     0.057981   avg weight        2.1099
#
# Epoch: 200
# epoch    200  total error     0.057721   avg weight        2.1122
#
# Epoch: 201
# epoch    201  total error      0.05746   avg weight        2.1135
#
# Epoch: 202
# epoch    202  total error     0.057309   avg weight        2.1137
#
# Epoch: 203
# epoch    203  total error     0.057091   avg weight        2.1167
#
# Epoch: 204
# epoch    204  total error     0.057093   avg weight        2.1183
#
# Epoch: 205
# epoch    205  total error     0.056817   avg weight        2.1205
#
# Epoch: 206
# epoch    206  total error     0.056581   avg weight        2.1171
#
# Epoch: 207
# epoch    207  total error     0.056277   avg weight        2.1208
#
# Epoch: 208
# epoch    208  total error     0.055929   avg weight          2.12
#
# Epoch: 209
# epoch    209  total error     0.055576   avg weight         2.119
#
# Epoch: 210
# epoch    210  total error     0.055357   avg weight        2.1203
#
# Epoch: 211
# epoch    211  total error     0.055228   avg weight          2.12
#
# Epoch: 212
# epoch    212  total error     0.055219   avg weight        2.1171
#
# Epoch: 213
# epoch    213  total error     0.055102   avg weight         2.112
#
# Epoch: 214
# epoch    214  total error     0.055075   avg weight        2.1085
#
# Epoch: 215
# epoch    215  total error     0.054747   avg weight        2.1085
#
# Epoch: 216
# epoch    216  total error     0.054676   avg weight        2.1087
#
# Epoch: 217
# epoch    217  total error      0.05445   avg weight        2.1088
#
# Epoch: 218
# epoch    218  total error     0.054859   avg weight        2.1098
#
# Epoch: 219
# epoch    219  total error     0.054236   avg weight        2.1115
#
# Epoch: 220
# epoch    220  total error      0.05401   avg weight        2.1102
#
# Epoch: 221
# epoch    221  total error      0.05426   avg weight        2.1125
#
# Epoch: 222
# epoch    222  total error     0.053838   avg weight        2.1143
#
# Epoch: 223
# epoch    223  total error     0.053779   avg weight        2.1167
#
# Epoch: 224
# epoch    224  total error     0.053595   avg weight        2.1172
#
# Epoch: 225
# epoch    225  total error     0.053548   avg weight        2.1203
#
# Epoch: 226
# epoch    226  total error     0.053363   avg weight        2.1219
#
# Epoch: 227
# epoch    227  total error     0.053218   avg weight        2.1245
#
# Epoch: 228
# epoch    228  total error     0.053202   avg weight        2.1284
#
# Epoch: 229
# epoch    229  total error     0.052969   avg weight         2.128
#
# Epoch: 230
# epoch    230  total error     0.052861   avg weight        2.1344
#
# Epoch: 231
# epoch    231  total error      0.05276   avg weight        2.1392
#
# Epoch: 232
# epoch    232  total error      0.05245   avg weight        2.1411
#
# Epoch: 233
# epoch    233  total error     0.052306   avg weight        2.1479
#
# Epoch: 234
# epoch    234  total error     0.052133   avg weight        2.1549
#
# Epoch: 235
# epoch    235  total error        0.052   avg weight        2.1628
#
# Epoch: 236
# epoch    236  total error     0.051857   avg weight        2.1725
#
# Epoch: 237
# epoch    237  total error     0.051659   avg weight        2.1819
#
# Epoch: 238
# epoch    238  total error     0.051501   avg weight        2.1822
#
# Epoch: 239
# epoch    239  total error     0.051337   avg weight        2.1892
#
# Epoch: 240
# epoch    240  total error     0.051066   avg weight        2.1989
#
# Epoch: 241
# epoch    241  total error     0.050808   avg weight        2.2078
#
# Epoch: 242
# epoch    242  total error     0.050383   avg weight        2.2173
#
# Epoch: 243
# epoch    243  total error     0.050695   avg weight        2.2272
#
# Epoch: 244
# epoch    244  total error     0.050123   avg weight        2.2384
#
# Epoch: 245
# epoch    245  total error     0.051089   avg weight        2.2503
#
# Epoch: 246
# epoch    246  total error     0.050069   avg weight        2.2551
#
# Epoch: 247
# epoch    247  total error     0.049827   avg weight         2.266
#
# Epoch: 248
# epoch    248  total error     0.049692   avg weight        2.2724
#
# Epoch: 249
# epoch    249  total error     0.049637   avg weight        2.2847
#
# Epoch: 250
# epoch    250  total error     0.049491   avg weight        2.2886
#
# Epoch: 251
# epoch    251  total error      0.04936   avg weight        2.2997
#
# Epoch: 252
# epoch    252  total error     0.049161   avg weight        2.3113
#
# Epoch: 253
# epoch    253  total error     0.049102   avg weight        2.3276
#
# Epoch: 254
# epoch    254  total error     0.048831   avg weight        2.3458
#
# Epoch: 255
# epoch    255  total error     0.048511   avg weight        2.3481
#
# Epoch: 256
# epoch    256  total error     0.047994   avg weight        2.3572
#
# Epoch: 257
# epoch    257  total error     0.048007   avg weight        2.3661
#
# Epoch: 258
# epoch    258  total error     0.048135   avg weight        2.3741
#
# Epoch: 259
# epoch    259  total error     0.047744   avg weight         2.378
#
# Epoch: 260
# epoch    260  total error     0.047636   avg weight        2.3867
#
# Epoch: 261
# epoch    261  total error     0.067679   avg weight        2.3935
#
# Epoch: 262
# epoch    262  total error     0.047464   avg weight        2.3969
#
# Epoch: 263
# epoch    263  total error      0.04732   avg weight        2.4017
#
# Epoch: 264
# epoch    264  total error       0.0522   avg weight        2.4074
#
# Epoch: 265
# epoch    265  total error     0.047282   avg weight        2.4029
#
# Epoch: 266
# epoch    266  total error     0.047169   avg weight         2.406
#
# Epoch: 267
# epoch    267  total error     0.047825   avg weight        2.4084
#
# Epoch: 268
# epoch    268  total error     0.047005   avg weight        2.4028
#
# Epoch: 269
# epoch    269  total error     0.046846   avg weight        2.4047
#
# Epoch: 270
# epoch    270  total error     0.047026   avg weight        2.4074
#
# Epoch: 271
# epoch    271  total error     0.046898   avg weight        2.4103
#
# Epoch: 272
# epoch    272  total error     0.046561   avg weight        2.4102
#
# Epoch: 273
# epoch    273  total error     0.046773   avg weight        2.4173
#
# Epoch: 274
# epoch    274  total error     0.046463   avg weight        2.4206
#
# Epoch: 275
# epoch    275  total error     0.046201   avg weight        2.4191
#
# Epoch: 276
# epoch    276  total error     0.056532   avg weight        2.4229
#
# Epoch: 277
# epoch    277  total error     0.046329   avg weight          2.42
#
# Epoch: 278
# epoch    278  total error     0.046038   avg weight        2.4205
#
# Epoch: 279
# epoch    279  total error     0.050038   avg weight        2.4237
#
# Epoch: 280
# epoch    280  total error     0.045994   avg weight         2.428
#
# Epoch: 281
# epoch    281  total error     0.045874   avg weight        2.4338
#
# Epoch: 282
# epoch    282  total error     0.045753   avg weight        2.4315
#
# Epoch: 283
# epoch    283  total error      0.04566   avg weight        2.4353
#
# Epoch: 284
# epoch    284  total error      0.04551   avg weight        2.4384
#
# Epoch: 285
# epoch    285  total error     0.045363   avg weight        2.4418
#
# Epoch: 286
# epoch    286  total error     0.045207   avg weight        2.4394
#
# Epoch: 287
# epoch    287  total error      0.04506   avg weight        2.4409
#
# Epoch: 288
# epoch    288  total error     0.044903   avg weight        2.4407
#
# Epoch: 289
# epoch    289  total error     0.044649   avg weight        2.4455
#
# Epoch: 290
# epoch    290  total error      0.04453   avg weight        2.4428
#
# Epoch: 291
# epoch    291  total error     0.044264   avg weight        2.4468
#
# Epoch: 292
# epoch    292  total error     0.044125   avg weight        2.4505
#
# Epoch: 293
# epoch    293  total error     0.044072   avg weight        2.4564
#
# Epoch: 294
# epoch    294  total error     0.044085   avg weight        2.4587
#
# Epoch: 295
# epoch    295  total error     0.043753   avg weight         2.466
#
# Epoch: 296
# epoch    296  total error     0.043717   avg weight        2.4715
#
# Epoch: 297
# epoch    297  total error     0.043676   avg weight        2.4741
#
# Epoch: 298
# epoch    298  total error     0.043438   avg weight        2.4828
#
# Epoch: 299
# epoch    299  total error      0.04855   avg weight        2.4896
#
# Epoch: 300
# epoch    300  total error     0.043779   avg weight        2.4876
#
# Epoch: 301
# epoch    301  total error     0.043213   avg weight        2.4914
#
# Epoch: 302
# epoch    302  total error     0.047635   avg weight        2.4991
#
# Epoch: 303
# epoch    303  total error      0.04341   avg weight        2.4994
#
# Epoch: 304
# epoch    304  total error      0.04296   avg weight        2.5028
#
# Epoch: 305
# epoch    305  total error     0.043437   avg weight        2.5076
#
# Epoch: 306
# epoch    306  total error     0.042898   avg weight        2.5136
#
# Epoch: 307
# epoch    307  total error     0.042698   avg weight        2.5161
#
# Epoch: 308
# epoch    308  total error     0.042842   avg weight        2.5223
#
# Epoch: 309
# epoch    309  total error     0.042546   avg weight         2.528
#
# Epoch: 310
# epoch    310  total error     0.042477   avg weight        2.5319
#
# Epoch: 311
# epoch    311  total error     0.042414   avg weight        2.5372
#
# Epoch: 312
# epoch    312  total error     0.042296   avg weight        2.5431
#
# Epoch: 313
# epoch    313  total error     0.042202   avg weight        2.5496
#
# Epoch: 314
# epoch    314  total error     0.042002   avg weight        2.5545
#
# Epoch: 315
# epoch    315  total error     0.041918   avg weight        2.5525
#
# Epoch: 316
# epoch    316  total error      0.04186   avg weight        2.5525
#
# Epoch: 317
# epoch    317  total error     0.041758   avg weight        2.5569
#
# Epoch: 318
# epoch    318  total error     0.041633   avg weight          2.56
#
# Epoch: 319
# epoch    319  total error     0.041522   avg weight         2.565
#
# Epoch: 320
# epoch    320  total error      0.04144   avg weight        2.5714
#
# Epoch: 321
# epoch    321  total error     0.041278   avg weight        2.5725
#
# Epoch: 322
# epoch    322  total error     0.041093   avg weight        2.5769
#
# Epoch: 323
# epoch    323  total error     0.040926   avg weight        2.5821
#
# Epoch: 324
# epoch    324  total error     0.040751   avg weight        2.5867
#
# Epoch: 325
# epoch    325  total error      0.04074   avg weight         2.593
#
# Epoch: 326
# epoch    326  total error     0.040627   avg weight        2.6012
#
# Epoch: 327
# epoch    327  total error     0.040471   avg weight        2.6114
#
# Epoch: 328
# epoch    328  total error     0.040328   avg weight        2.6217
#
# Epoch: 329
# epoch    329  total error     0.040103   avg weight        2.6308
#
# Epoch: 330
# epoch    330  total error     0.040024   avg weight        2.6395
#
# Epoch: 331
# epoch    331  total error     0.039638   avg weight        2.6524
#
# Epoch: 332
# epoch    332  total error     0.075714   avg weight        2.6643
#
# Epoch: 333
# epoch    333  total error     0.040502   avg weight        2.6717
#
# Epoch: 334
# epoch    334  total error     0.039721   avg weight        2.6677
#
# Epoch: 335
# epoch    335  total error     0.039856   avg weight        2.6778
#
# Epoch: 336
# epoch    336  total error     0.039418   avg weight        2.6869
#
# Epoch: 337
# epoch    337  total error       0.0394   avg weight        2.6923
#
# Epoch: 338
# epoch    338  total error      0.03953   avg weight        2.6914
#
# Epoch: 339
# epoch    339  total error     0.039227   avg weight        2.6997
#
# Epoch: 340
# epoch    340  total error     0.039143   avg weight        2.7075
#
# Epoch: 341
# epoch    341  total error      0.03915   avg weight        2.7182
#
# Epoch: 342
# epoch    342  total error     0.038903   avg weight        2.7213
#
# Epoch: 343
# epoch    343  total error     0.038716   avg weight        2.7325
#
# Epoch: 344
# epoch    344  total error      0.03874   avg weight        2.7455
#
# Epoch: 345
# epoch    345  total error     0.038541   avg weight        2.7603
#
# Epoch: 346
# epoch    346  total error     0.038507   avg weight        2.7729
#
# Epoch: 347
# epoch    347  total error     0.038346   avg weight        2.7777
#
# Epoch: 348
# epoch    348  total error     0.038192   avg weight        2.7845
#
# Epoch: 349
# epoch    349  total error     0.038113   avg weight        2.7932
#
# Epoch: 350
# epoch    350  total error     0.037975   avg weight        2.8061
#
# Epoch: 351
# epoch    351  total error     0.037942   avg weight        2.8196
#
# Epoch: 352
# epoch    352  total error     0.037915   avg weight        2.8249
#
# Epoch: 353
# epoch    353  total error     0.037712   avg weight        2.8402
#
# Epoch: 354
# epoch    354  total error      0.03775   avg weight        2.8545
#
# Epoch: 355
# epoch    355  total error      0.03781   avg weight        2.8666
#
# Epoch: 356
# epoch    356  total error     0.037464   avg weight        2.8819
#
# Epoch: 357
# epoch    357  total error     0.037482   avg weight        2.8923
#
# Epoch: 358
# epoch    358  total error     0.037466   avg weight        2.9069
#
# Epoch: 359
# epoch    359  total error     0.037209   avg weight        2.9225
#
# Epoch: 360
# epoch    360  total error     0.037112   avg weight        2.9275
#
# Epoch: 361
# epoch    361  total error     0.037133   avg weight        2.9324
#
# Epoch: 362
# epoch    362  total error     0.036871   avg weight        2.9411
#
# Epoch: 363
# epoch    363  total error     0.036884   avg weight        2.9505
#
# Epoch: 364
# epoch    364  total error     0.036621   avg weight        2.9588
#
# Epoch: 365
# epoch    365  total error      0.03654   avg weight        2.9604
#
# Epoch: 366
# epoch    366  total error     0.036421   avg weight        2.9645
#
# Epoch: 367
# epoch    367  total error     0.036157   avg weight        2.9698
#
# Epoch: 368
# epoch    368  total error     0.035981   avg weight         2.977
#
# Epoch: 369
# epoch    369  total error      0.03572   avg weight        2.9944
#
# Epoch: 370
# epoch    370  total error     0.035556   avg weight        3.0095
#
# Epoch: 371
# epoch    371  total error     0.035652   avg weight        3.0244
#
# Epoch: 372
# epoch    372  total error     0.035378   avg weight        3.0396
#
# Epoch: 373
# epoch    373  total error     0.035192   avg weight        3.0535
#
# Epoch: 374
# epoch    374  total error     0.035345   avg weight        3.0679
#
# Epoch: 375
# epoch    375  total error     0.035009   avg weight         3.085
#
# Epoch: 376
# epoch    376  total error     0.035036   avg weight        3.1041
#
# Epoch: 377
# epoch    377  total error     0.034846   avg weight        3.1206
#
# Epoch: 378
# epoch    378  total error      0.03469   avg weight        3.1404
#
# Epoch: 379
# epoch    379  total error     0.034555   avg weight        3.1589
#
# Epoch: 380
# epoch    380  total error     0.034404   avg weight        3.1784
#
# Epoch: 381
# epoch    381  total error     0.034395   avg weight        3.1836
#
# Epoch: 382
# epoch    382  total error     0.034369   avg weight        3.1961
#
# Epoch: 383
# epoch    383  total error     0.034119   avg weight        3.2034
#
# Epoch: 384
# epoch    384  total error     0.033965   avg weight        3.2145
#
# Epoch: 385
# epoch    385  total error      0.03388   avg weight        3.2287
#
# Epoch: 386
# epoch    386  total error     0.033815   avg weight        3.2406
#
# Epoch: 387
# epoch    387  total error     0.033631   avg weight        3.2554
#
# Epoch: 388
# epoch    388  total error     0.033473   avg weight        3.2745
#
# Epoch: 389
# epoch    389  total error      0.03326   avg weight         3.292
#
# Epoch: 390
# epoch    390  total error     0.033128   avg weight         3.312
#
# Epoch: 391
# epoch    391  total error     0.032945   avg weight        3.3353
#
# Epoch: 392
# epoch    392  total error     0.032826   avg weight        3.3603
#
# Epoch: 393
# epoch    393  total error     0.033011   avg weight        3.3569
#
# Epoch: 394
# epoch    394  total error     0.032566   avg weight        3.3755
#
# Epoch: 395
# epoch    395  total error     0.032667   avg weight        3.3901
#
# Epoch: 396
# epoch    396  total error     0.032381   avg weight        3.4025
#
# Epoch: 397
# epoch    397  total error     0.032481   avg weight        3.4098
#
# Epoch: 398
# epoch    398  total error     0.032287   avg weight        3.4129
#
# Epoch: 399
# epoch    399  total error     0.032146   avg weight        3.4307
#
# Epoch: 400
# epoch    400  total error     0.031963   avg weight        3.4414
#
# Epoch: 401
# epoch    401  total error     0.031769   avg weight        3.4621
#
# Epoch: 402
# epoch    402  total error      0.03154   avg weight        3.4795
#
# Epoch: 403
# epoch    403  total error     0.031388   avg weight        3.4937
#
# Epoch: 404
# epoch    404  total error      0.03167   avg weight        3.4993
#
# Epoch: 405
# epoch    405  total error     0.031422   avg weight        3.5135
#
# Epoch: 406
# epoch    406  total error     0.031268   avg weight        3.5247
#
# Epoch: 407
# epoch    407  total error     0.031129   avg weight        3.5285
#
# Epoch: 408
# epoch    408  total error     0.031147   avg weight        3.5279
#
# Epoch: 409
# epoch    409  total error     0.030964   avg weight        3.5369
#
# Epoch: 410
# epoch    410  total error     0.030835   avg weight        3.5413
#
# Epoch: 411
# epoch    411  total error     0.030799   avg weight        3.5513
#
# Epoch: 412
# epoch    412  total error     0.030621   avg weight        3.5584
#
# Epoch: 413
# epoch    413  total error     0.030675   avg weight        3.5717
#
# Epoch: 414
# epoch    414  total error     0.030369   avg weight        3.5869
#
# Epoch: 415
# epoch    415  total error     0.030342   avg weight        3.5903
#
# Epoch: 416
# epoch    416  total error      0.03018   avg weight        3.6039
#
# Epoch: 417
# epoch    417  total error     0.030246   avg weight        3.6132
#
# Epoch: 418
# epoch    418  total error     0.030201   avg weight        3.6245
#
# Epoch: 419
# epoch    419  total error     0.030091   avg weight        3.6372
#
# Epoch: 420
# epoch    420  total error     0.029979   avg weight        3.6498
#
# Epoch: 421
# epoch    421  total error     0.029973   avg weight        3.6643
#
# Epoch: 422
# epoch    422  total error     0.029789   avg weight        3.6687
#
# Epoch: 423
# epoch    423  total error      0.02971   avg weight        3.6825
#
# Epoch: 424
# epoch    424  total error     0.029542   avg weight        3.6963
#
# Epoch: 425
# epoch    425  total error     0.029365   avg weight         3.697
#
# Epoch: 426
# epoch    426  total error     0.029364   avg weight        3.7082
#
# Epoch: 427
# epoch    427  total error     0.029296   avg weight        3.7201
#
# Epoch: 428
# epoch    428  total error      0.02934   avg weight        3.7371
#
# Epoch: 429
# epoch    429  total error     0.029125   avg weight        3.7518
#
# Epoch: 430
# epoch    430  total error     0.029069   avg weight        3.7614
#
# Epoch: 431
# epoch    431  total error     0.028911   avg weight        3.7763
#
# Epoch: 432
# epoch    432  total error     0.028728   avg weight        3.7897
#
# Epoch: 433
# epoch    433  total error     0.029186   avg weight        3.8073
#
# Epoch: 434
# epoch    434  total error     0.028723   avg weight        3.8051
#
# Epoch: 435
# epoch    435  total error     0.028595   avg weight        3.8067
#
# Epoch: 436
# epoch    436  total error     0.028825   avg weight        3.8153
#
# Epoch: 437
# epoch    437  total error     0.028536   avg weight        3.8242
#
# Epoch: 438
# epoch    438  total error     0.028392   avg weight        3.8343
#
# Epoch: 439
# epoch    439  total error     0.028505   avg weight        3.8315
#
# Epoch: 440
# epoch    440  total error     0.028345   avg weight        3.8373
#
# Epoch: 441
# epoch    441  total error     0.028188   avg weight        3.8395
#
# Epoch: 442
# epoch    442  total error     0.028305   avg weight        3.8453
#
# Epoch: 443
# epoch    443  total error     0.028079   avg weight        3.8514
#
# Epoch: 444
# epoch    444  total error     0.028011   avg weight        3.8516
#
# Epoch: 445
# epoch    445  total error     0.027931   avg weight        3.8547
#
# Epoch: 446
# epoch    446  total error     0.028006   avg weight         3.852
#
# Epoch: 447
# epoch    447  total error     0.027778   avg weight         3.851
#
# Epoch: 448
# epoch    448  total error     0.027639   avg weight        3.8506
#
# Epoch: 449
# epoch    449  total error     0.027474   avg weight        3.8545
#
# Epoch: 450
# epoch    450  total error     0.027496   avg weight        3.8593
#
# Epoch: 451
# epoch    451  total error     0.027302   avg weight        3.8686
#
# Epoch: 452
# epoch    452  total error     0.027149   avg weight        3.8695
#
# Epoch: 453
# epoch    453  total error     0.026945   avg weight        3.8691
#
# Epoch: 454
# epoch    454  total error     0.026722   avg weight        3.8681
#
# Epoch: 455
# epoch    455  total error     0.026878   avg weight        3.8766
#
# Epoch: 456
# epoch    456  total error     0.026578   avg weight        3.8753
#
# Epoch: 457
# epoch    457  total error     0.026614   avg weight        3.8812
#
# Epoch: 458
# epoch    458  total error     0.026352   avg weight        3.8822
#
# Epoch: 459
# epoch    459  total error     0.026182   avg weight         3.886
#
# Epoch: 460
# epoch    460  total error     0.026154   avg weight        3.8866
#
# Epoch: 461
# epoch    461  total error     0.025974   avg weight         3.889
#
# Epoch: 462
# epoch    462  total error     0.025813   avg weight        3.8897
#
# Epoch: 463
# epoch    463  total error     0.025614   avg weight        3.8903
#
# Epoch: 464
# epoch    464  total error     0.025418   avg weight        3.8921
#
# Epoch: 465
# epoch    465  total error     0.025244   avg weight        3.9011
#
# Epoch: 466
# epoch    466  total error     0.025124   avg weight        3.9055
#
# Epoch: 467
# epoch    467  total error     0.025257   avg weight        3.9076
#
# Epoch: 468
# epoch    468  total error     0.025079   avg weight        3.9091
#
# Epoch: 469
# epoch    469  total error     0.024992   avg weight        3.9112
#
# Epoch: 470
# epoch    470  total error     0.025135   avg weight         3.911
#
# Epoch: 471
# epoch    471  total error     0.024687   avg weight        3.9128
#
# Epoch: 472
# epoch    472  total error     0.025031   avg weight        3.9154
#
# Epoch: 473
# epoch    473  total error     0.024599   avg weight        3.9161
#
# Epoch: 474
# epoch    474  total error     0.024629   avg weight        3.9193
#
# Epoch: 475
# epoch    475  total error     0.024482   avg weight        3.9207
#
# Epoch: 476
# epoch    476  total error     0.024401   avg weight        3.9219
#
# Epoch: 477
# epoch    477  total error     0.024226   avg weight        3.9211
#
# Epoch: 478
# epoch    478  total error      0.02408   avg weight        3.9213
#
# Epoch: 479
# epoch    479  total error     0.023905   avg weight        3.9219
#
# Epoch: 480
# epoch    480  total error     0.023866   avg weight        3.9139
#
# Epoch: 481
# epoch    481  total error     0.024203   avg weight        3.9066
#
# Epoch: 482
# epoch    482  total error     0.023664   avg weight        3.8998
#
# Epoch: 483
# epoch    483  total error     0.023533   avg weight        3.8921
#
# Epoch: 484
# epoch    484  total error     0.023346   avg weight        3.8853
#
# Epoch: 485
# epoch    485  total error     0.023162   avg weight        3.8796
#
# Epoch: 486
# epoch    486  total error     0.023035   avg weight        3.8728
#
# Epoch: 487
# epoch    487  total error     0.022792   avg weight        3.8616
#
# Epoch: 488
# epoch    488  total error     0.022578   avg weight        3.8567
#
# Epoch: 489
# epoch    489  total error     0.022552   avg weight        3.8518
#
# Epoch: 490
# epoch    490  total error     0.022385   avg weight        3.8476
#
# Epoch: 491
# epoch    491  total error     0.022993   avg weight         3.845
#
# Epoch: 492
# epoch    492  total error     0.022391   avg weight        3.8419
#
# Epoch: 493
# epoch    493  total error     0.022492   avg weight          3.84
#
# Epoch: 494
# epoch    494  total error      0.02221   avg weight        3.8517
#
# Epoch: 495
# epoch    495  total error      0.02217   avg weight        3.8543
#
# Epoch: 496
# epoch    496  total error      0.02206   avg weight         3.855
#
# Epoch: 497
# epoch    497  total error     0.021956   avg weight        3.8572
#
# Epoch: 498
# epoch    498  total error     0.021989   avg weight        3.8565
#
# Epoch: 499
# epoch    499  total error     0.021767   avg weight        3.8479
#
# Epoch: 500
# epoch    500  total error     0.021836   avg weight        3.8416
#
# Epoch: 501
# epoch    501  total error     0.021666   avg weight        3.8401
#
# Epoch: 502
# epoch    502  total error      0.02155   avg weight        3.8382
#
# Epoch: 503
# epoch    503  total error     0.021438   avg weight        3.8351
#
# Epoch: 504
# epoch    504  total error       0.0213   avg weight        3.8318
#
# Epoch: 505
# epoch    505  total error     0.021125   avg weight        3.8283
#
# Epoch: 506
# epoch    506  total error     0.020991   avg weight        3.8358
#
# Epoch: 507
# epoch    507  total error     0.021079   avg weight        3.8363
#
# Epoch: 508
# epoch    508  total error     0.021049   avg weight        3.8354
#
# Epoch: 509
# epoch    509  total error     0.020737   avg weight        3.8411
#
# Epoch: 510
# epoch    510  total error     0.020803   avg weight         3.844
#
# Epoch: 511
# epoch    511  total error      0.02066   avg weight        3.8464
#
# Epoch: 512
# epoch    512  total error     0.020923   avg weight        3.8526
#
# Epoch: 513
# epoch    513  total error     0.031911   avg weight        3.8544
#
# Epoch: 514
# epoch    514  total error     0.020673   avg weight        3.8573
#
# Epoch: 515
# epoch    515  total error      0.02056   avg weight        3.8622
#
# Epoch: 516
# epoch    516  total error     0.031932   avg weight        3.8677
#
# Epoch: 517
# epoch    517  total error     0.020442   avg weight        3.8727
#
# Epoch: 518
# epoch    518  total error     0.021797   avg weight        3.8773
#
# Epoch: 519
# epoch    519  total error     0.020404   avg weight        3.8822
#
# Epoch: 520
# epoch    520  total error     0.020478   avg weight         3.887
#
# Epoch: 521
# epoch    521  total error     0.020332   avg weight        3.8927
#
# Epoch: 522
# epoch    522  total error     0.020307   avg weight        3.8982
#
# Epoch: 523
# epoch    523  total error     0.020357   avg weight        3.9039
#
# Epoch: 524
# epoch    524  total error     0.020211   avg weight        3.9101
#
# Epoch: 525
# epoch    525  total error     0.020171   avg weight        3.9046
#
# Epoch: 526
# epoch    526  total error     0.020149   avg weight        3.9023
#
# Epoch: 527
# epoch    527  total error     0.020019   avg weight        3.9001
#
# Epoch: 528
# epoch    528  total error     0.019951   avg weight        3.9002
#
# Epoch: 529
# epoch    529  total error     0.019958   avg weight        3.8924
#
# Epoch: 530
# epoch    530  total error     0.019827   avg weight        3.9084
#
# Epoch: 531
# epoch    531  total error     0.019758   avg weight        3.9102
#
# Epoch: 532
# epoch    532  total error     0.019607   avg weight        3.9173
#
# Epoch: 533
# epoch    533  total error     0.019502   avg weight        3.9189
#
# Epoch: 534
# epoch    534  total error     0.019382   avg weight        3.9181
#
# Epoch: 535
# epoch    535  total error     0.019253   avg weight        3.9164
#
# Epoch: 536
# epoch    536  total error     0.019125   avg weight        3.9157
#
# Epoch: 537
# epoch    537  total error     0.018918   avg weight        3.9113
#
# Epoch: 538
# epoch    538  total error     0.019103   avg weight        3.9087
#
# Epoch: 539
# epoch    539  total error     0.018839   avg weight         3.905
#
# Epoch: 540
# epoch    540  total error     0.018871   avg weight        3.9019
#
# Epoch: 541
# epoch    541  total error     0.018759   avg weight        3.9051
#
# Epoch: 542
# epoch    542  total error     0.018737   avg weight        3.9045
#
# Epoch: 543
# epoch    543  total error     0.018607   avg weight        3.9028
#
# Epoch: 544
# epoch    544  total error     0.018492   avg weight        3.9052
#
# Epoch: 545
# epoch    545  total error      0.01833   avg weight        3.9078
#
# Epoch: 546
# epoch    546  total error     0.018212   avg weight        3.9062
#
# Epoch: 547
# epoch    547  total error     0.018028   avg weight        3.9072
#
# Epoch: 548
# epoch    548  total error     0.017967   avg weight        3.9057
#
# Epoch: 549
# epoch    549  total error     0.017725   avg weight         3.908
#
# Epoch: 550
# epoch    550  total error     0.017904   avg weight        3.9081
#
# Epoch: 551
# epoch    551  total error     0.017608   avg weight        3.9075
#
# Epoch: 552
# epoch    552  total error     0.017535   avg weight        3.9083
#
# Epoch: 553
# epoch    553  total error     0.017615   avg weight        3.9076
#
# Epoch: 554
# epoch    554  total error     0.017503   avg weight        3.9074
#
# Epoch: 555
# epoch    555  total error     0.017368   avg weight        3.9071
#
# Epoch: 556
# epoch    556  total error     0.017317   avg weight        3.9085
#
# Epoch: 557
# epoch    557  total error     0.017214   avg weight        3.9091
#
# Epoch: 558
# epoch    558  total error      0.01708   avg weight        3.9082
#
# Epoch: 559
# epoch    559  total error      0.01698   avg weight        3.9128
#
# Epoch: 560
# epoch    560  total error     0.016828   avg weight        3.9146
#
# Epoch: 561
# epoch    561  total error     0.016846   avg weight        3.9179
#
# Epoch: 562
# epoch    562  total error     0.016983   avg weight        3.9173
#
# Epoch: 563
# epoch    563  total error     0.016633   avg weight        3.9195
#
# Epoch: 564
# epoch    564  total error     0.016515   avg weight        3.9197
#
# Epoch: 565
# epoch    565  total error     0.016704   avg weight        3.9212
#
# Epoch: 566
# epoch    566  total error     0.016272   avg weight         3.922
#
# Epoch: 567
# epoch    567  total error     0.016555   avg weight        3.9238
#
# Epoch: 568
# epoch    568  total error     0.016237   avg weight        3.9212
#
# Epoch: 569
# epoch    569  total error     0.016273   avg weight        3.9209
#
# Epoch: 570
# epoch    570  total error     0.016159   avg weight        3.9197
#
# Epoch: 571
# epoch    571  total error     0.016094   avg weight        3.9193
#
# Epoch: 572
# epoch    572  total error     0.016031   avg weight        3.9191
#
# Epoch: 573
# epoch    573  total error     0.015934   avg weight        3.9181
#
# Epoch: 574
# epoch    574  total error     0.015816   avg weight        3.9155
#
# Epoch: 575
# epoch    575  total error     0.015792   avg weight        3.9133
#
# Epoch: 576
# epoch    576  total error     0.015738   avg weight        3.9106
#
# Epoch: 577
# epoch    577  total error     0.015654   avg weight        3.9079
#
# Epoch: 578
# epoch    578  total error     0.015622   avg weight        3.9045
#
# Epoch: 579
# epoch    579  total error     0.015487   avg weight        3.8988
#
# Epoch: 580
# epoch    580  total error     0.015402   avg weight        3.8943
#
# Epoch: 581
# epoch    581  total error     0.015272   avg weight        3.8898
#
# Epoch: 582
# epoch    582  total error     0.015171   avg weight        3.8864
#
# Epoch: 583
# epoch    583  total error     0.015003   avg weight        3.8818
#
# Epoch: 584
# epoch    584  total error     0.015095   avg weight         3.879
#
# Epoch: 585
# epoch    585  total error     0.014945   avg weight        3.8753
#
# Epoch: 586
# epoch    586  total error     0.014918   avg weight        3.8719
#
# Epoch: 587
# epoch    587  total error      0.01476   avg weight        3.8692
#
# Epoch: 588
# epoch    588  total error     0.014842   avg weight        3.8654
#
# Epoch: 589
# epoch    589  total error     0.014712   avg weight        3.8681
#
# Epoch: 590
# epoch    590  total error     0.014736   avg weight        3.8672
#
# Epoch: 591
# epoch    591  total error     0.014612   avg weight        3.8669
#
# Epoch: 592
# epoch    592  total error     0.014539   avg weight        3.8712
#
# Epoch: 593
# epoch    593  total error     0.014414   avg weight        3.8692
#
# Epoch: 594
# epoch    594  total error     0.014306   avg weight        3.8723
#
# Epoch: 595
# epoch    595  total error     0.014236   avg weight        3.8736
#
# Epoch: 596
# epoch    596  total error     0.014087   avg weight        3.8757
#
# Epoch: 597
# epoch    597  total error     0.014229   avg weight        3.8758
#
# Epoch: 598
# epoch    598  total error     0.014017   avg weight        3.8773
#
# Epoch: 599
# epoch    599  total error     0.014031   avg weight        3.8768
#
# Epoch: 600
# epoch    600  total error     0.013907   avg weight        3.8782
#
# Epoch: 601
# epoch    601  total error     0.013853   avg weight        3.8794
#
# Epoch: 602
# epoch    602  total error     0.013759   avg weight        3.8815
#
# Epoch: 603
# epoch    603  total error     0.013668   avg weight        3.8758
#
# Epoch: 604
# epoch    604  total error     0.013581   avg weight        3.8778
#
# Epoch: 605
# epoch    605  total error     0.013626   avg weight        3.8803
#
# Epoch: 606
# epoch    606  total error      0.01357   avg weight        3.8792
#
# Epoch: 607
# epoch    607  total error     0.013432   avg weight        3.8802
#
# Epoch: 608
# epoch    608  total error     0.013446   avg weight        3.8825
#
# Epoch: 609
# epoch    609  total error     0.013363   avg weight        3.8849
#
# Epoch: 610
# epoch    610  total error      0.01327   avg weight        3.8865
#
# Epoch: 611
# epoch    611  total error     0.013183   avg weight        3.8891
#
# Epoch: 612
# epoch    612  total error     0.013085   avg weight         3.892
#
# Epoch: 613
# epoch    613  total error     0.012991   avg weight        3.8911
#
# Epoch: 614
# epoch    614  total error     0.012902   avg weight        3.8926
#
# Epoch: 615
# epoch    615  total error     0.012985   avg weight        3.8955
#
# Epoch: 616
# ...
#
# Epoch: 795
# epoch    795  total error    0.0046826   avg weight        4.1673
#
# Epoch: 796
# epoch    796  total error    0.0046842   avg weight        4.1669
#
# Epoch: 797
# epoch    797  total error    0.0046472   avg weight        4.1666
#
# Epoch: 798
# epoch    798  total error    0.0046152   avg weight        4.1674
#
# Epoch: 799
# epoch    799  total error     0.004576   avg weight        4.1678
#
# Epoch: 800
# epoch    800  total error    0.0045352   avg weight        4.1678
#
# Epoch: 801
# epoch    801  total error    0.0044827   avg weight        4.1681
#
# Epoch: 802
# epoch    802  total error    0.0044724   avg weight        4.1683
#
# Epoch: 803
# epoch    803  total error     0.004453   avg weight        4.1632
#
# Epoch: 804
# epoch    804  total error    0.0044571   avg weight        4.1625
#
# Epoch: 805
# epoch    805  total error    0.0044176   avg weight        4.1593
#
# Epoch: 806
# epoch    806  total error    0.0044126   avg weight        4.1591
#
# Epoch: 807
# epoch    807  total error    0.0043681   avg weight        4.1629
#
# Epoch: 808
# epoch    808  total error    0.0043326   avg weight        4.1673
#
# Epoch: 809
# epoch    809  total error    0.0042923   avg weight         4.172
#
# Epoch: 810
# epoch    810  total error    0.0042488   avg weight         4.177
#
# Epoch: 811
# epoch    811  total error    0.0041993   avg weight        4.1836
#
# Epoch: 812
# epoch    812  total error    0.0041435   avg weight        4.1776
#
# Epoch: 813
# epoch    813  total error     0.004104   avg weight        4.1806
#
# Epoch: 814
# epoch    814  total error    0.0041021   avg weight        4.1797
#
# Epoch: 815
# epoch    815  total error    0.0041947   avg weight        4.1795
#
# Epoch: 816
# epoch    816  total error    0.0040735   avg weight        4.1811
#
# Epoch: 817
# epoch    817  total error    0.0041308   avg weight        4.1836
#
# Epoch: 818
# epoch    818  total error    0.0040745   avg weight        4.1815
#
# Epoch: 819
# epoch    819  total error    0.0040381   avg weight        4.1845
#
# Epoch: 820
# epoch    820  total error     0.014484   avg weight        4.1866
#
# Epoch: 821
# epoch    821  total error    0.0040961   avg weight        4.1866
#
# Epoch: 822
# epoch    822  total error    0.0042547   avg weight        4.1875
#
# Epoch: 823
# epoch    823  total error    0.0040621   avg weight        4.1894
#
# Epoch: 824
# epoch    824  total error    0.0040151   avg weight        4.1914
#
# Epoch: 825
# epoch    825  total error     0.004041   avg weight         4.192
#
# Epoch: 826
# epoch    826  total error     0.004006   avg weight        4.1918
#
# Epoch: 827
# epoch    827  total error    0.0039793   avg weight        4.1926
#
# Epoch: 828
# epoch    828  total error    0.0039703   avg weight        4.1931
#
# Epoch: 829
# epoch    829  total error    0.0039435   avg weight        4.1944
#
# Epoch: 830
# epoch    830  total error    0.0039232   avg weight        4.1948
#
# Epoch: 831
# epoch    831  total error    0.0039004   avg weight         4.196
#
# Epoch: 832
# epoch    832  total error    0.0038724   avg weight        4.1978
#
# Epoch: 833
# epoch    833  total error    0.0038401   avg weight        4.1997
#
# Epoch: 834
# epoch    834  total error     0.003884   avg weight        4.1992
#
# Epoch: 835
# epoch    835  total error      0.00383   avg weight        4.2016
#
# Epoch: 836
# epoch    836  total error    0.0038203   avg weight        4.2012
#
# Epoch: 837
# epoch    837  total error    0.0037917   avg weight        4.2025
#
# Epoch: 838
# epoch    838  total error    0.0037604   avg weight         4.205
#
# Epoch: 839
# epoch    839  total error    0.0037252   avg weight        4.2052
#
# Epoch: 840
# epoch    840  total error    0.0036932   avg weight        4.2078
#
# Epoch: 841
# epoch    841  total error    0.0036509   avg weight        4.2068
#
# Epoch: 842
# epoch    842  total error    0.0035977   avg weight        4.2074
#
# Epoch: 843
# epoch    843  total error    0.0036432   avg weight        4.2092
#
# Epoch: 844
# epoch    844  total error    0.0036523   avg weight        4.2118
#
# Epoch: 845
# epoch    845  total error    0.0036141   avg weight        4.2109
#
# Epoch: 846
# epoch    846  total error      0.00357   avg weight        4.2109
#
# Epoch: 847
# epoch    847  total error    0.0035463   avg weight        4.2123
#
# Epoch: 848
# epoch    848  total error     0.003514   avg weight        4.2131
#
# Epoch: 849
# epoch    849  total error    0.0034671   avg weight        4.2144
#
# Epoch: 850
# epoch    850  total error     0.003606   avg weight        4.2153
#
# Epoch: 851
# epoch    851  total error    0.0036195   avg weight        4.2129
#
# Epoch: 852
# epoch    852  total error    0.0034075   avg weight        4.2146
#
# Epoch: 853
# epoch    853  total error    0.0035577   avg weight        4.2157
#
# Epoch: 854
# epoch    854  total error    0.0034855   avg weight        4.2148
#
# Epoch: 855
# epoch    855  total error    0.0033831   avg weight        4.2161
#
# Epoch: 856
# epoch    856  total error    0.0034787   avg weight        4.2168
#
# Epoch: 857
# epoch    857  total error    0.0034127   avg weight        4.2164
#
# Epoch: 858
# epoch    858  total error    0.0033706   avg weight        4.2178
#
# Epoch: 859
# epoch    859  total error    0.0033686   avg weight         4.218
#
# Epoch: 860
# epoch    860  total error    0.0033434   avg weight        4.2185
#
# Epoch: 861
# epoch    861  total error     0.003341   avg weight        4.2192
#
# Epoch: 862
# epoch    862  total error    0.0033231   avg weight          4.22
#
# Epoch: 863
# epoch    863  total error    0.0033012   avg weight        4.2215
#
# Epoch: 864
# epoch    864  total error    0.0032853   avg weight        4.2227
#
# Epoch: 865
# epoch    865  total error    0.0032679   avg weight        4.2231
#
# Epoch: 866
# epoch    866  total error    0.0032475   avg weight        4.2237
#
# Epoch: 867
# epoch    867  total error    0.0032014   avg weight        4.2247
#
# Epoch: 868
# epoch    868  total error    0.0032649   avg weight        4.2257
#
# Epoch: 869
# epoch    869  total error    0.0031993   avg weight        4.2271
#
# Epoch: 870
# epoch    870  total error    0.0032086   avg weight        4.2286
#
# Epoch: 871
# epoch    871  total error    0.0031724   avg weight          4.23
#
# Epoch: 872
# epoch    872  total error    0.0031662   avg weight        4.2317
#
# Epoch: 873
# epoch    873  total error     0.003143   avg weight        4.2369
#
# Epoch: 874
# epoch    874  total error    0.0031154   avg weight        4.2406
#
# Epoch: 875
# epoch    875  total error    0.0030844   avg weight         4.244
#
# Epoch: 876
# epoch    876  total error    0.0030518   avg weight        4.2359
#
# Epoch: 877
# epoch    877  total error    0.0030171   avg weight        4.2366
#
# Epoch: 878
# epoch    878  total error    0.0029701   avg weight        4.2327
#
# Epoch: 879
# epoch    879  total error    0.0030004   avg weight        4.2346
#
# Epoch: 880
# epoch    880  total error    0.0029494   avg weight        4.2342
#
# Epoch: 881
# epoch    881  total error     0.003001   avg weight        4.2353
#
# Epoch: 882
# epoch    882  total error    0.0029359   avg weight        4.2362
#
# Epoch: 883
# epoch    883  total error    0.0029442   avg weight        4.2375
#
# Epoch: 884
# epoch    884  total error    0.0029113   avg weight        4.2383
#
# Epoch: 885
# epoch    885  total error     0.002884   avg weight        4.2399
#
# Epoch: 886
# epoch    886  total error    0.0028537   avg weight        4.2399
#
# Epoch: 887
# epoch    887  total error    0.0028255   avg weight        4.2416
#
# Epoch: 888
# epoch    888  total error    0.0028054   avg weight        4.2415
#
# Epoch: 889
# epoch    889  total error     0.002771   avg weight        4.2422
#
# Epoch: 890
# epoch    890  total error    0.0027341   avg weight        4.2435
#
# Epoch: 891
# epoch    891  total error    0.0027346   avg weight        4.2448
#
# Epoch: 892
# epoch    892  total error    0.0026876   avg weight        4.2452
#
# Epoch: 893
# epoch    893  total error    0.0027167   avg weight        4.2461
#
# Epoch: 894
# epoch    894  total error    0.0026798   avg weight        4.2466
#
# Epoch: 895
# epoch    895  total error    0.0026941   avg weight         4.247
#
# Epoch: 896
# epoch    896  total error    0.0026711   avg weight        4.2475
#
# Epoch: 897
# epoch    897  total error    0.0026574   avg weight        4.2494
#
# Epoch: 898
# epoch    898  total error    0.0026545   avg weight        4.2494
#
# Epoch: 899
# epoch    899  total error    0.0026319   avg weight        4.2499
#
# Epoch: 900
# epoch    900  total error    0.0026039   avg weight        4.2512
#
# Epoch: 901
# epoch    901  total error    0.0025836   avg weight        4.2517
#
# Epoch: 902
# epoch    902  total error    0.0025525   avg weight         4.252
#
# Epoch: 903
# epoch    903  total error     0.002529   avg weight        4.2534
#
# Epoch: 904
# epoch    904  total error    0.0025076   avg weight        4.2541
#
# Epoch: 905
# epoch    905  total error    0.0025351   avg weight        4.2549
#
# Epoch: 906
# epoch    906  total error    0.0024833   avg weight        4.2557
#
# Epoch: 907
# epoch    907  total error    0.0025032   avg weight        4.2549
#
# Epoch: 908
# epoch    908  total error    0.0024693   avg weight        4.2557
#
# Epoch: 909
# epoch    909  total error    0.0024709   avg weight        4.2556
#
# Epoch: 910
# epoch    910  total error    0.0024437   avg weight        4.2562
#
# Epoch: 911
# epoch    911  total error    0.0024579   avg weight        4.2571
#
# Epoch: 912
# epoch    912  total error    0.0024309   avg weight        4.2585
#
# Epoch: 913
# epoch    913  total error    0.0024225   avg weight        4.2597
#
# Epoch: 914
# epoch    914  total error    0.0024061   avg weight        4.2614
#
# Epoch: 915
# epoch    915  total error    0.0024216   avg weight        4.2629
#
# Epoch: 916
# epoch    916  total error    0.0023881   avg weight        4.2627
#
# Epoch: 917
# epoch    917  total error    0.0023932   avg weight        4.2635
#
# Epoch: 918
# epoch    918  total error      0.00237   avg weight        4.2653
#
# Epoch: 919
# epoch    919  total error    0.0023499   avg weight        4.2663
#
# Epoch: 920
# epoch    920  total error    0.0023265   avg weight        4.2673
#
# Epoch: 921
# epoch    921  total error    0.0023033   avg weight        4.2712
#
# Epoch: 922
# epoch    922  total error    0.0023115   avg weight         4.271
#
# Epoch: 923
# epoch    923  total error     0.002259   avg weight        4.2685
#
# Epoch: 924
# epoch    924  total error    0.0022951   avg weight         4.269
#
# Epoch: 925
# epoch    925  total error    0.0022887   avg weight        4.2718
#
# Epoch: 926
# epoch    926  total error    0.0022624   avg weight        4.2708
#
# Epoch: 927
# epoch    927  total error    0.0022584   avg weight        4.2716
#
# Epoch: 928
# epoch    928  total error    0.0022444   avg weight        4.2722
#
# Epoch: 929
# epoch    929  total error    0.0022251   avg weight        4.2733
#
# Epoch: 930
# epoch    930  total error    0.0022116   avg weight        4.2746
#
# Epoch: 931
# epoch    931  total error    0.0021977   avg weight        4.2768
#
# Epoch: 932
# epoch    932  total error    0.0022051   avg weight        4.2789
#
# Epoch: 933
# epoch    933  total error    0.0021588   avg weight        4.2811
#
# Epoch: 934
# epoch    934  total error    0.0021759   avg weight        4.2826
#
# Epoch: 935
# epoch    935  total error     0.002179   avg weight         4.282
#
# Epoch: 936
# epoch    936  total error    0.0021594   avg weight        4.2841
#
# Epoch: 937
# epoch    937  total error    0.0021625   avg weight        4.2863
#
# Epoch: 938
# epoch    938  total error    0.0021432   avg weight        4.2887
#
# Epoch: 939
# epoch    939  total error     0.002131   avg weight          4.29
#
# Epoch: 940
# epoch    940  total error    0.0021166   avg weight        4.2935
#
# Epoch: 941
# epoch    941  total error    0.0021094   avg weight        4.2962
#
# Epoch: 942
# epoch    942  total error    0.0020864   avg weight        4.2962
#
# Epoch: 943
# epoch    943  total error    0.0020992   avg weight        4.2964
#
# Epoch: 944
# epoch    944  total error    0.0020627   avg weight        4.2977
#
# Epoch: 945
# epoch    945  total error    0.0020739   avg weight        4.2972
#
# Epoch: 946
# epoch    946  total error    0.0020712   avg weight        4.2984
#
# Epoch: 947
# epoch    947  total error    0.0020542   avg weight        4.2996
#
# Epoch: 948
# epoch    948  total error    0.0020617   avg weight        4.3002
#
# Epoch: 949
# epoch    949  total error    0.0020367   avg weight        4.3019
#
# Epoch: 950
# epoch    950  total error    0.0020278   avg weight        4.3028
#
# Epoch: 951
# epoch    951  total error    0.0020131   avg weight        4.3043
#
# Epoch: 952
# epoch    952  total error    0.0019927   avg weight        4.3069
#
# Epoch: 953
# epoch    953  total error    0.0019725   avg weight        4.3099
#
# Epoch: 954
# epoch    954  total error    0.0019554   avg weight        4.3083
#
# Epoch: 955
# epoch    955  total error    0.0019248   avg weight        4.3101
#
# Epoch: 956
# epoch    956  total error    0.0019391   avg weight        4.3119
#
# Epoch: 957
# epoch    957  total error    0.0019245   avg weight        4.3127
#
# Epoch: 958
# epoch    958  total error      0.00192   avg weight        4.3111
#
# Epoch: 959
# epoch    959  total error    0.0019104   avg weight        4.3121
#
# Epoch: 960
# epoch    960  total error    0.0019136   avg weight        4.3117
#
# Epoch: 961
# epoch    961  total error    0.0018946   avg weight        4.3123
#
# Epoch: 962
# epoch    962  total error    0.0018934   avg weight        4.3131
#
# Epoch: 963
# epoch    963  total error     0.001882   avg weight        4.3143
#
# Epoch: 964
# epoch    964  total error    0.0018737   avg weight        4.3163
#
# Epoch: 965
# epoch    965  total error    0.0018554   avg weight        4.3174
#
# Epoch: 966
# epoch    966  total error    0.0018602   avg weight        4.3176
#
# Epoch: 967
# epoch    967  total error    0.0018427   avg weight        4.3186
#
# Epoch: 968
# epoch    968  total error    0.0018451   avg weight        4.3197
#
# Epoch: 969
# epoch    969  total error    0.0018447   avg weight        4.3205
#
# Epoch: 970
# epoch    970  total error    0.0018199   avg weight        4.3219
#
# Epoch: 971
# epoch    971  total error    0.0018186   avg weight        4.3233
#
# Epoch: 972
# epoch    972  total error    0.0018059   avg weight        4.3251
#
# Epoch: 973
# epoch    973  total error    0.0017954   avg weight        4.3248
#
# Epoch: 974
# epoch    974  total error    0.0017792   avg weight        4.3269
#
# Epoch: 975
# epoch    975  total error    0.0017629   avg weight        4.3266
#
# Epoch: 976
# epoch    976  total error     0.001748   avg weight        4.3275
#
# Epoch: 977
# epoch    977  total error    0.0017243   avg weight         4.328
#
# Epoch: 978
# epoch    978  total error    0.0017076   avg weight        4.3296
#
# Epoch: 979
# epoch    979  total error    0.0017271   avg weight        4.3299
#
# Epoch: 980
# epoch    980  total error    0.0016918   avg weight        4.3303
#
# Epoch: 981
# epoch    981  total error    0.0017555   avg weight        4.3308
#
# Epoch: 982
# epoch    982  total error    0.0016783   avg weight        4.3314
#
# Epoch: 983
# epoch    983  total error    0.0017143   avg weight        4.3324
#
# Epoch: 984
# epoch    984  total error    0.0016762   avg weight        4.3332
#
# Epoch: 985
# epoch    985  total error    0.0016843   avg weight        4.3346
#
# Epoch: 986
# epoch    986  total error    0.0016741   avg weight        4.3355
#
# Epoch: 987
# epoch    987  total error    0.0016647   avg weight        4.3371
#
# Epoch: 988
# epoch    988  total error    0.0016546   avg weight        4.3393
#
# Epoch: 989
# epoch    989  total error    0.0016483   avg weight        4.3389
#
# Epoch: 990
# epoch    990  total error    0.0016342   avg weight          4.34
#
# Epoch: 991
# epoch    991  total error     0.001625   avg weight        4.3423
#
# Epoch: 992
# epoch    992  total error    0.0016057   avg weight        4.3443
#
# Epoch: 993
# epoch    993  total error    0.0016059   avg weight        4.3471
#
# Epoch: 994
# epoch    994  total error    0.0016076   avg weight        4.3489
#
# Epoch: 995
# epoch    995  total error    0.0015954   avg weight        4.3483
#
# Epoch: 996
# epoch    996  total error    0.0015813   avg weight        4.3492
#
# Epoch: 997
# epoch    997  total error    0.0015755   avg weight        4.3508
#
# Epoch: 998
# epoch    998  total error    0.0015621   avg weight        4.3517
#
# Epoch: 999
# epoch    999  total error    0.0015502   avg weight        4.3538

# %%
x=[i for i in range(len(error))]
plt.plot(x, error)
plt.show()

# %%
y_pred_train = [rnn.activate(point).argmax() for point in traindata['input']]
y_actual_train =[int(output[0]) for output in traindata['class']]

# %%
from sklearn.metrics import precision_recall_fscore_support
precision, recall, f1_score, _ = precision_recall_fscore_support(y_actual_train, y_pred_train, labels=[0,1,2])
print "Precision = "+str(precision)+"\nRecall = "+str(recall)+"\nF1 Score = "+str(f1_score)
# Out:
# Precision = [ 0.99224806  1.          0.99107143]
# Recall = [ 0.99224806  1.          0.99107143]
# F1 Score = [ 0.99224806  1.          0.99107143]

# %%
y_pred_test = [rnn.activate(point).argmax() for point in testdata['input']]
y_actual_test = [int(output[0]) for output in testdata['class']]

# %%
from sklearn.metrics import precision_recall_fscore_support
precision, recall, f1_score, _ = precision_recall_fscore_support(y_actual_test, y_pred_test, labels=[0,1,2])
print "Precision = "+str(precision)+"\nRecall = "+str(recall)+"\nF1 Score = "+str(f1_score)
# Out:
# Precision = [ 0.43589744  0.38888889  0.34285714]
# Recall = [ 0.37777778  0.51219512  0.28571429]
# F1 Score = [ 0.4047619   0.44210526  0.31168831]

# %%
y_pred_test = [rnn.activate(point).argmax() for point in inp[int(3/4*len(inp)):]]
y_actual_test = [lab_to_int[output] for output in lab[int(3/4*len(inp)):]]

# %%
from sklearn.metrics import precision_recall_fscore_support
precision, recall, f1_score, _ = precision_recall_fscore_support(y_actual_test, y_pred_test, labels=[0,1,2])
print "Precision = "+str(precision)+"\nRecall = "+str(recall)+"\nF1 Score = "+str(f1_score)
# Out:
# Precision = [ 0.86666667  0.82258065  0.86486486]
# Recall = [ 0.8125      0.91071429  0.7804878 ]
# F1 Score = [ 0.83870968  0.86440678  0.82051282]

# %%
import feature_extractor
import scipy.io.wavfile as wav
import math

extractor = feature_extractor.FeatureExtractor()

file_name = raw_input("Enter the name of the call file name.\n> ")
rate_sig, sig = wav.read(file_name)

plt.plot(sig)
plt.plot((0,len(sig)),(0,0),'g')
plt.show()

complete_call_result = int_to_lab[rnn.activate(extractor.extract_features(audio_signal = (rate_sig, sig))).argmax()]
first_half_result = int_to_lab[rnn.activate(extractor.extract_features(audio_signal = (rate_sig, sig[:int(len(sig)/2)]))).argmax()]
second_half_result = int_to_lab[rnn.activate(extractor.extract_features(audio_signal = (rate_sig, sig[int(len(sig)/2):]))).argmax()]
segment_result = []
for i in range(int(math.ceil(len(sig)/(rate_sig*20)))):
    segment_result.append(int_to_lab[rnn.activate(extractor.extract_features(audio_signal = (rate_sig, sig[i*rate_sig*20:i*rate_sig*20+rate_sig*20]))).argmax()])
# Out:
# Enter the name of the call file name.
# > negative_15.wav

# %%
import numpy as np
from __future__ import division
print "Overall call result: "+complete_call_result
print "Trainsition: "+first_half_result+" --> "+second_half_result
map_dict = {'negative':-1, 'neutral':0, 'positive':1}
mapped_segment_result = [map_dict[result] for result in segment_result]
index = [i for i in range(len(mapped_segment_result))]
index = np.asarray(index)
bar_width = 1
plt.plot((0,index[-1]+1),((0,0)), 'r')
plt.bar(index, mapped_segment_result, bar_width)
plt.xticks(index + bar_width/2 , (str(i*20)+'-'+str((i+1)*20) for i in index))
plt.xlabel('Time series with 20 seconds chunk')
#plt.axes([0, 100, -2, 2])
plt.ylabel('Emotion:\n1 = positive\n0 = neutral\n-1 = negative')
plt.title('Emotion per 20 second segment')
plt.show()
# Out:
# Overall call result: positive
# Trainsition: positive --> positive

# %%
def plot_confusion_matrix(cm, title='Confusion matrix', cmap=plt.cm.Blues):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(cm))
    plt.xticks(tick_marks, ['neutral','positive','negative'], rotation=45)
    plt.yticks(tick_marks, ['neutral','positive','negative'])
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_actual_train, y_pred_train, labels=[0,1,2])
print cm
plot_confusion_matrix(cm)
# Out:
# [[128   0   1]
#  [  0 144   0]
#  [  1   0 111]]

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_actual_test, y_pred_test, labels=[0,1,2])
print cm
plot_confusion_matrix(cm)
# Out:
# [[26  5  1]
#  [ 1 51  4]
#  [ 3  6 32]]

# %%
len([1 for i in range(len(y_pred_test)) if y_pred_test[i]==y_actual_test[i]])/float(len(y_pred_test))
# Out:
# 0.390625

# %%
lab[1]
# Out:
# 'positive'
