# %% [markdown]
# # This part is basically for testing the various classifers and program formulation

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import emotion_analysis

# %%
Emotion = emotion_analysis.EmotionAnalysis()

# %%
inp, lab = Emotion.prepare_dataset('data')
# Out:
# Read audio file 'data\negative_1.wav', count: 1
# ['negative', '1.wav']
# Read audio file 'data\negative_104.wav', count: 2
# ['negative', '104.wav']
# Read audio file 'data\negative_110.wav', count: 3
# ['negative', '110.wav']
# Read audio file 'data\negative_114.wav', count: 4
# ['negative', '114.wav']
# Read audio file 'data\negative_115.wav', count: 5
# ['negative', '115.wav']
# Read audio file 'data\negative_118.wav', count: 6
# ['negative', '118.wav']
# Read audio file 'data\negative_12.wav', count: 7
# ['negative', '12.wav']
# Read audio file 'data\negative_121.wav', count: 8
# ['negative', '121.wav']
# Read audio file 'data\negative_123.wav', count: 9
# ['negative', '123.wav']
# Read audio file 'data\negative_131.wav', count: 10
# ['negative', '131.wav']
# Read audio file 'data\negative_139.wav', count: 11
# ['negative', '139.wav']
# Read audio file 'data\negative_140.wav', count: 12
# ['negative', '140.wav']
# Read audio file 'data\negative_141.wav', count: 13
# ['negative', '141.wav']
# Read audio file 'data\negative_142.wav', count: 14
# ['negative', '142.wav']
# Read audio file 'data\negative_143.wav', count: 15
# ['negative', '143.wav']
# Read audio file 'data\negative_145.wav', count: 16
# ['negative', '145.wav']
# Read audio file 'data\negative_146.wav', count: 17
# ['negative', '146.wav']
# Read audio file 'data\negative_148.wav', count: 18
# ['negative', '148.wav']
# Read audio file 'data\negative_149.wav', count: 19
# ['negative', '149.wav']
# Read audio file 'data\negative_15.wav', count: 20
# ['negative', '15.wav']
# Read audio file 'data\negative_151.wav', count: 21
# ['negative', '151.wav']
# Read audio file 'data\negative_166.wav', count: 22
# ['negative', '166.wav']
# Read audio file 'data\negative_167.wav', count: 23
# ['negative', '167.wav']
# Read audio file 'data\negative_170.wav', count: 24
# ['negative', '170.wav']
# Read audio file 'data\negative_178.wav', count: 25
# ['negative', '178.wav']
# Read audio file 'data\negative_179.wav', count: 26
# ['negative', '179.wav']
# Read audio file 'data\negative_181.wav', count: 27
# ['negative', '181.wav']
# Read audio file 'data\negative_183.wav', count: 28
# ['negative', '183.wav']
# Read audio file 'data\negative_185.wav', count: 29
# ['negative', '185.wav']
# Read audio file 'data\negative_189.wav', count: 30
# ['negative', '189.wav']
# Read audio file 'data\negative_19.wav', count: 31
# ['negative', '19.wav']
# Read audio file 'data\negative_190.wav', count: 32
# ['negative', '190.wav']
# Read audio file 'data\negative_195.wav', count: 33
# ['negative', '195.wav']
# Read audio file 'data\negative_20.wav', count: 34
# ['negative', '20.wav']
# Read audio file 'data\negative_202.wav', count: 35
# ['negative', '202.wav']
# Read audio file 'data\negative_207.wav', count: 36
# ['negative', '207.wav']
# Read audio file 'data\negative_21.wav', count: 37
# ['negative', '21.wav']
# Read audio file 'data\negative_214.wav', count: 38
# ['negative', '214.wav']
# Read audio file 'data\negative_217.wav', count: 39
# ['negative', '217.wav']
# Read audio file 'data\negative_219.wav', count: 40
# ['negative', '219.wav']
# Read audio file 'data\negative_225.wav', count: 41
# ['negative', '225.wav']
# Read audio file 'data\negative_230.wav', count: 42
# ['negative', '230.wav']
# Read audio file 'data\negative_238.wav', count: 43
# ['negative', '238.wav']
# Read audio file 'data\negative_241.wav', count: 44
# ['negative', '241.wav']
# Read audio file 'data\negative_242.wav', count: 45
# ['negative', '242.wav']
# Read audio file 'data\negative_247.wav', count: 46
# ['negative', '247.wav']
# Read audio file 'data\negative_248.wav', count: 47
# ['negative', '248.wav']
# Read audio file 'data\negative_250.wav', count: 48
# ['negative', '250.wav']
# Read audio file 'data\negative_256.wav', count: 49
# ['negative', '256.wav']
# Read audio file 'data\negative_257.wav', count: 50
# ['negative', '257.wav']
# Read audio file 'data\negative_258.wav', count: 51
# ['negative', '258.wav']
# Read audio file 'data\negative_270.wav', count: 52
# ['negative', '270.wav']
# Read audio file 'data\negative_272.wav', count: 53
# ['negative', '272.wav']
# Read audio file 'data\negative_273.wav', count: 54
# ['negative', '273.wav']
# Read audio file 'data\negative_279.wav', count: 55
# ['negative', '279.wav']
# Read audio file 'data\negative_28.wav', count: 56
# ['negative', '28.wav']
# Read audio file 'data\negative_281.wav', count: 57
# ['negative', '281.wav']
# Read audio file 'data\negative_282.wav', count: 58
# ['negative', '282.wav']
# Read audio file 'data\negative_283.wav', count: 59
# ['negative', '283.wav']
# Read audio file 'data\negative_284.wav', count: 60
# ['negative', '284.wav']
# Read audio file 'data\negative_285.wav', count: 61
# ['negative', '285.wav']
# Read audio file 'data\negative_288.wav', count: 62
# ['negative', '288.wav']
# Read audio file 'data\negative_289.wav', count: 63
# ['negative', '289.wav']
# Read audio file 'data\negative_29.wav', count: 64
# ['negative', '29.wav']
# Read audio file 'data\negative_291.wav', count: 65
# ['negative', '291.wav']
# Read audio file 'data\negative_292.wav', count: 66
# ['negative', '292.wav']
# Read audio file 'data\negative_294.wav', count: 67
# ['negative', '294.wav']
# Read audio file 'data\negative_295.wav', count: 68
# ['negative', '295.wav']
# Read audio file 'data\negative_296.wav', count: 69
# ['negative', '296.wav']
# Read audio file 'data\negative_297.wav', count: 70
# ['negative', '297.wav']
# Read audio file 'data\negative_298.wav', count: 71
# ['negative', '298.wav']
# Read audio file 'data\negative_299.wav', count: 72
# ['negative', '299.wav']
# Read audio file 'data\negative_30.wav', count: 73
# ['negative', '30.wav']
# Read audio file 'data\negative_301.wav', count: 74
# ['negative', '301.wav']
# Read audio file 'data\negative_307.wav', count: 75
# ['negative', '307.wav']
# Read audio file 'data\negative_308.wav', count: 76
# ['negative', '308.wav']
# Read audio file 'data\negative_31.wav', count: 77
# ['negative', '31.wav']
# Read audio file 'data\negative_311.wav', count: 78
# ['negative', '311.wav']
# Read audio file 'data\negative_316.wav', count: 79
# ['negative', '316.wav']
# Read audio file 'data\negative_320.wav', count: 80
# ['negative', '320.wav']
# Read audio file 'data\negative_326.wav', count: 81
# ['negative', '326.wav']
# Read audio file 'data\negative_328.wav', count: 82
# ['negative', '328.wav']
# Read audio file 'data\negative_333.wav', count: 83
# ['negative', '333.wav']
# Read audio file 'data\negative_334.wav', count: 84
# ['negative', '334.wav']
# Read audio file 'data\negative_335.wav', count: 85
# ['negative', '335.wav']
# Read audio file 'data\negative_338.wav', count: 86
# ['negative', '338.wav']
# Read audio file 'data\negative_356.wav', count: 87
# ['negative', '356.wav']
# Read audio file 'data\negative_357.wav', count: 88
# ['negative', '357.wav']
# Read audio file 'data\negative_367.wav', count: 89
# ['negative', '367.wav']
# Read audio file 'data\negative_368.wav', count: 90
# ['negative', '368.wav']
# Read audio file 'data\negative_37.wav', count: 91
# ['negative', '37.wav']
# Read audio file 'data\negative_371.wav', count: 92
# ['negative', '371.wav']
# Read audio file 'data\negative_372.wav', count: 93
# ['negative', '372.wav']
# Read audio file 'data\negative_373.wav', count: 94
# ['negative', '373.wav']
# Read audio file 'data\negative_374.wav', count: 95
# ['negative', '374.wav']
# Read audio file 'data\negative_376.wav', count: 96
# ['negative', '376.wav']
# Read audio file 'data\negative_377.wav', count: 97
# ['negative', '377.wav']
# Read audio file 'data\negative_378.wav', count: 98
# ['negative', '378.wav']
# Read audio file 'data\negative_379.wav', count: 99
# ['negative', '379.wav']
# Read audio file 'data\negative_38.wav', count: 100
# ['negative', '38.wav']
# Read audio file 'data\negative_384.wav', count: 101
# ['negative', '384.wav']
# Read audio file 'data\negative_385.wav', count: 102
# ['negative', '385.wav']
# Read audio file 'data\negative_386.wav', count: 103
# ['negative', '386.wav']
# Read audio file 'data\negative_396.wav', count: 104
# ['negative', '396.wav']
# Read audio file 'data\negative_4.wav', count: 105
# ['negative', '4.wav']
# Read audio file 'data\negative_424.wav', count: 106
# ['negative', '424.wav']
# Read audio file 'data\negative_426.wav', count: 107
# ['negative', '426.wav']
# Read audio file 'data\negative_429.wav', count: 108
# ['negative', '429.wav']
# Read audio file 'data\negative_436.wav', count: 109
# ['negative', '436.wav']
# Read audio file 'data\negative_437.wav', count: 110
# ['negative', '437.wav']
# Read audio file 'data\negative_438.wav', count: 111
# ['negative', '438.wav']
# Read audio file 'data\negative_439.wav', count: 112
# ['negative', '439.wav']
# Read audio file 'data\negative_441.wav', count: 113
# ['negative', '441.wav']
# Read audio file 'data\negative_442.wav', count: 114
# ['negative', '442.wav']
# Read audio file 'data\negative_443.wav', count: 115
# ['negative', '443.wav']
# Read audio file 'data\negative_444.wav', count: 116
# ['negative', '444.wav']
# Read audio file 'data\negative_446.wav', count: 117
# ['negative', '446.wav']
# Read audio file 'data\negative_450.wav', count: 118
# ['negative', '450.wav']
# Read audio file 'data\negative_451.wav', count: 119
# ['negative', '451.wav']
# Read audio file 'data\negative_452.wav', count: 120
# ['negative', '452.wav']
# Read audio file 'data\negative_460.wav', count: 121
# ['negative', '460.wav']
# Read audio file 'data\negative_462.wav', count: 122
# ['negative', '462.wav']
# Read audio file 'data\negative_464.wav', count: 123
# ['negative', '464.wav']
# Read audio file 'data\negative_468.wav', count: 124
# ['negative', '468.wav']
# Read audio file 'data\negative_469.wav', count: 125
# ['negative', '469.wav']
# Read audio file 'data\negative_473.wav', count: 126
# ['negative', '473.wav']
# Read audio file 'data\negative_474.wav', count: 127
# ['negative', '474.wav']
# Read audio file 'data\negative_487.wav', count: 128
# ['negative', '487.wav']
# Read audio file 'data\negative_49.wav', count: 129
# ['negative', '49.wav']
# Read audio file 'data\negative_498.wav', count: 130
# ['negative', '498.wav']
# Read audio file 'data\negative_506.wav', count: 131
# ['negative', '506.wav']
# Read audio file 'data\negative_51.wav', count: 132
# ['negative', '51.wav']
# Read audio file 'data\negative_520.wav', count: 133
# ['negative', '520.wav']
# Read audio file 'data\negative_522.wav', count: 134
# ['negative', '522.wav']
# Read audio file 'data\negative_53.wav', count: 135
# ['negative', '53.wav']
# Read audio file 'data\negative_65.wav', count: 136
# ['negative', '65.wav']
# Read audio file 'data\negative_69.wav', count: 137
# ['negative', '69.wav']
# Read audio file 'data\negative_70.wav', count: 138
# ['negative', '70.wav']
# Read audio file 'data\negative_74.wav', count: 139
# ['negative', '74.wav']
# Read audio file 'data\negative_75.wav', count: 140
# ['negative', '75.wav']
# Read audio file 'data\negative_77.wav', count: 141
# ['negative', '77.wav']
# Read audio file 'data\negative_78.wav', count: 142
# ['negative', '78.wav']
# Read audio file 'data\negative_79.wav', count: 143
# ['negative', '79.wav']
# Read audio file 'data\negative_8.wav', count: 144
# ['negative', '8.wav']
# Read audio file 'data\negative_81.wav', count: 145
# ['negative', '81.wav']
# Read audio file 'data\negative_82.wav', count: 146
# ['negative', '82.wav']
# Read audio file 'data\negative_83.wav', count: 147
# ['negative', '83.wav']
# Read audio file 'data\negative_84.wav', count: 148
# ['negative', '84.wav']
# Read audio file 'data\negative_86.wav', count: 149
# ['negative', '86.wav']
# Read audio file 'data\negative_87.wav', count: 150
# ['negative', '87.wav']
# Read audio file 'data\negative_88.wav', count: 151
# ['negative', '88.wav']
# Read audio file 'data\negative_89.wav', count: 152
# ['negative', '89.wav']
# Read audio file 'data\negative_92.wav', count: 153
# ['negative', '92.wav']
# Read audio file 'data\negative_96.wav', count: 154
# ['negative', '96.wav']
# Read audio file 'data\neutral_10.wav', count: 155
# ['neutral', '10.wav']
# Read audio file 'data\neutral_102.wav', count: 156
# ['neutral', '102.wav']
# Read audio file 'data\neutral_103.wav', count: 157
# ['neutral', '103.wav']
# Read audio file 'data\neutral_108.wav', count: 158
# ['neutral', '108.wav']
# Read audio file 'data\neutral_11.wav', count: 159
# ['neutral', '11.wav']
# Read audio file 'data\neutral_111.wav', count: 160
# ['neutral', '111.wav']
# Read audio file 'data\neutral_112.wav', count: 161
# ['neutral', '112.wav']
# Read audio file 'data\neutral_113.wav', count: 162
# ['neutral', '113.wav']
# Read audio file 'data\neutral_117.wav', count: 163
# ['neutral', '117.wav']
# Read audio file 'data\neutral_124.wav', count: 164
# ['neutral', '124.wav']
# Read audio file 'data\neutral_125.wav', count: 165
# ['neutral', '125.wav']
# Read audio file 'data\neutral_126.wav', count: 166
# ['neutral', '126.wav']
# Read audio file 'data\neutral_127.wav', count: 167
# ['neutral', '127.wav']
# Read audio file 'data\neutral_128.wav', count: 168
# ['neutral', '128.wav']
# Read audio file 'data\neutral_129.wav', count: 169
# ['neutral', '129.wav']
# Read audio file 'data\neutral_137.wav', count: 170
# ['neutral', '137.wav']
# Read audio file 'data\neutral_150.wav', count: 171
# ['neutral', '150.wav']
# Read audio file 'data\neutral_152.wav', count: 172
# ['neutral', '152.wav']
# Read audio file 'data\neutral_153.wav', count: 173
# ['neutral', '153.wav']
# Read audio file 'data\neutral_154.wav', count: 174
# ['neutral', '154.wav']
# Read audio file 'data\neutral_16.wav', count: 175
# ['neutral', '16.wav']
# Read audio file 'data\neutral_160.wav', count: 176
# ['neutral', '160.wav']
# Read audio file 'data\neutral_161.wav', count: 177
# ['neutral', '161.wav']
# Read audio file 'data\neutral_162.wav', count: 178
# ['neutral', '162.wav']
# Read audio file 'data\neutral_168.wav', count: 179
# ['neutral', '168.wav']
# Read audio file 'data\neutral_171.wav', count: 180
# ['neutral', '171.wav']
# Read audio file 'data\neutral_177.wav', count: 181
# ['neutral', '177.wav']
# Read audio file 'data\neutral_18.wav', count: 182
# ['neutral', '18.wav']
# Read audio file 'data\neutral_180.wav', count: 183
# ['neutral', '180.wav']
# Read audio file 'data\neutral_182.wav', count: 184
# ['neutral', '182.wav']
# Read audio file 'data\neutral_184.wav', count: 185
# ['neutral', '184.wav']
# Read audio file 'data\neutral_186.wav', count: 186
# ['neutral', '186.wav']
# Read audio file 'data\neutral_192.wav', count: 187
# ['neutral', '192.wav']
# Read audio file 'data\neutral_193.wav', count: 188
# ['neutral', '193.wav']
# Read audio file 'data\neutral_196.wav', count: 189
# ['neutral', '196.wav']
# Read audio file 'data\neutral_199.wav', count: 190
# ['neutral', '199.wav']
# Read audio file 'data\neutral_2.wav', count: 191
# ['neutral', '2.wav']
# Read audio file 'data\neutral_201.wav', count: 192
# ['neutral', '201.wav']
# Read audio file 'data\neutral_203.wav', count: 193
# ['neutral', '203.wav']
# Read audio file 'data\neutral_204.wav', count: 194
# ['neutral', '204.wav']
# Read audio file 'data\neutral_208.wav', count: 195
# ['neutral', '208.wav']
# Read audio file 'data\neutral_209.wav', count: 196
# ['neutral', '209.wav']
# Read audio file 'data\neutral_210.wav', count: 197
# ['neutral', '210.wav']
# Read audio file 'data\neutral_211.wav', count: 198
# ['neutral', '211.wav']
# Read audio file 'data\neutral_213.wav', count: 199
# ['neutral', '213.wav']
# Read audio file 'data\neutral_221.wav', count: 200
# ['neutral', '221.wav']
# Read audio file 'data\neutral_222.wav', count: 201
# ['neutral', '222.wav']
# Read audio file 'data\neutral_227.wav', count: 202
# ['neutral', '227.wav']
# Read audio file 'data\neutral_228.wav', count: 203
# ['neutral', '228.wav']
# Read audio file 'data\neutral_229.wav', count: 204
# ['neutral', '229.wav']
# Read audio file 'data\neutral_23.wav', count: 205
# ['neutral', '23.wav']
# Read audio file 'data\neutral_336.wav', count: 246
# ['neutral', '336.wav']
# Read audio file 'data\neutral_346.wav', count: 247
# ['neutral', '346.wav']
# Read audio file 'data\neutral_348.wav', count: 248
# ['neutral', '348.wav']
# Read audio file 'data\neutral_349.wav', count: 249
# ['neutral', '349.wav']
# Read audio file 'data\neutral_350.wav', count: 250
# ['neutral', '350.wav']
# Read audio file 'data\neutral_354.wav', count: 251
# ['neutral', '354.wav']
# Read audio file 'data\neutral_355.wav', count: 252
# ['neutral', '355.wav']
# Read audio file 'data\neutral_358.wav', count: 253
# ['neutral', '358.wav']
# Read audio file 'data\neutral_360.wav', count: 254
# ['neutral', '360.wav']
# Read audio file 'data\neutral_361.wav', count: 255
# ['neutral', '361.wav']
# Read audio file 'data\neutral_362.wav', count: 256
# ['neutral', '362.wav']
# Read audio file 'data\neutral_375.wav', count: 257
# ['neutral', '375.wav']
# Read audio file 'data\neutral_380.wav', count: 258
# ['neutral', '380.wav']
# Read audio file 'data\neutral_388.wav', count: 259
# ['neutral', '388.wav']
# Read audio file 'data\neutral_39.wav', count: 260
# ['neutral', '39.wav']
# Read audio file 'data\neutral_393.wav', count: 261
# ['neutral', '393.wav']
# Read audio file 'data\neutral_394.wav', count: 262
# ['neutral', '394.wav']
# Read audio file 'data\neutral_40.wav', count: 263
# ['neutral', '40.wav']
# Read audio file 'data\neutral_407.wav', count: 264
# ['neutral', '407.wav']
# Read audio file 'data\neutral_408.wav', count: 265
# ['neutral', '408.wav']
# Read audio file 'data\neutral_409.wav', count: 266
# ['neutral', '409.wav']
# Read audio file 'data\neutral_41.wav', count: 267
# ['neutral', '41.wav']
# Read audio file 'data\neutral_419.wav', count: 268
# ['neutral', '419.wav']
# Read audio file 'data\neutral_42.wav', count: 269
# ['neutral', '42.wav']
# Read audio file 'data\neutral_420.wav', count: 270
# ['neutral', '420.wav']
# Read audio file 'data\neutral_421.wav', count: 271
# ['neutral', '421.wav']
# Read audio file 'data\neutral_427.wav', count: 272
# ['neutral', '427.wav']
# Read audio file 'data\neutral_428.wav', count: 273
# ['neutral', '428.wav']
# Read audio file 'data\neutral_43.wav', count: 274
# ['neutral', '43.wav']
# Read audio file 'data\neutral_431.wav', count: 275
# ['neutral', '431.wav']
# Read audio file 'data\neutral_432.wav', count: 276
# ['neutral', '432.wav']
# Read audio file 'data\neutral_434.wav', count: 277
# ['neutral', '434.wav']
# Read audio file 'data\neutral_435.wav', count: 278
# ['neutral', '435.wav']
# Read audio file 'data\neutral_440.wav', count: 279
# ['neutral', '440.wav']
# Read audio file 'data\neutral_445.wav', count: 280
# ['neutral', '445.wav']
# Read audio file 'data\neutral_447.wav', count: 281
# ['neutral', '447.wav']
# Read audio file 'data\neutral_448.wav', count: 282
# ['neutral', '448.wav']
# Read audio file 'data\neutral_449.wav', count: 283
# ['neutral', '449.wav']
# Read audio file 'data\neutral_453.wav', count: 284
# ['neutral', '453.wav']
# Read audio file 'data\neutral_454.wav', count: 285
# ['neutral', '454.wav']
# Read audio file 'data\neutral_457.wav', count: 286
# ['neutral', '457.wav']
# Read audio file 'data\neutral_458.wav', count: 287
# ['neutral', '458.wav']
# Read audio file 'data\neutral_459.wav', count: 288
# ['neutral', '459.wav']
# Read audio file 'data\neutral_461.wav', count: 289
# ['neutral', '461.wav']
# Read audio file 'data\neutral_463.wav', count: 290
# ['neutral', '463.wav']
# Read audio file 'data\neutral_465.wav', count: 291
# ['neutral', '465.wav']
# Read audio file 'data\neutral_466.wav', count: 292
# ['neutral', '466.wav']
# Read audio file 'data\neutral_47.wav', count: 293
# ['neutral', '47.wav']
# Read audio file 'data\neutral_470.wav', count: 294
# ['neutral', '470.wav']
# Read audio file 'data\neutral_471.wav', count: 295
# ['neutral', '471.wav']
# Read audio file 'data\neutral_472.wav', count: 296
# ['neutral', '472.wav']
# Read audio file 'data\neutral_48.wav', count: 297
# ['neutral', '48.wav']
# Read audio file 'data\neutral_488.wav', count: 298
# ['neutral', '488.wav']
# Read audio file 'data\neutral_489.wav', count: 299
# ['neutral', '489.wav']
# Read audio file 'data\neutral_490.wav', count: 300
# ['neutral', '490.wav']
# Read audio file 'data\neutral_491.wav', count: 301
# ['neutral', '491.wav']
# Read audio file 'data\neutral_492.wav', count: 302
# ['neutral', '492.wav']
# Read audio file 'data\neutral_493.wav', count: 303
# ['neutral', '493.wav']
# Read audio file 'data\neutral_494.wav', count: 304
# ['neutral', '494.wav']
# Read audio file 'data\neutral_495.wav', count: 305
# ['neutral', '495.wav']
# Read audio file 'data\neutral_496.wav', count: 306
# ['neutral', '496.wav']
# Read audio file 'data\neutral_497.wav', count: 307
# ['neutral', '497.wav']
# Read audio file 'data\neutral_5.wav', count: 308
# ['neutral', '5.wav']
# Read audio file 'data\neutral_50.wav', count: 309
# ['neutral', '50.wav']
# Read audio file 'data\neutral_501.wav', count: 310
# ['neutral', '501.wav']
# Read audio file 'data\neutral_507.wav', count: 311
# ['neutral', '507.wav']
# Read audio file 'data\neutral_512.wav', count: 312
# ['neutral', '512.wav']
# Read audio file 'data\neutral_518.wav', count: 313
# ['neutral', '518.wav']
# Read audio file 'data\neutral_52.wav', count: 314
# ['neutral', '52.wav']
# Read audio file 'data\neutral_58.wav', count: 315
# ['neutral', '58.wav']
# Read audio file 'data\neutral_59.wav', count: 316
# ['neutral', '59.wav']
# Read audio file 'data\neutral_60.wav', count: 317
# ['neutral', '60.wav']
# Read audio file 'data\neutral_63.wav', count: 318
# ['neutral', '63.wav']
# Read audio file 'data\neutral_64.wav', count: 319
# ['neutral', '64.wav']
# Read audio file 'data\neutral_67.wav', count: 320
# ['neutral', '67.wav']
# Read audio file 'data\neutral_73.wav', count: 321
# ['neutral', '73.wav']
# Read audio file 'data\neutral_80.wav', count: 322
# ['neutral', '80.wav']
# Read audio file 'data\neutral_85.wav', count: 323
# ['neutral', '85.wav']
# Read audio file 'data\neutral_9.wav', count: 324
# ['neutral', '9.wav']
# Read audio file 'data\neutral_90.wav', count: 325
# Read audio file 'data\positive_514.wav', count: 494
# ['positive', '514.wav']
# Read audio file 'data\positive_515.wav', count: 495
# ['positive', '515.wav']
# Read audio file 'data\positive_516.wav', count: 496
# ['positive', '516.wav']
# Read audio file 'data\positive_517.wav', count: 497
# ['positive', '517.wav']
# Read audio file 'data\positive_519.wav', count: 498
# ['positive', '519.wav']
# Read audio file 'data\positive_54.wav', count: 499
# ['positive', '54.wav']
# Read audio file 'data\positive_55.wav', count: 500
# ['positive', '55.wav']
# Read audio file 'data\positive_56.wav', count: 501
# ['positive', '56.wav']
# Read audio file 'data\positive_57.wav', count: 502
# ['positive', '57.wav']
# Read audio file 'data\positive_6.wav', count: 503
# ['positive', '6.wav']
# Read audio file 'data\positive_61.wav', count: 504
# ['positive', '61.wav']
# Read audio file 'data\positive_62.wav', count: 505
# ['positive', '62.wav']
# Read audio file 'data\positive_66.wav', count: 506
# ['positive', '66.wav']
# Read audio file 'data\positive_68.wav', count: 507
# ['positive', '68.wav']
# Read audio file 'data\positive_7.wav', count: 508
# ['positive', '7.wav']
# Read audio file 'data\positive_71.wav', count: 509
# ['positive', '71.wav']
# Read audio file 'data\positive_76.wav', count: 510
# ['positive', '76.wav']
# Read audio file 'data\positive_94.wav', count: 511
# ['positive', '94.wav']
# Read audio file 'data\positive_97.wav', count: 512
# ['positive', '97.wav']
# Read audio file 'data\positive_99.wav', count: 513
# ['positive', '99.wav']

# %%
from random import shuffle
import numpy as np
dataset = zip(inp, lab)
shuffle(dataset)
inp, lab = zip(*dataset)
#max_value = max([max(i) for i in inp])
#normalised_inp = np.asarray(inp)/max_value
#inp = np.asarray(inp)/max_value

# %%
Emotion.write_to_csv(inp, lab, 'dataset.csv')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-1a7f4aaa32ca> in <module>()
# ----> 1 Emotion.write_to_csv(inp, lab, 'dataset.csv')
#
# D:\Projects\Emotion_Analysis\EmotionAnalyser\emotion_analysis.py in write_to_csv(self, inp, label, name)
#      14                 writer = csv.writer(csvfile, delimiter=',')
#      15                 for i in range(len(inp)):
# ---> 16                         row = inp[i]+[label[i]]
#      17                         writer.writerow(row)
#      18                         csvfile.flush()
#
# TypeError: ufunc 'add' did not contain a loop with signature matching types dtype('S32') dtype('S32') dtype('S32')

# %%
# Random Forest : Better performance

from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(n_estimators=100)
clf = clf.fit(inp[0:int(len(inp)*3/float(4))],lab[0:int(len(inp)*3/float(4))])
#clf = clf.fit(inp, lab)

# %%
# KNN classifier : Good performance

#from sklearn.neighbors import KNeighborsClassifier
#clf = KNeighborsClassifier()
#clf = clf.fit(inp[0:int(len(inp)*3/float(4))],lab[0:int(len(inp)*3/float(4))])
#clf = clf.fit(inp, lab)

# %%
# SVM with RBF : Worst performance

#from sklearn import svm
#clf = svm.SVC(kernel = 'rbf')
#clf = clf.fit(inp[0:int(len(inp)*3/float(4))],lab[0:int(len(inp)*3/float(4))])
#clf = clf.fit(inp, lab)

# %%
# Naive Bayes Classifier : Poor performance

#from sklearn.naive_bayes import GaussianNB
#clf = GaussianNB()
#clf = clf.fit(inp[0:int(len(inp)*3/float(4))],lab[0:int(len(inp)*3/float(4))])

# %%
pred_lab = clf.predict(inp[int(len(inp)*3/float(4)):])
act_lab = lab[int(len(inp)*3/float(4)):]
#pred_lab = clf.predict(inp)
#act_lab = lab

# %%
import numpy as np
from __future__ import division
accuracy = np.sum([1 for i in range(len(pred_lab)) if pred_lab[i]==act_lab[i]])/len(pred_lab)
print "Accuracy = "+str(accuracy)
# Out:
# Accuracy = 0.519379844961

# %%
from sklearn.metrics import precision_recall_fscore_support
precision, recall, f1_score, _ = precision_recall_fscore_support(act_lab, pred_lab)
print "Precision = "+str(precision)+"\nRecall = "+str(recall)+"\nF1 Score = "+str(f1_score)
# Out:
# Precision = [ 0.525       0.46875     0.54385965]
# Recall = [ 0.525       0.34090909  0.68888889]
# F1 Score = [ 0.525       0.39473684  0.60784314]

# %%
import collections
print "Actual    = "+str(collections.Counter(act_lab))
print "Predicted = "+str(collections.Counter(pred_lab))
# Out:
# Actual    = Counter({'positive': 45, 'neutral': 44, 'negative': 40})
# Predicted = Counter({'positive': 57, 'negative': 40, 'neutral': 32})

# %%
Emotion.test_classifier(clf, [inp, lab])
# Out:
# [array([ 0.87096774,  0.89440994,  0.8680203 ]),
#  array([ 0.87662338,  0.82758621,  0.92432432]),
#  array([ 0.87378641,  0.85970149,  0.89528796])]

# %%
Emotion.evaluate(clf, 'negative_1.wav')
# Out:
# 'negative'

# %% [markdown]
# ##  The following part can be used to predict emotion for a recorded voice and a new audio file

# %%
#To accept an audio data and predict its emotion
import pyaudio
import wave
import scipy.io.wavfile as wav

FORMAT = pyaudio.paInt16
CHANNELS = 1
RATE = 44100
CHUNK = 1024
RECORD_SECONDS = 20
WAVE_OUTPUT_FILENAME = "file.wav"
 
audio = pyaudio.PyAudio()
 
# start Recording
stream = audio.open(format=FORMAT, channels=CHANNELS,
                rate=RATE, input=True,
                frames_per_buffer=CHUNK)
print "recording..."
frames = []
 
for i in range(0, int(RATE / CHUNK * RECORD_SECONDS)):
    data = stream.read(CHUNK)
    frames.append(data)
print "finished recording"
 
 
# stop Recording
stream.stop_stream()
stream.close()
audio.terminate()
 
waveFile = wave.open(WAVE_OUTPUT_FILENAME, 'wb')
waveFile.setnchannels(CHANNELS)
waveFile.setsampwidth(audio.get_sample_size(FORMAT))
waveFile.setframerate(RATE)
waveFile.writeframes(b''.join(frames))
waveFile.close()

import feature_extractor
Extractor = feature_extractor.FeatureExtractor()
f = Extractor.extract_features('file.wav')

plt.plot(wav.read('file.wav')[1])
plt.show()

clf.predict([f])

# %%
#To read an audio file and predict its emotion 
import feature_extractor
Extractor = feature_extractor.FeatureExtractor()
f = Extractor.extract_features('calls\\9969957664_TaiyubM_2016-01-07-15-11-09.wav')
clf.predict([f])

# %% [markdown]
# ## This part tests the class written.

# %%
#To test the class written
import emotion_analysis
emo = emotion_analysis.EmotionAnalysis()

# %%
inp, lab = emo.prepare_dataset('data')

# %%
clf = emo.train_classifier([inp, lab])

# %%
precision, recall, f1_score = emo.test_classifier(clf, [inp, lab])

# %%
f1_score

# %%
import scipy.io.wavfile as wav
emo.evaluate(clf,  audio_signal = wav.read('file.wav'))

# %% [markdown]
# ## This part is useful for creating custom training dataset, from the recorded Edelweiss sales call.
# It opens each call and plays it into chunks of 20 sec each and then asks me for a label for those 20 sec of call.

# %%
import pyaudio
import scipy.io.wavfile as wav
from __future__ import division
import math
from os import listdir
from os.path import isfile, join

segments = []

path = "calls"
c_total = 0
c_read = 0
c_skipped = 0
audio_files = [f for f in listdir(path) if isfile(join(path, f))]
for audio_file in audio_files:
    c_total+=1
    print "Reading file: "+str(c_total)
    try:
        rate_sig, sig = wav.read(join(path, audio_file))
        c_read+=1
    except:
        c_skipped+=1
        continue
    for i in range(int(math.ceil(len(sig)/(rate_sig*20)))):
        segments.append(sig[i*(rate_sig*20):i*(rate_sig*20) + rate_sig*20])
print "\n\n"
print "Total files: "+str(c_total)
print "Read files: "+str(c_read)
print "Skipped files:"+str(c_skipped)

# %%
FORMAT = pyaudio.paInt16
CHANNELS = 1

map_key_to_emotion = {'1':'negative','2':'neutral', '3':'positive'}

p = pyaudio.PyAudio()  
#open stream  
stream = p.open(format = FORMAT,  
                channels = CHANNELS,  
                rate = rate_sig,  
                output = True)  
#read data
count_label = 0
for segment in segments:
    count_label+=1
    stream.write(segment[0:len(segment)/2])
    stream.write(segment[len(segment)/2:])
    segment_label = map_key_to_emotion[raw_input()]
    
    wav.write("data\\"+segment_label+"_"+str(count_label)+".wav", rate_sig, segment)


#stop stream  
#stream.stop_stream()  
#stream.close()  

#close PyAudio  
#p.terminate()

# %%
rate, data = wav.read('negative_1.wav')
stream.write(data)

# %% [markdown]
# ## This part will perform three things for any call:
# 1. Predict the emotion in the entire call.
# 2. Predict the emotion transition between the first half and the second half of the call.
# 3. Predict the emotion in 20 second segments and plot a histogram of emotions or give the count of emotions.

# %%
import scipy.io.wavfile as wav
import math
file_name = raw_input("Enter the name of the call file name.\n> ")
rate_sig, sig = wav.read(file_name)

plt.plot(sig)
plt.plot((0,len(sig)),(0,0),'g')
plt.show()

complete_call_result = emo.evaluate(clf, audio_signal = (rate_sig, sig))
first_half_result = emo.evaluate(clf, audio_signal = (rate_sig, sig[:int(len(sig)/2)]))
second_half_result = emo.evaluate(clf, audio_signal = (rate_sig, sig[int(len(sig)/2):]))
segment_result = []
for i in range(int(math.ceil(len(sig)/(rate_sig*20)))):
    segment_result.append(emo.evaluate(clf, audio_signal = (rate_sig, sig[i*rate_sig*20:i*rate_sig*20+rate_sig*20])))
# Out:
# Enter the name of the call file name.
# > positive_57.wav

# %%
import numpy as np
from __future__ import division
print "Overall call result: "+complete_call_result
print "Trainsition: "+first_half_result+" --> "+second_half_result
map_dict = {'negative':-1, 'neutral':0, 'positive':1}
mapped_segment_result = [map_dict[result] for result in segment_result]
index = [i for i in range(len(mapped_segment_result))]
index = np.asarray(index)
bar_width = 1
plt.plot((0,index[-1]+1),((0,0)), 'r')
plt.bar(index, mapped_segment_result, bar_width)
plt.xticks(index + bar_width/2 , (str(i*20)+'-'+str((i+1)*20) for i in index))
plt.xlabel('Time series with 20 seconds chunk')
#plt.axes([0, 100, -2, 2])
plt.ylabel('Emotion:\n1 = positive\n0 = neutral\n-1 = negative')
plt.title('Emotion per 20 second segment')
plt.show()
# Out:
# Overall call result: negative
# Trainsition: negative --> negative
