# %%
from __future__ import division 
import matplotlib.pyplot as plt
# %matplotlib inline
import emotion_analysis
emo = emotion_analysis.EmotionAnalysis()

# %%
inp, lab = emo.prepare_dataset_per_frame('tess_data')
# Out:
# Read audio file 'tess_data\OAF_goal_sad.wav.wav', count: 100
# Skipping audio file 'tess_data\YAF_neat_fear.wav.wav'
# Read audio file 'tess_data\YAF_bite_neutral.wav.wav', count: 200
# Read audio file 'tess_data\OAF_cause_disgust.wav.wav', count: 300
# Read audio file 'tess_data\OAF_match_ps.wav.wav', count: 400
# Read audio file 'tess_data\YAF_bone_sad.wav.wav', count: 500
# Read audio file 'tess_data\OAF_white_ps.wav.wav', count: 600
# Read audio file 'tess_data\YAF_read_neutral.wav.wav', count: 700
# Read audio file 'tess_data\YAF_tip_ps.wav.wav', count: 800
# Read audio file 'tess_data\OAF_vote_fear.wav.wav', count: 900
# Read audio file 'tess_data\YAF_lid_fear.wav.wav', count: 1000
# Read audio file 'tess_data\YAF_laud_disgust.wav.wav', count: 1100
# Read audio file 'tess_data\YAF_laud_sad.wav.wav', count: 1200
# Skipping audio file 'tess_data\YAF_germ_angry.wav.wav'
# Read audio file 'tess_data\OAF_kick_angry.wav.wav', count: 1300
# Read audio file 'tess_data\OAF_seize_angry.wav.wav', count: 1400
# Read audio file 'tess_data\OAF_perch_sad.wav.wav', count: 1500
# Read audio file 'tess_data\OAF_hash_ps.wav.wav', count: 1600
# Read audio file 'tess_data\OAF_jug_disgust.wav.wav', count: 1700
# Read audio file 'tess_data\OAF_tell_ps.wav.wav', count: 1800
# Read audio file 'tess_data\OAF_check_fear.wav.wav', count: 1900
# Read audio file 'tess_data\YAF_south_sad.wav.wav', count: 2000
# Read audio file 'tess_data\OAF_kill_disgust.wav.wav', count: 2100
# Read audio file 'tess_data\YAF_third_sad.wav.wav', count: 2200
# Read audio file 'tess_data\YAF_cool_neutral.wav.wav', count: 2300
# Read audio file 'tess_data\YAF_gin_happy.wav.wav', count: 2400
# Read audio file 'tess_data\OAF_pass_fear.wav.wav', count: 2500
# Read audio file 'tess_data\OAF_gas_neutral.wav.wav', count: 2600
# Read audio file 'tess_data\YAF_road_angry.wav.wav', count: 2700

# %%
from collections import Counter
Counter(lab)
lab
# Out:
# ['neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  ...]

# %%
#from random import shuffle
import numpy as np
#dataset = zip(inp, lab)
#shuffle(dataset)
#inp, lab = zip(*dataset)
max_value = max([max(i) for i in inp])
min_value = min([min(i) for i in inp])

#inp = inp[:100000]
#lab = lab[:100000]

#normalised_inp = np.asarray(inp)/max_value
inp = (np.asarray(inp)-min_value)/(max_value-min_value)

# %%
from pybrain.structure.modules import LSTMLayer, SoftmaxLayer, TanhLayer
from pybrain.supervised import RPropMinusTrainer, BackpropTrainer
from pybrain.tools.shortcuts import buildNetwork
from pybrain.datasets import SequenceClassificationDataSet, ClassificationDataSet

# %%
lab_to_int = {'neutral':0, 'positive':1, 'negative':2}
int_to_lab = {0:'neutral', 1:'positive', 2:'negative'}
traindata = ClassificationDataSet(len(inp[0]), 1, nb_classes = 3)
#for i in range(int(len(inp)*3/4)):
for i in range(int(len(inp))):
    traindata.addSample(inp[i],lab_to_int[lab[i]])

# %%
traindata._convertToOneOfMany()

# %%
rnn = buildNetwork(traindata.indim, 10, traindata.outdim, hiddenclass = LSTMLayer, outclass = SoftmaxLayer, recurrent = True)
trainer = RPropMinusTrainer(rnn, dataset = traindata, verbose = True)
error = []
#counter = 0

# %%
for i in range(150):
    #print "Epoch: "+str(counter)
    error.append(trainer.train())
    #print ""
    #counter += 1
# Out:
# epoch     45  total error      0.10172   avg weight        1.0371
# epoch     46  total error      0.10153   avg weight        1.0395
# epoch     47  total error      0.10146   avg weight        1.0433
# epoch     48  total error      0.10128   avg weight        1.0488
# epoch     49  total error      0.10116   avg weight        1.0572
# epoch     50  total error      0.10105   avg weight        1.0697
# epoch     51  total error      0.10091   avg weight        1.0858
# epoch     52  total error      0.10079   avg weight        1.1111
# epoch     53  total error       0.1007   avg weight        1.1461
# epoch     54  total error      0.10078   avg weight        1.1964
# epoch     55  total error      0.10068   avg weight        1.1962
# epoch     56  total error      0.10062   avg weight        1.1973
# epoch     57  total error      0.10054   avg weight        1.1987
# epoch     58  total error      0.10051   avg weight        1.2006
# epoch     59  total error      0.10039   avg weight        1.2027
# epoch     60  total error      0.10034   avg weight         1.206
# epoch     61  total error      0.10041   avg weight        1.2111
# epoch     62  total error      0.10039   avg weight        1.2075
# epoch     63  total error      0.10026   avg weight        1.2106
# epoch     64  total error      0.10025   avg weight        1.2107
# epoch     65  total error      0.10016   avg weight        1.2145
# epoch     66  total error      0.10011   avg weight          1.22
# epoch     67  total error      0.10008   avg weight        1.2149
# epoch     68  total error      0.10008   avg weight        1.2174
# epoch     69  total error     0.099995   avg weight        1.2205
# epoch     70  total error     0.099945   avg weight        1.2177
# epoch     71  total error     0.099918   avg weight        1.2197
# epoch     72  total error     0.099863   avg weight        1.2205
# epoch     73  total error     0.099829   avg weight        1.2217
# epoch     74  total error     0.099878   avg weight        1.2212
# epoch     75  total error     0.099787   avg weight        1.2199
# epoch     76  total error     0.099713   avg weight        1.2224
# epoch     77  total error       0.1073   avg weight        1.2242
# epoch     78  total error     0.099746   avg weight        1.2244
# epoch     79  total error      0.09982   avg weight        1.2235
# epoch     80  total error     0.099706   avg weight        1.2246
# epoch     81  total error     0.099633   avg weight        1.2246
# epoch     82  total error      0.09968   avg weight        1.2259
# epoch     83  total error     0.099601   avg weight        1.2273
# epoch     84  total error     0.099533   avg weight        1.2285
# epoch     85  total error     0.099523   avg weight        1.2308
# epoch     86  total error     0.099453   avg weight        1.2336
# epoch     87  total error     0.099387   avg weight        1.2377
# epoch     88  total error     0.099347   avg weight        1.2436
# epoch     89  total error     0.099258   avg weight        1.2514
# epoch     90  total error     0.099167   avg weight        1.2625
# epoch     91  total error     0.099077   avg weight         1.278
# epoch     92  total error     0.098975   avg weight        1.2995
# epoch     93  total error     0.098881   avg weight        1.3284
# epoch     94  total error     0.098824   avg weight        1.3395
# epoch     95  total error     0.099014   avg weight        1.3295
# epoch     96  total error     0.098835   avg weight        1.3339
# epoch     97  total error     0.098798   avg weight        1.3305
# epoch     98  total error     0.098773   avg weight        1.3347
# epoch     99  total error     0.098694   avg weight        1.3364
# epoch    100  total error     0.098679   avg weight        1.3411
# epoch    101  total error     0.098608   avg weight        1.3468
# epoch    102  total error     0.098554   avg weight        1.3529
# epoch    103  total error      0.09853   avg weight        1.3485
# epoch    104  total error      0.09849   avg weight        1.3526
# epoch    105  total error     0.098495   avg weight        1.3519
# epoch    106  total error     0.098425   avg weight        1.3556
# epoch    107  total error     0.098371   avg weight        1.3606
# epoch    108  total error     0.098328   avg weight        1.3677
# epoch    109  total error     0.098263   avg weight        1.3716
# epoch    110  total error     0.098198   avg weight        1.3806
# epoch    111  total error     0.098124   avg weight        1.3899
# epoch    112  total error     0.098258   avg weight        1.3835
# epoch    113  total error     0.098098   avg weight        1.3872
# epoch    114  total error     0.098113   avg weight        1.3854
# epoch    115  total error     0.098096   avg weight        1.3853
# epoch    116  total error     0.098039   avg weight        1.3844
# epoch    117  total error     0.097998   avg weight        1.3877
# epoch    118  total error     0.097951   avg weight        1.3895
# epoch    119  total error      0.09797   avg weight        1.3915
# epoch    120  total error     0.097902   avg weight        1.3931
# epoch    121  total error     0.097848   avg weight        1.3956
# epoch    122  total error       0.0978   avg weight        1.3995
# epoch    123  total error     0.097733   avg weight        1.4024
# epoch    124  total error     0.097734   avg weight        1.4074
# epoch    125  total error     0.097636   avg weight        1.4065
# epoch    126  total error     0.097675   avg weight         1.409
# epoch    127  total error     0.097567   avg weight        1.4078
# epoch    128  total error     0.097596   avg weight        1.4101
# epoch    129  total error     0.097477   avg weight        1.4102
# epoch    130  total error     0.097405   avg weight         1.413
# epoch    131  total error     0.097324   avg weight        1.4166
# epoch    132  total error     0.097273   avg weight        1.4194
# epoch    133  total error     0.097171   avg weight        1.4216
# epoch    134  total error     0.097118   avg weight        1.4246
# epoch    135  total error     0.097021   avg weight        1.4282
# epoch    136  total error     0.096936   avg weight        1.4284
# epoch    137  total error     0.096965   avg weight        1.4345
# epoch    138  total error     0.096918   avg weight        1.4297
# epoch    139  total error      0.09681   avg weight        1.4314
# epoch    140  total error     0.096729   avg weight        1.4356
# epoch    141  total error     0.096659   avg weight        1.4389
# epoch    142  total error      0.09669   avg weight        1.4373
# epoch    143  total error     0.096543   avg weight        1.4398
# epoch    144  total error     0.096622   avg weight        1.4441
# epoch    145  total error     0.096654   avg weight        1.4449
# epoch    146  total error     0.096483   avg weight        1.4436
# epoch    147  total error     0.096531   avg weight        1.4461
# epoch    148  total error     0.096473   avg weight        1.4494
# epoch    149  total error     0.096367   avg weight         1.448
# epoch    150  total error     0.096414   avg weight         1.449
# epoch    151  total error      0.09634   avg weight        1.4473
# epoch    152  total error     0.096279   avg weight        1.4489
# epoch    153  total error     0.096282   avg weight        1.4506
# epoch    154  total error      0.09622   avg weight        1.4527
# epoch    155  total error     0.096157   avg weight        1.4545
# epoch    156  total error     0.096153   avg weight        1.4571
# epoch    157  total error      0.09615   avg weight        1.4586
# epoch    158  total error     0.096155   avg weight         1.459
# epoch    159  total error     0.096099   avg weight        1.4585
# epoch    160  total error     0.096057   avg weight        1.4604
# epoch    161  total error     0.096015   avg weight        1.4619
# epoch    162  total error     0.095982   avg weight        1.4643
# epoch    163  total error     0.095931   avg weight        1.4672
# epoch    164  total error     0.095891   avg weight        1.4708
# epoch    165  total error     0.095842   avg weight        1.4752
# epoch    166  total error     0.095799   avg weight        1.4807
# epoch    167  total error     0.095727   avg weight        1.4866
# epoch    168  total error     0.095807   avg weight        1.4895
# epoch    169  total error     0.095685   avg weight        1.4894
# epoch    170  total error     0.095651   avg weight        1.4952
# epoch    171  total error     0.095579   avg weight        1.5001
# epoch    172  total error     0.095646   avg weight        1.5059
# epoch    173  total error     0.095568   avg weight        1.5014
# epoch    174  total error     0.095595   avg weight        1.5032
# epoch    175  total error     0.095553   avg weight        1.5014
# epoch    176  total error     0.095514   avg weight        1.5024
# epoch    177  total error     0.095475   avg weight        1.5049
# epoch    178  total error     0.095434   avg weight        1.5075
# epoch    179  total error     0.095389   avg weight        1.5102
# epoch    180  total error     0.095331   avg weight        1.5088
# epoch    181  total error     0.095281   avg weight        1.5123
# epoch    182  total error     0.095218   avg weight        1.5164
# epoch    183  total error     0.095149   avg weight        1.5196
# epoch    184  total error     0.095151   avg weight        1.5249
# epoch    185  total error     0.095106   avg weight        1.5297
# epoch    186  total error     0.095033   avg weight        1.5282
# epoch    187  total error     0.094952   avg weight        1.5325
# epoch    188  total error     0.094871   avg weight        1.5354
# epoch    189  total error     0.094775   avg weight        1.5402
# epoch    190  total error     0.094897   avg weight        1.5455
# epoch    191  total error     0.094743   avg weight        1.5479
# epoch    192  total error     0.094697   avg weight        1.5469
# epoch    193  total error     0.094647   avg weight        1.5494
# epoch    194  total error     0.094635   avg weight         1.549

# %%
x=[i for i in range(len(error))]
plt.plot(x, error)
plt.show()

# %%
import feature_extractor
import scipy.io.wavfile as wav
import math

extractor = feature_extractor.FeatureExtractor()

def final_result(audio_signal):
    all_result = []
    for frame_feature in extractor.extract_features_per_frame(audio_signal = audio_signal):
        inp = (np.asarray(frame_feature)-min_value)/(max_value-min_value)
        frame_result = int_to_lab[rnn.activate(frame_feature).argmax()]
        all_result.append(frame_result)
    label_counts = Counter(all_result)
    print label_counts
    return max(label_counts, key = label_counts.get)

# %%
from os import listdir
from os.path import isfile, join
import scipy.io.wavfile as wav

path = 'tess_data'

y_pred=[]
y_actual=[]

audio_files = [f for f in listdir(path) if isfile(join(path, f))]
for audio_file in audio_files[:1000]:
    y_pred.append(final_result(audio_signal = wav.read(join(path, audio_file))))
    y_actual.append(audio_file.split('_')[2].split('.')[0])
# Out:
# Counter({'positive': 80, 'neutral': 37, 'negative': 36})
# Counter({'negative': 77, 'positive': 74, 'neutral': 74})
# Counter({'negative': 70, 'positive': 66, 'neutral': 36})
# Counter({'positive': 102, 'negative': 58, 'neutral': 39})
# Counter({'negative': 80, 'neutral': 69, 'positive': 54})
# Counter({'positive': 92, 'neutral': 61, 'negative': 49})
# Counter({'negative': 153, 'positive': 73, 'neutral': 29})
# Counter({'neutral': 67, 'negative': 49, 'positive': 45})
# Counter({'neutral': 97, 'positive': 65, 'negative': 64})
# Counter({'negative': 77, 'positive': 52, 'neutral': 39})
# Counter({'positive': 93, 'neutral': 57, 'negative': 49})
# Counter({'neutral': 94, 'negative': 83, 'positive': 22})
# Counter({'positive': 81, 'negative': 64, 'neutral': 48})
# Counter({'negative': 183, 'neutral': 50, 'positive': 16})
# Counter({'positive': 59, 'negative': 51, 'neutral': 43})
# Counter({'negative': 110, 'positive': 70, 'neutral': 69})
# Counter({'negative': 84, 'positive': 68, 'neutral': 34})
# Counter({'neutral': 80, 'positive': 72, 'negative': 50})
# Counter({'neutral': 78, 'negative': 75, 'positive': 61})
# Counter({'neutral': 92, 'negative': 74, 'positive': 50})
# Counter({'negative': 156, 'positive': 64, 'neutral': 36})
# Counter({'negative': 73, 'positive': 68, 'neutral': 19})
# Counter({'positive': 87, 'negative': 83, 'neutral': 61})
# Counter({'positive': 89, 'negative': 51, 'neutral': 37})
# Counter({'positive': 118, 'negative': 46, 'neutral': 39})
# Counter({'positive': 94, 'negative': 65, 'neutral': 57})
# Counter({'positive': 93, 'negative': 83, 'neutral': 31})
# Counter({'negative': 127, 'positive': 78, 'neutral': 53})
# Counter({'negative': 56, 'positive': 47, 'neutral': 36})
# Counter({'negative': 124, 'positive': 68, 'neutral': 42})
# Counter({'negative': 76, 'positive': 53, 'neutral': 31})
# Counter({'negative': 119, 'positive': 37, 'neutral': 31})
# Counter({'negative': 134, 'positive': 48, 'neutral': 25})
# Counter({'positive': 83, 'negative': 83, 'neutral': 14})
# Counter({'negative': 141, 'positive': 59, 'neutral': 42})
# Counter({'positive': 58, 'negative': 54, 'neutral': 42})
# Counter({'negative': 82, 'positive': 80, 'neutral': 76})
# Counter({'positive': 70, 'negative': 54, 'neutral': 41})
# Counter({'neutral': 73, 'positive': 68, 'negative': 59})
# Counter({'negative': 87, 'neutral': 65, 'positive': 44})
# Counter({'neutral': 85, 'negative': 64, 'positive': 56})
# Counter({'negative': 132, 'neutral': 70, 'positive': 40})
# Counter({'neutral': 54, 'negative': 48, 'positive': 40})
# Counter({'positive': 87, 'negative': 78, 'neutral': 74})
# Counter({'negative': 55, 'neutral': 40, 'positive': 35})
# Counter({'positive': 69, 'negative': 59, 'neutral': 45})
# Counter({'neutral': 61, 'positive': 56, 'negative': 50})
# Counter({'negative': 138, 'neutral': 76, 'positive': 63})
# Counter({'positive': 62, 'negative': 48, 'neutral': 22})
# Counter({'negative': 94, 'neutral': 67, 'positive': 59})
# Counter({'negative': 65, 'positive': 64, 'neutral': 22})
# Counter({'negative': 91, 'positive': 36, 'neutral': 35})
# Counter({'negative': 110, 'neutral': 44, 'positive': 39})
# Counter({'negative': 96, 'positive': 46, 'neutral': 44})
# Counter({'negative': 141, 'positive': 62, 'neutral': 51})
# Counter({'negative': 91, 'positive': 50, 'neutral': 25})
# Counter({'negative': 120, 'positive': 68, 'neutral': 33})
# Counter({'negative': 90, 'positive': 46, 'neutral': 2})
# Counter({'negative': 95, 'positive': 75, 'neutral': 38})
# Counter({'negative': 107, 'positive': 52, 'neutral': 43})
# Counter({'negative': 97, 'positive': 66, 'neutral': 43})
# Counter({'negative': 161, 'positive': 49, 'neutral': 36})
# Counter({'positive': 70, 'negative': 66, 'neutral': 16})
# Counter({'positive': 72, 'negative': 71, 'neutral': 70})
# Counter({'negative': 93, 'positive': 38, 'neutral': 13})
# Counter({'negative': 77, 'positive': 61, 'neutral': 51})
# Counter({'negative': 96, 'positive': 57, 'neutral': 19})
# Counter({'negative': 78, 'neutral': 57, 'positive': 42})
# Counter({'negative': 172, 'neutral': 45, 'positive': 34})
# Counter({'positive': 69, 'negative': 50, 'neutral': 23})
# Counter({'negative': 138, 'neutral': 52, 'positive': 49})
# Counter({'negative': 73, 'positive': 62, 'neutral': 4})
# Counter({'negative': 79, 'positive': 61, 'neutral': 39})
# Counter({'neutral': 90, 'negative': 65, 'positive': 39})
# Counter({'positive': 93, 'neutral': 57, 'negative': 55})
# Counter({'negative': 134, 'positive': 64, 'neutral': 54})
# Counter({'positive': 69, 'negative': 58, 'neutral': 41})
# Counter({'positive': 101, 'negative': 75, 'neutral': 44})
# Counter({'positive': 68, 'negative': 58, 'neutral': 18})
# Counter({'positive': 99, 'negative': 49, 'neutral': 41})
# Counter({'positive': 91, 'negative': 79, 'neutral': 42})
# Counter({'positive': 79, 'neutral': 52, 'negative': 46})
# Counter({'negative': 142, 'positive': 60, 'neutral': 19})
# Counter({'positive': 56, 'neutral': 45, 'negative': 44})
# Counter({'positive': 100, 'neutral': 78, 'negative': 65})
# Counter({'positive': 69, 'negative': 61, 'neutral': 35})
# Counter({'positive': 97, 'neutral': 54, 'negative': 48})
# Counter({'negative': 104, 'neutral': 51, 'positive': 35})
# Counter({'positive': 83, 'neutral': 54, 'negative': 52})
# Counter({'negative': 148, 'neutral': 46, 'positive': 38})
# Counter({'positive': 57, 'neutral': 52, 'negative': 39})
# Counter({'positive': 115, 'negative': 70, 'neutral': 59})
# Counter({'negative': 67, 'positive': 52, 'neutral': 26})
# Counter({'positive': 92, 'negative': 56, 'neutral': 55})
# Counter({'negative': 102, 'neutral': 44, 'positive': 38})
# Counter({'positive': 110, 'neutral': 64, 'negative': 48})
# Counter({'negative': 160, 'positive': 51, 'neutral': 44})
# Counter({'positive': 85, 'neutral': 45, 'negative': 33})
# Counter({'neutral': 94, 'positive': 87, 'negative': 48})
# Counter({'positive': 70, 'negative': 46, 'neutral': 40})
# Counter({'neutral': 84, 'positive': 83, 'negative': 37})
# Counter({'negative': 85, 'positive': 69, 'neutral': 56})
# Counter({'neutral': 80, 'positive': 68, 'negative': 68})
# Counter({'negative': 181, 'neutral': 37, 'positive': 30})
# Counter({'neutral': 79, 'positive': 63, 'negative': 27})
# Counter({'positive': 100, 'neutral': 90, 'negative': 61})
# Counter({'negative': 70, 'positive': 58, 'neutral': 41})
# Counter({'positive': 111, 'negative': 65, 'neutral': 38})
# Counter({'negative': 72, 'positive': 68, 'neutral': 61})
# Counter({'positive': 73, 'neutral': 70, 'negative': 52})
# Counter({'negative': 110, 'neutral': 84, 'positive': 52})
# Counter({'positive': 97, 'neutral': 46, 'negative': 16})
# Counter({'positive': 100, 'neutral': 72, 'negative': 62})
# Counter({'positive': 57, 'negative': 55, 'neutral': 29})
# Counter({'positive': 85, 'negative': 60, 'neutral': 56})
# Counter({'negative': 84, 'positive': 75, 'neutral': 52})
# Counter({'neutral': 79, 'positive': 76, 'negative': 39})
# Counter({'negative': 162, 'positive': 64, 'neutral': 28})
# Counter({'positive': 95, 'neutral': 45, 'negative': 20})
# Counter({'neutral': 80, 'positive': 75, 'negative': 71})
# Counter({'negative': 75, 'positive': 65, 'neutral': 28})
# Counter({'positive': 82, 'negative': 65, 'neutral': 61})
# Counter({'neutral': 85, 'negative': 83, 'positive': 64})
# Counter({'neutral': 92, 'positive': 70, 'negative': 36})
# Counter({'negative': 99, 'positive': 94, 'neutral': 65})
# Counter({'positive': 90, 'neutral': 25, 'negative': 24})
# Counter({'positive': 113, 'neutral': 71, 'negative': 49})
# Counter({'positive': 67, 'negative': 54, 'neutral': 36})
# Counter({'positive': 97, 'negative': 72, 'neutral': 14})
# Counter({'negative': 92, 'neutral': 64, 'positive': 49})
# Counter({'positive': 123, 'negative': 41, 'neutral': 36})
# Counter({'negative': 110, 'positive': 96, 'neutral': 41})
# Counter({'negative': 89, 'positive': 48, 'neutral': 7})
# Counter({'positive': 98, 'neutral': 87, 'negative': 58})
# Counter({'positive': 65, 'negative': 58, 'neutral': 44})
# Counter({'positive': 98, 'negative': 44, 'neutral': 36})
# Counter({'neutral': 77, 'negative': 63, 'positive': 49})
# Counter({'positive': 90, 'neutral': 47, 'negative': 47})
# Counter({'negative': 137, 'neutral': 68, 'positive': 35})
# Counter({'negative': 75, 'positive': 56, 'neutral': 33})
# Counter({'neutral': 107, 'positive': 85, 'negative': 51})
# Counter({'positive': 79, 'negative': 35, 'neutral': 30})
# Counter({'positive': 87, 'neutral': 73, 'negative': 43})
# Counter({'negative': 76, 'neutral': 55, 'positive': 52})
# Counter({'positive': 97, 'negative': 60, 'neutral': 58})
# Counter({'negative': 145, 'positive': 53, 'neutral': 39})
# Counter({'negative': 73, 'positive': 60, 'neutral': 34})
# Counter({'positive': 115, 'neutral': 81, 'negative': 59})
# Counter({'positive': 81, 'negative': 64, 'neutral': 25})
# Counter({'positive': 79, 'neutral': 72, 'negative': 51})
# Counter({'negative': 83, 'neutral': 65, 'positive': 52})
# Counter({'neutral': 76, 'positive': 69, 'negative': 56})
# Counter({'negative': 108, 'positive': 96, 'neutral': 49})
# Counter({'positive': 76, 'negative': 49, 'neutral': 36})
# Counter({'positive': 131, 'negative': 71, 'neutral': 45})
# Counter({'negative': 87, 'positive': 74, 'neutral': 11})
# Counter({'positive': 82, 'negative': 82, 'neutral': 35})
# Counter({'negative': 173, 'positive': 22, 'neutral': 8})
# Counter({'positive': 90, 'neutral': 74, 'negative': 51})
# Counter({'negative': 121, 'positive': 98, 'neutral': 73})
# Counter({'positive': 95, 'neutral': 37, 'negative': 20})
# Counter({'negative': 107, 'positive': 90, 'neutral': 44})
# Counter({'positive': 76, 'negative': 65, 'neutral': 24})
# Counter({'negative': 81, 'positive': 69, 'neutral': 43})
# Counter({'negative': 96, 'positive': 66, 'neutral': 44})
# Counter({'positive': 101, 'neutral': 47, 'negative': 39})
# Counter({'positive': 121, 'negative': 108, 'neutral': 58})
# Counter({'neutral': 63, 'positive': 52, 'negative': 33})
# Counter({'negative': 120, 'positive': 78, 'neutral': 43})
# Counter({'negative': 98, 'positive': 43, 'neutral': 19})
# Counter({'negative': 121, 'positive': 66, 'neutral': 19})
# Counter({'negative': 89, 'positive': 61, 'neutral': 47})
# Counter({'negative': 134, 'positive': 28, 'neutral': 11})
# Counter({'negative': 187, 'neutral': 40, 'positive': 28})
# Counter({'negative': 87, 'neutral': 37, 'positive': 32})
# Counter({'neutral': 87, 'positive': 79, 'negative': 74})
# Counter({'positive': 81, 'negative': 50, 'neutral': 18})
# Counter({'negative': 81, 'positive': 74, 'neutral': 33})
# Counter({'negative': 79, 'positive': 65, 'neutral': 54})
# Counter({'positive': 82, 'negative': 64, 'neutral': 59})
# Counter({'negative': 124, 'positive': 102, 'neutral': 61})
# Counter({'neutral': 54, 'positive': 51, 'negative': 40})
# Counter({'neutral': 100, 'positive': 92, 'negative': 61})
# Counter({'negative': 69, 'positive': 50, 'neutral': 38})
# Counter({'positive': 86, 'neutral': 78, 'negative': 48})
# Counter({'neutral': 75, 'positive': 59, 'negative': 59})
# Counter({'neutral': 87, 'positive': 66, 'negative': 42})
# Counter({'negative': 161, 'neutral': 53, 'positive': 29})
# Counter({'negative': 67, 'neutral': 45, 'positive': 35})
# Counter({'negative': 123, 'neutral': 72, 'positive': 45})
# Counter({'negative': 85, 'positive': 41, 'neutral': 23})
# Counter({'negative': 87, 'positive': 61, 'neutral': 44})
# Counter({'negative': 87, 'neutral': 76, 'positive': 34})
# Counter({'neutral': 86, 'negative': 59, 'positive': 57})
# Counter({'negative': 149, 'neutral': 78, 'positive': 42})
# Counter({'positive': 64, 'negative': 60, 'neutral': 40})
# Counter({'negative': 86, 'positive': 84, 'neutral': 69})
# Counter({'negative': 77, 'positive': 44, 'neutral': 24})
# Counter({'positive': 79, 'neutral': 62, 'negative': 42})
# Counter({'negative': 105, 'neutral': 52, 'positive': 49})
# Counter({'positive': 81, 'neutral': 57, 'negative': 47})
# Counter({'negative': 158, 'positive': 74, 'neutral': 16})
# Counter({'negative': 76, 'neutral': 46, 'positive': 38})
# Counter({'positive': 90, 'negative': 88, 'neutral': 61})
# Counter({'negative': 97, 'positive': 43, 'neutral': 21})
# Counter({'negative': 89, 'positive': 65, 'neutral': 32})
# Counter({'negative': 96, 'neutral': 60, 'positive': 31})
# Counter({'neutral': 96, 'positive': 59, 'negative': 56})
# Counter({'negative': 118, 'positive': 92, 'neutral': 48})
# Counter({'positive': 104, 'negative': 46, 'neutral': 17})
# Counter({'positive': 153, 'negative': 48, 'neutral': 46})
# Counter({'positive': 85, 'negative': 61, 'neutral': 13})
# Counter({'negative': 76, 'positive': 73, 'neutral': 40})
# Counter({'positive': 96, 'negative': 75, 'neutral': 33})
# Counter({'positive': 110, 'neutral': 37, 'negative': 34})
# Counter({'negative': 126, 'positive': 72, 'neutral': 44})
# Counter({'positive': 56, 'negative': 53, 'neutral': 33})
# Counter({'neutral': 77, 'positive': 74, 'negative': 70})
# Counter({'positive': 79, 'negative': 46, 'neutral': 14})
# Counter({'positive': 89, 'negative': 64, 'neutral': 51})
# Counter({'negative': 64, 'positive': 58, 'neutral': 50})
# Counter({'positive': 98, 'neutral': 95, 'negative': 36})
# Counter({'negative': 184, 'neutral': 43, 'positive': 34})
# Counter({'positive': 57, 'negative': 53, 'neutral': 44})
# Counter({'positive': 105, 'negative': 89, 'neutral': 75})
# Counter({'positive': 90, 'negative': 66, 'neutral': 23})
# Counter({'positive': 95, 'neutral': 62, 'negative': 47})
# Counter({'positive': 84, 'neutral': 59, 'negative': 55})
# Counter({'neutral': 90, 'negative': 58, 'positive': 51})
# Counter({'negative': 143, 'neutral': 71, 'positive': 42})
# Counter({'positive': 76, 'negative': 60, 'neutral': 28})
# Counter({'positive': 117, 'negative': 63, 'neutral': 60})
# Counter({'positive': 106, 'negative': 47, 'neutral': 30})
# Counter({'positive': 117, 'neutral': 49, 'negative': 49})
# Counter({'positive': 78, 'negative': 75, 'neutral': 57})
# Counter({'positive': 108, 'negative': 53, 'neutral': 44})
# Counter({'negative': 141, 'neutral': 64, 'positive': 43})
# Counter({'positive': 71, 'negative': 65, 'neutral': 32})
# Counter({'positive': 92, 'negative': 72, 'neutral': 70})
# Counter({'positive': 65, 'negative': 61, 'neutral': 21})
# Counter({'positive': 98, 'negative': 56, 'neutral': 50})
# Counter({'negative': 76, 'positive': 69, 'neutral': 57})
# Counter({'positive': 99, 'neutral': 64, 'negative': 56})
# Counter({'negative': 159, 'positive': 57, 'neutral': 32})
# Counter({'positive': 69, 'negative': 50, 'neutral': 43})
# Counter({'positive': 103, 'negative': 73, 'neutral': 55})
# Counter({'positive': 75, 'negative': 60, 'neutral': 32})
# Counter({'positive': 94, 'neutral': 52, 'negative': 50})
# Counter({'negative': 145, 'neutral': 45, 'positive': 32})
# Counter({'negative': 113, 'positive': 83, 'neutral': 23})
# Counter({'negative': 150, 'positive': 38, 'neutral': 38})
# Counter({'negative': 57, 'neutral': 52, 'positive': 44})
# Counter({'negative': 127, 'positive': 77, 'neutral': 37})
# Counter({'negative': 79, 'positive': 54, 'neutral': 16})
# Counter({'positive': 84, 'negative': 60, 'neutral': 51})
# Counter({'negative': 66, 'positive': 60, 'neutral': 59})
# Counter({'positive': 74, 'negative': 70, 'neutral': 31})
# Counter({'negative': 148, 'positive': 54, 'neutral': 34})
# Counter({'neutral': 71, 'negative': 48, 'positive': 35})
# Counter({'negative': 102, 'neutral': 95, 'positive': 53})
# Counter({'neutral': 56, 'positive': 53, 'negative': 46})
# Counter({'neutral': 91, 'positive': 66, 'negative': 40})
# Counter({'neutral': 101, 'negative': 78, 'positive': 36})
# Counter({'neutral': 89, 'negative': 78, 'positive': 29})
# Counter({'negative': 131, 'positive': 90, 'neutral': 53})
# Counter({'negative': 67, 'positive': 40, 'neutral': 35})
# Counter({'negative': 98, 'positive': 86, 'neutral': 54})
# Counter({'positive': 74, 'negative': 63, 'neutral': 21})
# Counter({'negative': 134, 'positive': 40, 'neutral': 23})
# Counter({'negative': 96, 'positive': 57, 'neutral': 51})
# Counter({'positive': 113, 'negative': 54, 'neutral': 16})
# Counter({'negative': 176, 'positive': 62, 'neutral': 9})
# Counter({'negative': 65, 'positive': 48, 'neutral': 37})
# Counter({'neutral': 106, 'positive': 88, 'negative': 59})
# Counter({'positive': 70, 'neutral': 48, 'negative': 41})
# Counter({'neutral': 81, 'positive': 73, 'negative': 49})
# Counter({'neutral': 127, 'positive': 43, 'negative': 27})
# Counter({'positive': 83, 'negative': 73, 'neutral': 48})
# Counter({'negative': 143, 'neutral': 71, 'positive': 51})
# Counter({'positive': 68, 'negative': 45, 'neutral': 42})
# Counter({'positive': 136, 'neutral': 62, 'negative': 36})
# Counter({'positive': 86, 'negative': 63, 'neutral': 10})
# Counter({'positive': 71, 'negative': 56, 'neutral': 54})
# Counter({'negative': 89, 'positive': 56, 'neutral': 50})
# Counter({'positive': 85, 'negative': 66, 'neutral': 46})
# Counter({'negative': 112, 'positive': 99, 'neutral': 37})
# Counter({'positive': 60, 'neutral': 56, 'negative': 43})
# Counter({'neutral': 93, 'negative': 63, 'positive': 53})
# Counter({'positive': 57, 'negative': 56, 'neutral': 44})
# Counter({'positive': 99, 'negative': 54, 'neutral': 32})
# Counter({'negative': 76, 'positive': 59, 'neutral': 50})
# Counter({'neutral': 92, 'negative': 50, 'positive': 44})
# Counter({'negative': 132, 'neutral': 67, 'positive': 34})
# Counter({'positive': 67, 'neutral': 55, 'negative': 36})
# Counter({'neutral': 122, 'positive': 73, 'negative': 49})
# Counter({'positive': 91, 'negative': 50, 'neutral': 29})
# Counter({'positive': 113, 'negative': 72, 'neutral': 23})
# Counter({'neutral': 101, 'positive': 59, 'negative': 33})
# Counter({'positive': 106, 'neutral': 74, 'negative': 41})
# Counter({'negative': 118, 'neutral': 81, 'positive': 55})
# Counter({'positive': 104, 'negative': 25, 'neutral': 23})
# Counter({'negative': 96, 'positive': 70, 'neutral': 52})
# Counter({'negative': 77, 'positive': 41, 'neutral': 32})
# Counter({'negative': 86, 'positive': 77, 'neutral': 45})
# Counter({'negative': 100, 'neutral': 48, 'positive': 43})
# Counter({'negative': 87, 'positive': 81, 'neutral': 42})
# Counter({'negative': 150, 'neutral': 61, 'positive': 29})
# Counter({'neutral': 72, 'positive': 54, 'negative': 32})
# Counter({'positive': 110, 'neutral': 67, 'negative': 59})
# Counter({'positive': 80, 'negative': 46, 'neutral': 42})
# Counter({'positive': 98, 'negative': 49, 'neutral': 29})
# Counter({'negative': 74, 'neutral': 65, 'positive': 57})
# Counter({'positive': 76, 'negative': 75, 'neutral': 46})
# Counter({'negative': 117, 'positive': 101, 'neutral': 80})
# Counter({'positive': 77, 'negative': 63, 'neutral': 24})
# Counter({'neutral': 86, 'negative': 85, 'positive': 69})
# Counter({'negative': 75, 'positive': 52, 'neutral': 28})
# Counter({'positive': 80, 'neutral': 75, 'negative': 63})
# Counter({'negative': 107, 'neutral': 52, 'positive': 48})
# Counter({'neutral': 92, 'positive': 82, 'negative': 65})
# Counter({'negative': 129, 'positive': 83, 'neutral': 58})
# Counter({'neutral': 63, 'positive': 55, 'negative': 50})
# Counter({'neutral': 118, 'positive': 82, 'negative': 63})
# Counter({'negative': 67, 'positive': 51, 'neutral': 49})
# Counter({'positive': 83, 'negative': 77, 'neutral': 48})
# Counter({'negative': 93, 'neutral': 80, 'positive': 48})
# Counter({'neutral': 109, 'positive': 60, 'negative': 44})
# Counter({'negative': 189, 'neutral': 58, 'positive': 50})
# Counter({'positive': 73, 'negative': 50, 'neutral': 24})
# Counter({'positive': 150, 'negative': 68, 'neutral': 38})
# Counter({'positive': 89, 'negative': 61, 'neutral': 15})
# Counter({'positive': 123, 'neutral': 52, 'negative': 43})
# Counter({'negative': 84, 'positive': 80, 'neutral': 45})
# Counter({'positive': 110, 'neutral': 52, 'negative': 52})
# Counter({'negative': 153, 'positive': 54, 'neutral': 43})
# Counter({'positive': 68, 'neutral': 57, 'negative': 39})
# Counter({'positive': 76, 'negative': 71, 'neutral': 70})
# Counter({'negative': 53, 'positive': 49, 'neutral': 27})
# Counter({'positive': 98, 'negative': 50, 'neutral': 40})
# Counter({'negative': 99, 'positive': 49, 'neutral': 41})
# Counter({'negative': 67, 'positive': 65, 'neutral': 61})
# Counter({'negative': 163, 'neutral': 45, 'positive': 31})
# Counter({'positive': 70, 'negative': 47, 'neutral': 40})
# Counter({'positive': 95, 'negative': 83, 'neutral': 62})
# Counter({'negative': 83, 'positive': 50, 'neutral': 22})
# Counter({'positive': 94, 'negative': 72, 'neutral': 25})
# Counter({'negative': 103, 'positive': 54, 'neutral': 51})
# Counter({'positive': 83, 'neutral': 73, 'negative': 49})
# Counter({'negative': 116, 'positive': 115, 'neutral': 39})
# Counter({'positive': 60, 'negative': 57, 'neutral': 34})
# Counter({'negative': 119, 'positive': 79, 'neutral': 43})
# Counter({'negative': 96, 'positive': 38, 'neutral': 24})
# Counter({'negative': 138, 'positive': 51, 'neutral': 7})
# Counter({'negative': 132, 'positive': 34, 'neutral': 28})
# Counter({'negative': 129, 'positive': 57, 'neutral': 7})
# Counter({'negative': 170, 'positive': 53, 'neutral': 39})
# Counter({'positive': 57, 'neutral': 52, 'negative': 40})
# Counter({'positive': 130, 'neutral': 60, 'negative': 52})
# Counter({'negative': 67, 'positive': 55, 'neutral': 25})
# Counter({'positive': 108, 'negative': 52, 'neutral': 30})
# Counter({'negative': 84, 'neutral': 52, 'positive': 49})
# Counter({'positive': 88, 'negative': 51, 'neutral': 40})
# Counter({'negative': 140, 'positive': 60, 'neutral': 41})
# Counter({'positive': 53, 'negative': 53, 'neutral': 46})
# Counter({'positive': 100, 'negative': 92, 'neutral': 41})
# Counter({'positive': 78, 'negative': 66, 'neutral': 15})
# Counter({'positive': 79, 'negative': 76, 'neutral': 27})
# Counter({'negative': 108, 'positive': 74, 'neutral': 42})
# Counter({'negative': 98, 'positive': 72, 'neutral': 42})
# Counter({'negative': 160, 'neutral': 48, 'positive': 43})
# Counter({'negative': 60, 'positive': 56, 'neutral': 37})
# Counter({'positive': 157, 'negative': 51, 'neutral': 39})
# Counter({'positive': 70, 'negative': 63, 'neutral': 34})
# Counter({'positive': 112, 'negative': 59, 'neutral': 25})
# Counter({'negative': 79, 'positive': 75, 'neutral': 42})
# Counter({'positive': 105, 'negative': 47, 'neutral': 45})
# Counter({'negative': 159, 'positive': 53, 'neutral': 38})
# Counter({'positive': 83, 'negative': 52, 'neutral': 34})
# Counter({'positive': 119, 'neutral': 57, 'negative': 44})
# Counter({'positive': 71, 'negative': 52, 'neutral': 42})
# Counter({'positive': 105, 'negative': 65, 'neutral': 45})
# Counter({'positive': 67, 'negative': 61, 'neutral': 58})
# Counter({'positive': 106, 'negative': 56, 'neutral': 35})
# Counter({'negative': 164, 'positive': 46, 'neutral': 43})
# Counter({'negative': 71, 'positive': 61, 'neutral': 17})
# Counter({'negative': 133, 'positive': 53, 'neutral': 43})
# Counter({'negative': 72, 'positive': 47, 'neutral': 19})
# Counter({'positive': 102, 'neutral': 51, 'negative': 50})
# Counter({'negative': 89, 'neutral': 65, 'positive': 40})
# Counter({'positive': 111, 'negative': 58, 'neutral': 41})
# Counter({'negative': 173, 'neutral': 42, 'positive': 27})
# Counter({'negative': 93, 'positive': 55, 'neutral': 21})
# Counter({'positive': 155, 'negative': 63, 'neutral': 42})
# Counter({'positive': 90, 'neutral': 49, 'negative': 43})
# Counter({'positive': 113, 'negative': 64, 'neutral': 24})
# Counter({'negative': 101, 'positive': 80, 'neutral': 34})
# Counter({'positive': 108, 'negative': 46, 'neutral': 38})
# Counter({'negative': 134, 'positive': 70, 'neutral': 31})
# Counter({'neutral': 70, 'positive': 61, 'negative': 16})
# Counter({'neutral': 104, 'positive': 80, 'negative': 54})
# Counter({'negative': 61, 'neutral': 53, 'positive': 35})
# Counter({'neutral': 75, 'positive': 55, 'negative': 47})
# Counter({'negative': 93, 'neutral': 54, 'positive': 31})
# Counter({'neutral': 137, 'positive': 49, 'negative': 12})
# Counter({'negative': 143, 'positive': 58, 'neutral': 33})
# Counter({'positive': 90, 'neutral': 47, 'negative': 27})
# Counter({'neutral': 127, 'negative': 62, 'positive': 56})
# Counter({'negative': 64, 'positive': 62, 'neutral': 22})
# Counter({'positive': 112, 'negative': 63, 'neutral': 32})
# Counter({'neutral': 72, 'negative': 63, 'positive': 56})
# Counter({'positive': 92, 'neutral': 63, 'negative': 60})
# Counter({'negative': 159, 'positive': 48, 'neutral': 34})
# Counter({'positive': 57, 'neutral': 57, 'negative': 41})
# Counter({'neutral': 99, 'negative': 89, 'positive': 47})
# Counter({'negative': 67, 'positive': 48, 'neutral': 42})
# Counter({'neutral': 80, 'positive': 74, 'negative': 48})
# Counter({'negative': 116, 'positive': 48, 'neutral': 36})
# Counter({'neutral': 115, 'positive': 54, 'negative': 43})
# Counter({'negative': 164, 'neutral': 50, 'positive': 49})
# Counter({'negative': 64, 'positive': 60, 'neutral': 26})
# Counter({'positive': 91, 'negative': 69, 'neutral': 47})
# Counter({'negative': 94, 'positive': 52, 'neutral': 19})
# Counter({'positive': 98, 'negative': 53, 'neutral': 44})
# Counter({'negative': 82, 'positive': 69, 'neutral': 43})
# Counter({'positive': 88, 'negative': 66, 'neutral': 53})
# Counter({'negative': 149, 'neutral': 60, 'positive': 45})
# Counter({'neutral': 53, 'negative': 43, 'positive': 39})
# Counter({'neutral': 98, 'positive': 70, 'negative': 68})
# Counter({'negative': 67, 'positive': 52, 'neutral': 40})
# Counter({'positive': 113, 'neutral': 56, 'negative': 30})
# Counter({'neutral': 70, 'negative': 60, 'positive': 54})
# Counter({'positive': 67, 'neutral': 67, 'negative': 48})
# Counter({'negative': 152, 'neutral': 49, 'positive': 17})
# Counter({'negative': 91, 'positive': 51, 'neutral': 24})
# Counter({'negative': 138, 'neutral': 64, 'positive': 34})
# Counter({'negative': 128, 'positive': 12, 'neutral': 4})
# Counter({'negative': 137, 'positive': 57, 'neutral': 8})
# Counter({'negative': 131, 'positive': 47, 'neutral': 10})
# Counter({'negative': 123, 'positive': 56, 'neutral': 39})
# Counter({'negative': 218, 'positive': 30, 'neutral': 12})
# Counter({'neutral': 57, 'negative': 48, 'positive': 39})
# Counter({'negative': 103, 'neutral': 68, 'positive': 65})
# Counter({'negative': 86, 'positive': 53, 'neutral': 16})
# Counter({'negative': 120, 'positive': 51, 'neutral': 10})
# Counter({'negative': 101, 'positive': 65, 'neutral': 35})
# Counter({'positive': 86, 'negative': 66, 'neutral': 32})
# Counter({'negative': 144, 'neutral': 46, 'positive': 34})
# Counter({'negative': 79, 'positive': 67, 'neutral': 13})
# Counter({'negative': 111, 'positive': 65, 'neutral': 50})
# Counter({'negative': 74, 'positive': 57, 'neutral': 7})
# Counter({'negative': 141, 'positive': 39, 'neutral': 8})
# Counter({'negative': 103, 'positive': 55, 'neutral': 39})
# Counter({'positive': 87, 'negative': 49, 'neutral': 47})
# Counter({'negative': 97, 'neutral': 83, 'positive': 66})
# Counter({'positive': 66, 'neutral': 60, 'negative': 28})
# Counter({'positive': 128, 'negative': 66, 'neutral': 61})
# Counter({'positive': 92, 'negative': 31, 'neutral': 30})
# Counter({'positive': 110, 'negative': 55, 'neutral': 23})
# Counter({'negative': 83, 'positive': 67, 'neutral': 58})
# Counter({'positive': 104, 'negative': 49, 'neutral': 48})
# Counter({'negative': 146, 'positive': 65, 'neutral': 62})
# Counter({'positive': 56, 'negative': 47, 'neutral': 43})
# Counter({'positive': 113, 'negative': 87, 'neutral': 53})
# Counter({'negative': 84, 'positive': 58, 'neutral': 30})
# Counter({'positive': 63, 'neutral': 59, 'negative': 56})
# Counter({'negative': 90, 'neutral': 70, 'positive': 56})
# Counter({'positive': 100, 'neutral': 53, 'negative': 48})
# Counter({'negative': 150, 'positive': 68, 'neutral': 27})
# Counter({'negative': 74, 'positive': 69, 'neutral': 12})
# Counter({'positive': 116, 'neutral': 74, 'negative': 51})
# Counter({'negative': 112, 'neutral': 30, 'positive': 23})
# Counter({'positive': 99, 'negative': 65, 'neutral': 28})
# Counter({'neutral': 86, 'positive': 60, 'negative': 59})
# Counter({'positive': 79, 'neutral': 61, 'negative': 55})
# Counter({'negative': 125, 'positive': 75, 'neutral': 50})
# Counter({'positive': 80, 'negative': 50, 'neutral': 30})
# Counter({'negative': 101, 'positive': 82, 'neutral': 52})
# Counter({'negative': 82, 'positive': 51, 'neutral': 18})
# Counter({'positive': 105, 'negative': 68, 'neutral': 30})
# Counter({'negative': 95, 'positive': 81, 'neutral': 47})
# Counter({'positive': 86, 'negative': 65, 'neutral': 59})
# Counter({'negative': 130, 'positive': 70, 'neutral': 50})
# Counter({'positive': 94, 'negative': 48, 'neutral': 30})
# Counter({'positive': 113, 'neutral': 63, 'negative': 59})
# Counter({'positive': 73, 'negative': 57, 'neutral': 11})
# Counter({'positive': 96, 'negative': 66, 'neutral': 48})
# Counter({'negative': 92, 'positive': 74, 'neutral': 46})
# Counter({'positive': 123, 'neutral': 64, 'negative': 43})
# Counter({'negative': 148, 'positive': 77, 'neutral': 36})
# Counter({'positive': 95, 'negative': 36, 'neutral': 23})
# Counter({'positive': 115, 'negative': 80, 'neutral': 37})
# Counter({'negative': 76, 'positive': 68, 'neutral': 38})
# Counter({'positive': 130, 'negative': 44, 'neutral': 35})
# Counter({'positive': 91, 'negative': 60, 'neutral': 59})
# Counter({'negative': 100, 'positive': 71, 'neutral': 51})
# Counter({'negative': 130, 'positive': 81, 'neutral': 29})
# Counter({'negative': 71, 'positive': 65, 'neutral': 23})
# Counter({'positive': 96, 'negative': 90, 'neutral': 54})
# Counter({'negative': 79, 'positive': 72, 'neutral': 12})
# Counter({'positive': 90, 'neutral': 66, 'negative': 52})
# Counter({'negative': 115, 'positive': 52, 'neutral': 47})
# Counter({'positive': 94, 'negative': 69, 'neutral': 58})
# Counter({'negative': 165, 'positive': 57, 'neutral': 31})
# Counter({'positive': 74, 'negative': 59, 'neutral': 37})
# Counter({'positive': 128, 'negative': 97, 'neutral': 35})
# Counter({'negative': 79, 'positive': 65, 'neutral': 15})
# Counter({'negative': 91, 'positive': 68, 'neutral': 26})
# Counter({'negative': 106, 'positive': 59, 'neutral': 49})
# Counter({'negative': 89, 'positive': 68, 'neutral': 35})
# Counter({'negative': 139, 'positive': 79, 'neutral': 30})
# Counter({'negative': 85, 'positive': 48, 'neutral': 22})
# Counter({'negative': 125, 'positive': 75, 'neutral': 63})
# Counter({'positive': 75, 'negative': 60, 'neutral': 32})
# Counter({'positive': 87, 'negative': 68, 'neutral': 35})
# Counter({'negative': 89, 'positive': 60, 'neutral': 43})
# Counter({'positive': 123, 'neutral': 58, 'negative': 30})
# Counter({'negative': 169, 'neutral': 80, 'positive': 27})
# Counter({'neutral': 52, 'negative': 49, 'positive': 42})
# Counter({'negative': 101, 'neutral': 78, 'positive': 63})
# Counter({'negative': 84, 'neutral': 43, 'positive': 35})
# Counter({'negative': 79, 'neutral': 65, 'positive': 39})
# Counter({'negative': 69, 'neutral': 64, 'positive': 53})
# Counter({'neutral': 100, 'positive': 60, 'negative': 41})
# Counter({'negative': 99, 'neutral': 85, 'positive': 61})
# Counter({'neutral': 69, 'negative': 67, 'positive': 28})
# Counter({'neutral': 98, 'negative': 69, 'positive': 59})
# Counter({'positive': 64, 'neutral': 39, 'negative': 39})
# Counter({'negative': 86, 'neutral': 67, 'positive': 66})
# Counter({'negative': 85, 'positive': 62, 'neutral': 52})
# Counter({'negative': 77, 'neutral': 66, 'positive': 65})
# Counter({'negative': 156, 'neutral': 58, 'positive': 46})
# Counter({'positive': 65, 'negative': 50, 'neutral': 34})
# Counter({'negative': 97, 'positive': 91, 'neutral': 43})
# Counter({'positive': 71, 'negative': 66, 'neutral': 13})
# Counter({'positive': 100, 'negative': 73, 'neutral': 50})
# Counter({'negative': 103, 'positive': 61, 'neutral': 42})
# Counter({'negative': 89, 'positive': 73, 'neutral': 61})
# Counter({'negative': 158, 'neutral': 80, 'positive': 20})
# Counter({'neutral': 59, 'negative': 59, 'positive': 47})
# Counter({'positive': 97, 'neutral': 66, 'negative': 62})
# Counter({'positive': 65, 'negative': 58, 'neutral': 37})
# Counter({'negative': 74, 'neutral': 60, 'positive': 56})
# Counter({'negative': 89, 'positive': 70, 'neutral': 53})
# Counter({'neutral': 72, 'positive': 62, 'negative': 56})
# Counter({'negative': 163, 'positive': 69, 'neutral': 21})
# Counter({'negative': 84, 'positive': 43, 'neutral': 21})
# Counter({'positive': 106, 'negative': 67, 'neutral': 45})
# Counter({'positive': 84, 'negative': 37, 'neutral': 24})
# Counter({'positive': 73, 'negative': 67, 'neutral': 46})
# Counter({'negative': 75, 'positive': 69, 'neutral': 47})
# Counter({'positive': 91, 'negative': 52, 'neutral': 47})
# Counter({'negative': 124, 'positive': 82, 'neutral': 61})
# Counter({'positive': 87, 'negative': 61, 'neutral': 32})
# Counter({'positive': 120, 'neutral': 68, 'negative': 55})
# Counter({'positive': 62, 'negative': 46, 'neutral': 45})
# Counter({'negative': 98, 'positive': 73, 'neutral': 26})
# Counter({'negative': 109, 'positive': 54, 'neutral': 30})
# Counter({'positive': 94, 'negative': 60, 'neutral': 52})
# Counter({'negative': 154, 'positive': 62, 'neutral': 37})
# Counter({'positive': 66, 'negative': 59, 'neutral': 41})
# Counter({'positive': 105, 'negative': 82, 'neutral': 47})
# Counter({'negative': 99, 'positive': 55, 'neutral': 28})
# Counter({'positive': 86, 'negative': 70, 'neutral': 40})
# Counter({'negative': 87, 'positive': 58, 'neutral': 56})
# Counter({'neutral': 70, 'negative': 63, 'positive': 62})
# Counter({'negative': 142, 'positive': 50, 'neutral': 46})
# Counter({'negative': 90, 'positive': 58, 'neutral': 17})
# Counter({'negative': 115, 'positive': 65, 'neutral': 47})
# Counter({'negative': 99, 'positive': 48, 'neutral': 5})
# Counter({'negative': 111, 'positive': 46, 'neutral': 29})
# Counter({'negative': 98, 'positive': 78, 'neutral': 25})
# Counter({'negative': 100, 'positive': 44, 'neutral': 34})
# Counter({'negative': 146, 'neutral': 52, 'positive': 40})
# Counter({'positive': 89, 'negative': 56, 'neutral': 16})
# Counter({'negative': 99, 'positive': 93, 'neutral': 33})
# Counter({'positive': 77, 'negative': 64, 'neutral': 7})
# Counter({'positive': 114, 'negative': 66, 'neutral': 28})
# Counter({'negative': 119, 'positive': 50, 'neutral': 15})
# Counter({'negative': 95, 'positive': 78, 'neutral': 33})
# Counter({'negative': 193, 'neutral': 42, 'positive': 11})
# Counter({'negative': 81, 'positive': 55, 'neutral': 15})
# Counter({'negative': 127, 'positive': 68, 'neutral': 35})
# Counter({'negative': 105, 'positive': 42, 'neutral': 22})
# Counter({'negative': 89, 'positive': 71, 'neutral': 32})
# Counter({'negative': 129, 'positive': 42, 'neutral': 37})
# Counter({'negative': 103, 'positive': 63, 'neutral': 40})
# Counter({'negative': 174, 'positive': 57, 'neutral': 11})
# Counter({'positive': 67, 'negative': 59, 'neutral': 41})
# Counter({'positive': 104, 'negative': 74, 'neutral': 52})
# Counter({'negative': 66, 'positive': 59, 'neutral': 33})
# Counter({'negative': 103, 'positive': 90, 'neutral': 31})
# Counter({'negative': 95, 'positive': 70, 'neutral': 44})
# Counter({'negative': 118, 'positive': 68, 'neutral': 30})
# Counter({'negative': 209, 'positive': 30, 'neutral': 19})
# Counter({'negative': 80, 'positive': 35, 'neutral': 25})
# Counter({'negative': 81, 'positive': 73, 'neutral': 52})
# Counter({'negative': 98, 'positive': 52, 'neutral': 7})
# Counter({'positive': 105, 'negative': 66, 'neutral': 29})
# Counter({'negative': 120, 'positive': 43, 'neutral': 34})
# Counter({'negative': 101, 'positive': 65, 'neutral': 34})
# Counter({'negative': 155, 'neutral': 54, 'positive': 43})
# Counter({'negative': 67, 'positive': 50, 'neutral': 45})
# Counter({'negative': 103, 'positive': 74, 'neutral': 66})
# Counter({'negative': 94, 'positive': 56, 'neutral': 30})
# Counter({'positive': 93, 'negative': 67, 'neutral': 37})
# Counter({'negative': 111, 'positive': 49, 'neutral': 37})
# Counter({'negative': 105, 'neutral': 67, 'positive': 51})
# Counter({'negative': 177, 'positive': 49, 'neutral': 30})
# Counter({'negative': 106, 'positive': 36, 'neutral': 19})
# Counter({'positive': 122, 'negative': 86, 'neutral': 39})
# Counter({'negative': 63, 'positive': 62, 'neutral': 21})
# Counter({'positive': 89, 'negative': 64, 'neutral': 33})
# Counter({'negative': 119, 'neutral': 39, 'positive': 38})
# Counter({'negative': 94, 'positive': 64, 'neutral': 31})
# Counter({'negative': 120, 'positive': 88, 'neutral': 17})
# Counter({'negative': 94, 'positive': 37, 'neutral': 28})
# Counter({'negative': 96, 'positive': 90, 'neutral': 56})
# Counter({'negative': 98, 'positive': 49, 'neutral': 14})
# Counter({'negative': 97, 'positive': 72, 'neutral': 33})
# Counter({'negative': 133, 'positive': 48, 'neutral': 19})
# Counter({'positive': 88, 'negative': 71, 'neutral': 42})
# Counter({'negative': 156, 'positive': 67, 'neutral': 17})
# Counter({'negative': 69, 'positive': 65, 'neutral': 33})
# Counter({'negative': 157, 'positive': 61, 'neutral': 42})
# Counter({'negative': 107, 'positive': 52, 'neutral': 11})
# Counter({'negative': 136, 'positive': 42, 'neutral': 22})
# Counter({'negative': 105, 'positive': 59, 'neutral': 55})
# Counter({'positive': 78, 'negative': 72, 'neutral': 55})
# Counter({'negative': 157, 'positive': 58, 'neutral': 51})
# Counter({'negative': 91, 'positive': 68, 'neutral': 13})
# Counter({'negative': 114, 'positive': 64, 'neutral': 47})
# Counter({'negative': 125, 'positive': 21, 'neutral': 3})
# Counter({'negative': 144, 'positive': 49, 'neutral': 4})
# Counter({'negative': 95, 'positive': 56, 'neutral': 45})
# Counter({'negative': 86, 'positive': 83, 'neutral': 46})
# Counter({'negative': 209, 'positive': 28, 'neutral': 25})
# Counter({'positive': 68, 'negative': 56, 'neutral': 45})
# Counter({'negative': 151, 'positive': 52, 'neutral': 33})
# Counter({'negative': 118, 'positive': 34, 'neutral': 15})
# Counter({'negative': 88, 'positive': 76, 'neutral': 44})
# Counter({'negative': 128, 'neutral': 34, 'positive': 27})
# Counter({'negative': 98, 'neutral': 56, 'positive': 55})
# Counter({'negative': 172, 'positive': 46, 'neutral': 25})
# Counter({'negative': 100, 'positive': 57, 'neutral': 10})
# Counter({'negative': 158, 'neutral': 45, 'positive': 33})
# Counter({'positive': 91, 'negative': 33, 'neutral': 20})
# Counter({'positive': 113, 'negative': 58, 'neutral': 39})
# Counter({'negative': 130, 'positive': 51, 'neutral': 38})
# Counter({'negative': 117, 'positive': 76, 'neutral': 46})
# Counter({'negative': 195, 'positive': 35, 'neutral': 17})
# Counter({'neutral': 63, 'positive': 56, 'negative': 41})
# Counter({'negative': 111, 'positive': 77, 'neutral': 49})
# Counter({'negative': 108, 'positive': 29, 'neutral': 17})
# Counter({'negative': 87, 'positive': 66, 'neutral': 39})
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-13-0c59468b8c10> in <module>()
#      10 audio_files = [f for f in listdir(path) if isfile(join(path, f))]
#      11 for audio_file in audio_files[:1000]:
# ---> 12     y_pred.append(final_result(audio_signal = wav.read(join(path, audio_file))))
#      13     y_actual.append(audio_file.split('_')[2].split('.')[0])
#
# <ipython-input-12-a5f5105c4c3c> in final_result(audio_signal)
#       8     all_result = []
#       9     for frame_feature in extractor.extract_features_per_frame(audio_signal = audio_signal):
# ---> 10         frame_result = int_to_lab[rnn.activate(frame_feature).argmax()]
#      11         all_result.append(frame_result)
#      12     label_counts = Counter(all_result)
#
# C:\Anaconda2\lib\site-packages\pybrain\structure\networks\recurrent.pyc in activate(self, inpt)
#      48         """Do one transformation of an input and return the result."""
#      49         self.inputbuffer[self.offset] = inpt
# ---> 50         self.forward()
#      51         return self.outputbuffer[self.offset - 1].copy()
#      52
#
# C:\Anaconda2\lib\site-packages\pybrain\structure\networks\recurrent.pyc in forward(self)
#      61         """Produce the output from the input."""
#      62         if not (self.offset + 1 < self.inputbuffer.shape[0]):
# ---> 63             self._growBuffers()
#      64         super(RecurrentNetworkComponent, self).forward()
#      65         self.offset += 1
#
# C:\Anaconda2\lib\site-packages\pybrain\structure\networks\network.pyc in _growBuffers(self)
#     141     def _growBuffers(self):
#     142         for m in self.modules:
# --> 143             m._growBuffers()
#     144         super(Network, self)._growBuffers()
#     145
#
# C:\Anaconda2\lib\site-packages\pybrain\structure\modules\module.pyc in _growBuffers(self)
#      62         # Save the current buffers
#      63         tmp = [getattr(self, n) for n, _ in self.bufferlist]
# ---> 64         Module._resetBuffers(self, currentlength * 2)
#      65
#      66         for previous, (buffername, _dim) in zip(tmp, self.bufferlist):
#
# C:\Anaconda2\lib\site-packages\pybrain\structure\modules\module.pyc in _resetBuffers(self, length)
#      54         """Reset buffers to a length (in time dimension) of 1."""
#      55         for buffername, dim in self.bufferlist:
# ---> 56             setattr(self, buffername, zeros((length, dim)))
#      57
#      58     def _growBuffers(self):
#
# MemoryError:

# %%
len(y_pred)
# Out:
# 654

# %%
from sklearn.metrics import precision_recall_fscore_support
precision, recall, f1_score, _ = precision_recall_fscore_support(y_actual, y_pred, labels=['neutral','positive','negative'])
print "Precision = "+str(precision)+"\nRecall = "+str(recall)+"\nF1 Score = "+str(f1_score)
# Out:
# Precision = [ 0.16666667  0.          0.        ]
# Recall = [ 0.13043478  0.          0.        ]
# F1 Score = [ 0.14634146  0.          0.        ]

# %%
file_name = raw_input("Enter the name of the call file name.\n> ")
rate_sig, sig = wav.read(file_name)

plt.plot(sig)
plt.plot((0,len(sig)),(0,0),'g')
plt.show()

complete_call_result = final_result(audio_signal = (rate_sig, sig))
first_half_result = final_result(audio_signal = (rate_sig, sig[:int(len(sig)/2)]))
second_half_result = final_result(audio_signal = (rate_sig, sig[int(len(sig)/2):]))
segment_result = []
for i in range(int(math.ceil(len(sig)/(rate_sig*20)))):
    segment_result.append(final_result(audio_signal = (rate_sig, sig[i*rate_sig*20:i*rate_sig*20+rate_sig*20])))
# Out:
# Enter the name of the call file name.
# > test.wav
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-17-77d2fae008aa> in <module>()
#       6 plt.show()
#       7
# ----> 8 complete_call_result = final_result(audio_signal = (rate_sig, sig))
#       9 first_half_result = final_result(audio_signal = (rate_sig, sig[:int(len(sig)/2)]))
#      10 second_half_result = final_result(audio_signal = (rate_sig, sig[int(len(sig)/2):]))
#
# <ipython-input-12-a5f5105c4c3c> in final_result(audio_signal)
#       7 def final_result(audio_signal):
#       8     all_result = []
# ----> 9     for frame_feature in extractor.extract_features_per_frame(audio_signal = audio_signal):
#      10         frame_result = int_to_lab[rnn.activate(frame_feature).argmax()]
#      11         all_result.append(frame_result)
#
# D:\Projects\Emotion_Analysis\EmotionAnalyser\feature_extractor.pyc in extract_features_per_frame(self, audio_file, audio_signal)
#      45                         frames_features = self.extract_frames_features(audio_signal)
#      46                 else:
# ---> 47                         frames_features = self.extract_frames_features(audio_signal)
#      48                 return frames_features
#
# D:\Projects\Emotion_Analysis\EmotionAnalyser\feature_extractor.pyc in extract_frames_features(self, audio_signal)
#      18         def extract_frames_features(self, audio_signal):
#      19                 (rate, sig) = audio_signal
# ---> 20                 mfcc_features = mfcc(sig, rate)
#      21                 fbank_features = logfbank(sig, rate)
#      22                 aggregate_features = np.append(mfcc_features, fbank_features, axis = 1)
#
# C:\Anaconda2\lib\site-packages\features\base.pyc in mfcc(signal, samplerate, winlen, winstep, numcep, nfilt, nfft, lowfreq, highfreq, preemph, ceplifter, appendEnergy, winfunc)
#      31     :returns: A numpy array of size (NUMFRAMES by numcep) containing features. Each row holds 1 feature vector.
#      32     """
# ---> 33     feat,energy = fbank(signal,samplerate,winlen,winstep,nfilt,nfft,lowfreq,highfreq,preemph,winfunc)
#      34     feat = numpy.log(feat)
#      35     feat = dct(feat, type=2, axis=1, norm='ortho')[:,:numcep]
#
# C:\Anaconda2\lib\site-packages\features\base.pyc in fbank(signal, samplerate, winlen, winstep, nfilt, nfft, lowfreq, highfreq, preemph, winfunc)
#      59     signal = sigproc.preemphasis(signal,preemph)
#      60     frames = sigproc.framesig(signal, winlen*samplerate, winstep*samplerate, winfunc)
# ---> 61     pspec = sigproc.powspec(frames,nfft)
#      62     energy = numpy.sum(pspec,1) # this stores the total energy in each frame
#      63     energy = numpy.where(energy == 0,numpy.finfo(float).eps,energy) # if energy is zero, we get problems with log
#
# C:\Anaconda2\lib\site-packages\features\sigproc.pyc in powspec(frames, NFFT)
#      89     :returns: If frames is an NxD matrix, output will be NxNFFT. Each row will be the power spectrum of the corresponding frame.
#      90     """
# ---> 91     return 1.0/NFFT * numpy.square(magspec(frames,NFFT))
#      92
#      93 def logpowspec(frames,NFFT,norm=1):
#
# C:\Anaconda2\lib\site-packages\features\sigproc.pyc in magspec(frames, NFFT)
#      79     :returns: If frames is an NxD matrix, output will be NxNFFT. Each row will be the magnitude spectrum of the corresponding frame.
#      80     """
# ---> 81     complex_spec = numpy.fft.rfft(frames,NFFT)
#      82     return numpy.absolute(complex_spec)
#      83
#
# C:\Anaconda2\lib\site-packages\numpy\fft\fftpack.pyc in rfft(a, n, axis, norm)
#     359     a = array(a, copy=True, dtype=float)
#     360     output = _raw_fft(a, n, axis, fftpack.rffti, fftpack.rfftf,
# --> 361                       _real_fft_cache)
#     362     if _unitary(norm):
#     363         output *= 1 / sqrt(a.shape[axis])
#
# C:\Anaconda2\lib\site-packages\numpy\fft\fftpack.pyc in _raw_fft(a, n, axis, init_function, work_function, fft_cache)
#      73             index[axis] = slice(0, s[axis])
#      74             s[axis] = n
# ---> 75             z = zeros(s, a.dtype.char)
#      76             z[index] = a
#      77             a = z
#
# MemoryError:

# %%
import numpy as np
from __future__ import division
print "Overall call result: "+complete_call_result
print "Trainsition: "+first_half_result+" --> "+second_half_result
map_dict = {'negative':-1, 'neutral':0, 'positive':1}
mapped_segment_result = [map_dict[result] for result in segment_result]
index = [i for i in range(len(mapped_segment_result))]
index = np.asarray(index)
bar_width = 1
plt.plot((0,index[-1]+1),((0,0)), 'r')
plt.bar(index, mapped_segment_result, bar_width)
plt.xticks(index + bar_width/2 , (str(i*20)+'-'+str((i+1)*20) for i in index))
plt.xlabel('Time series with 20 seconds chunk')
#plt.axes([0, 100, -2, 2])
plt.ylabel('Emotion:\n1 = positive\n0 = neutral\n-1 = negative')
plt.title('Emotion per 20 second segment')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-93469713bf6c> in <module>()
#       1 import numpy as np
#       2 from __future__ import division
# ----> 3 print "Overall call result: "+complete_call_result
#       4 print "Trainsition: "+first_half_result+" --> "+second_half_result
#       5 map_dict = {'negative':-1, 'neutral':0, 'positive':1}
#
# NameError: name 'complete_call_result' is not defined

# %%
def plot_confusion_matrix(cm, title='Confusion matrix', cmap=plt.cm.Blues):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(cm))
    plt.xticks(tick_marks, ['neutral','positive','negative'], rotation=45)
    plt.yticks(tick_marks, ['neutral','positive','negative'])
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_actual, y_pred, labels=['neutral','positive','negative'])
print cm
plot_confusion_matrix(cm)
# Out:
# [[12  7 73]
#  [ 0  0  0]
#  [ 0  0  0]]

# %%
len([1 for i in range(len(y_pred)) if y_pred[i]==y_actual[i]])/float(len(y_pred))

# %%
lab[1]
