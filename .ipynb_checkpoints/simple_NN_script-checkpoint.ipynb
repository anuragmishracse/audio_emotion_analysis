# %%
from __future__ import division 
import matplotlib.pyplot as plt
# %matplotlib inline
import emotion_analysis
emo = emotion_analysis.EmotionAnalysis()

# %%
inp, lab = emo.prepare_dataset('data')
# Out:
# Read audio file 'data\negative_38.wav', count: 100
# Read audio file 'data\neutral_221.wav', count: 200
# Read audio file 'data\neutral_490.wav', count: 300
# Read audio file 'data\positive_303.wav', count: 400
# Read audio file 'data\positive_55.wav', count: 500

# %%
from random import shuffle
import numpy as np

dataset = zip(inp, lab)
shuffle(dataset)
inp, lab = zip(*dataset)
max_value = max([max(i) for i in inp])
min_value = min([min(i) for i in inp])
#normalised_inp = np.asarray(inp)/max_value
inp = (np.asarray(inp)-min_value)/(max_value-min_value)

# %%
from pybrain.structure.modules import LSTMLayer, SoftmaxLayer, TanhLayer
from pybrain.supervised import RPropMinusTrainer, BackpropTrainer
from pybrain.tools.shortcuts import buildNetwork
from pybrain.datasets import SequenceClassificationDataSet, ClassificationDataSet

# %%
lab_to_int = {'neutral':0, 'positive':1, 'negative':2}
int_to_lab = {0:'neutral', 1:'positive', 2:'negative'}
alldata = ClassificationDataSet(len(inp[0]), 1, nb_classes = 3)
for i in range(int(len(inp)*3/4)):
#for i in range(int(len(inp))):
   alldata.addSample(inp[i],lab_to_int[lab[i]])

# %%
testdata, traindata = alldata.splitWithProportion(0.25)

# %%
len(testdata['input'])
# Out:
# 384

# %%
testdata._convertToOneOfMany()
traindata._convertToOneOfMany()

# %%
rnn = buildNetwork(traindata.indim,158, 105, traindata.outdim, hiddenclass = TanhLayer, outclass = SoftmaxLayer)
trainer = RPropMinusTrainer(rnn, dataset = traindata, verbose = True)
error = []
counter = 0

# %%
for i in range(900):
    print "Epoch: "+str(counter)
    error.append(trainer.train())
    print ""
    counter += 1
# Out:
# Epoch: 100
# epoch    100  total error     0.056446   avg weight        1.8195
#
# Epoch: 101
# epoch    101  total error     0.056083   avg weight        1.8411
#
# Epoch: 102
# epoch    102  total error     0.057286   avg weight        1.8531
#
# Epoch: 103
# epoch    103  total error     0.056023   avg weight        1.8715
#
# Epoch: 104
# epoch    104  total error     0.055169   avg weight        1.8771
#
# Epoch: 105
# epoch    105  total error       0.0548   avg weight        1.8982
#
# Epoch: 106
# epoch    106  total error     0.054667   avg weight        1.9088
#
# Epoch: 107
# epoch    107  total error     0.053974   avg weight        1.9303
#
# Epoch: 108
# epoch    108  total error      0.05348   avg weight        1.9433
#
# Epoch: 109
# epoch    109  total error     0.053263   avg weight         1.963
#
# Epoch: 110
# epoch    110  total error      0.05275   avg weight         1.978
#
# Epoch: 111
# epoch    111  total error     0.052218   avg weight        1.9998
#
# Epoch: 112
# epoch    112  total error     0.051816   avg weight        2.0119
#
# Epoch: 113
# epoch    113  total error     0.051137   avg weight        2.0328
#
# Epoch: 114
# epoch    114  total error     0.050742   avg weight        2.0518
#
# Epoch: 115
# epoch    115  total error     0.050195   avg weight        2.0761
#
# Epoch: 116
# epoch    116  total error     0.049453   avg weight        2.0941
#
# Epoch: 117
# epoch    117  total error     0.049091   avg weight        2.1135
#
# Epoch: 118
# epoch    118  total error     0.048462   avg weight        2.1367
#
# Epoch: 119
# epoch    119  total error     0.047722   avg weight        2.1546
#
# Epoch: 120
# epoch    120  total error     0.047102   avg weight        2.1714
#
# Epoch: 121
# epoch    121  total error     0.046671   avg weight        2.1864
#
# Epoch: 122
# epoch    122  total error     0.045842   avg weight        2.2021
#
# Epoch: 123
# epoch    123  total error     0.045235   avg weight         2.225
#
# Epoch: 124
# epoch    124  total error     0.044809   avg weight         2.246
#
# Epoch: 125
# epoch    125  total error     0.044563   avg weight        2.2636
#
# Epoch: 126
# epoch    126  total error     0.044027   avg weight         2.288
#
# Epoch: 127
# epoch    127  total error      0.04335   avg weight        2.3079
#
# Epoch: 128
# epoch    128  total error     0.042973   avg weight        2.3223
#
# Epoch: 129
# epoch    129  total error     0.042562   avg weight        2.3388
#
# Epoch: 130
# epoch    130  total error     0.042573   avg weight        2.3587
#
# Epoch: 131
# epoch    131  total error     0.041854   avg weight        2.3741
#
# Epoch: 132
# epoch    132  total error     0.041501   avg weight        2.3966
#
# Epoch: 133
# epoch    133  total error     0.041064   avg weight        2.4185
#
# Epoch: 134
# epoch    134  total error     0.040589   avg weight         2.444
#
# Epoch: 135
# epoch    135  total error      0.04064   avg weight        2.4672
#
# Epoch: 136
# epoch    136  total error     0.050729   avg weight        2.4821
#
# Epoch: 137
# epoch    137  total error     0.040429   avg weight         2.495
#
# Epoch: 138
# epoch    138  total error     0.040209   avg weight        2.5119
#
# Epoch: 139
# epoch    139  total error     0.039769   avg weight        2.5307
#
# Epoch: 140
# epoch    140  total error     0.039518   avg weight        2.5533
#
# Epoch: 141
# epoch    141  total error     0.039555   avg weight        2.5779
#
# Epoch: 142
# epoch    142  total error     0.038917   avg weight        2.5917
#
# Epoch: 143
# epoch    143  total error     0.038635   avg weight        2.6134
#
# Epoch: 144
# epoch    144  total error     0.038372   avg weight        2.6393
#
# Epoch: 145
# epoch    145  total error     0.037785   avg weight        2.6533
#
# Epoch: 146
# epoch    146  total error     0.037721   avg weight        2.6766
#
# Epoch: 147
# epoch    147  total error     0.037282   avg weight        2.6908
#
# Epoch: 148
# epoch    148  total error       0.0372   avg weight         2.714
#
# Epoch: 149
# epoch    149  total error     0.036401   avg weight        2.7299
#
# Epoch: 150
# epoch    150  total error     0.036267   avg weight        2.7492
#
# Epoch: 151
# epoch    151  total error     0.035787   avg weight         2.762
#
# Epoch: 152
# epoch    152  total error     0.035521   avg weight        2.7792
#
# Epoch: 153
# epoch    153  total error     0.034998   avg weight        2.7982
#
# Epoch: 154
# epoch    154  total error     0.035126   avg weight        2.8163
#
# Epoch: 155
# epoch    155  total error     0.034549   avg weight        2.8307
#
# Epoch: 156
# epoch    156  total error     0.034419   avg weight        2.8486
#
# Epoch: 157
# epoch    157  total error     0.034003   avg weight        2.8693
#
# Epoch: 158
# epoch    158  total error     0.033727   avg weight        2.8856
#
# Epoch: 159
# epoch    159  total error     0.033152   avg weight        2.9001
#
# Epoch: 160
# epoch    160  total error     0.032643   avg weight         2.903
#
# Epoch: 161
# epoch    161  total error     0.032237   avg weight         2.905
#
# Epoch: 162
# epoch    162  total error     0.031823   avg weight        2.9052
#
# Epoch: 163
# epoch    163  total error     0.031632   avg weight        2.9054
#
# Epoch: 164
# epoch    164  total error     0.031002   avg weight        2.9066
#
# Epoch: 165
# epoch    165  total error     0.031221   avg weight        2.9083
#
# Epoch: 166
# epoch    166  total error     0.030764   avg weight        2.9092
#
# Epoch: 167
# epoch    167  total error     0.030696   avg weight        2.9109
#
# Epoch: 168
# epoch    168  total error     0.030463   avg weight        2.9121
#
# Epoch: 169
# epoch    169  total error     0.030066   avg weight         2.913
#
# Epoch: 170
# epoch    170  total error     0.029598   avg weight         2.914
#
# Epoch: 171
# epoch    171  total error     0.029087   avg weight        2.9321
#
# Epoch: 172
# epoch    172  total error     0.028547   avg weight        2.9357
#
# Epoch: 173
# epoch    173  total error     0.028036   avg weight        2.9394
#
# Epoch: 174
# epoch    174  total error       0.0277   avg weight        2.9572
#
# Epoch: 175
# epoch    175  total error      0.02758   avg weight        2.9621
#
# Epoch: 176
# epoch    176  total error     0.026915   avg weight        2.9622
#
# Epoch: 177
# epoch    177  total error     0.027248   avg weight        2.9675
#
# Epoch: 178
# epoch    178  total error     0.026727   avg weight        2.9827
#
# Epoch: 179
# epoch    179  total error     0.026581   avg weight        2.9833
#
# Epoch: 180
# epoch    180  total error     0.026179   avg weight        2.9849
#
# Epoch: 181
# epoch    181  total error     0.025976   avg weight        2.9859
#
# Epoch: 182
# epoch    182  total error     0.025689   avg weight        2.9873
#
# Epoch: 183
# epoch    183  total error     0.025387   avg weight         2.988
#
# Epoch: 184
# epoch    184  total error     0.025084   avg weight        2.9899
#
# Epoch: 185
# epoch    185  total error     0.024596   avg weight        2.9925
#
# Epoch: 186
# epoch    186  total error     0.024197   avg weight        2.9951
#
# Epoch: 187
# epoch    187  total error     0.023989   avg weight         2.997
#
# Epoch: 188
# epoch    188  total error     0.023511   avg weight         3.001
#
# Epoch: 189
# epoch    189  total error     0.023679   avg weight        3.0041
#
# Epoch: 190
# epoch    190  total error     0.023299   avg weight        3.0061
#
# Epoch: 191
# epoch    191  total error     0.023267   avg weight        3.0038
#
# Epoch: 192
# epoch    192  total error     0.023547   avg weight         3.006
#
# Epoch: 193
# epoch    193  total error     0.022885   avg weight        3.0072
#
# Epoch: 194
# epoch    194  total error     0.022609   avg weight        3.0061
#
# Epoch: 195
# epoch    195  total error     0.022425   avg weight        3.0067
#
# Epoch: 196
# epoch    196  total error     0.022163   avg weight        3.0081
#
# Epoch: 197
# epoch    197  total error     0.021876   avg weight        3.0103
#
# Epoch: 198
# epoch    198  total error     0.021618   avg weight        3.0283
#
# Epoch: 199
# epoch    199  total error     0.021378   avg weight        3.0289
#
# Epoch: 200
# epoch    200  total error     0.021018   avg weight        3.0306
#
# Epoch: 201
# epoch    201  total error     0.020652   avg weight        3.0333
#
# Epoch: 202
# epoch    202  total error     0.020504   avg weight        3.0334
#
# Epoch: 203
# epoch    203  total error     0.020698   avg weight        3.0509
#
# Epoch: 204
# epoch    204  total error     0.020393   avg weight        3.0517
#
# Epoch: 205
# epoch    205  total error     0.020262   avg weight        3.0519
#
# Epoch: 206
# epoch    206  total error     0.020041   avg weight        3.0537
#
# Epoch: 207
# epoch    207  total error     0.019851   avg weight        3.0562
#
# Epoch: 208
# epoch    208  total error     0.019686   avg weight        3.0578
#
# Epoch: 209
# epoch    209  total error     0.019429   avg weight        3.0588
#
# Epoch: 210
# epoch    210  total error     0.019221   avg weight        3.0615
#
# Epoch: 211
# epoch    211  total error     0.019046   avg weight        3.0608
#
# Epoch: 212
# epoch    212  total error     0.018818   avg weight        3.0615
#
# Epoch: 213
# epoch    213  total error     0.018542   avg weight        3.0619
#
# Epoch: 214
# epoch    214  total error     0.018273   avg weight        3.0631
#
# Epoch: 215
# epoch    215  total error     0.017973   avg weight        3.0652
#
# Epoch: 216
# epoch    216  total error     0.017782   avg weight        3.0662
#
# Epoch: 217
# epoch    217  total error     0.017916   avg weight        3.0669
#
# Epoch: 218
# epoch    218  total error     0.017712   avg weight        3.0656
#
# Epoch: 219
# epoch    219  total error      0.01766   avg weight        3.0674
#
# Epoch: 220
# epoch    220  total error     0.017421   avg weight        3.0683
#
# Epoch: 221
# epoch    221  total error     0.017268   avg weight        3.0691
#
# Epoch: 222
# epoch    222  total error     0.017169   avg weight        3.0699
#
# Epoch: 223
# epoch    223  total error     0.016977   avg weight        3.0707
#
# Epoch: 224
# epoch    224  total error     0.016858   avg weight         3.071
#
# Epoch: 225
# epoch    225  total error      0.01669   avg weight        3.0719
#
# Epoch: 226
# epoch    226  total error     0.016479   avg weight        3.0723
#
# Epoch: 227
# epoch    227  total error     0.016277   avg weight        3.0727
#
# Epoch: 228
# epoch    228  total error      0.01628   avg weight        3.0737
#
# Epoch: 229
# epoch    229  total error     0.020961   avg weight        3.0746
#
# Epoch: 230
# epoch    230  total error     0.015817   avg weight        3.0746
#
# Epoch: 231
# epoch    231  total error     0.016508   avg weight        3.0753
#
# Epoch: 232
# epoch    232  total error     0.050485   avg weight        3.0751
#
# Epoch: 233
# epoch    233  total error     0.016533   avg weight        3.0755
#
# Epoch: 234
# epoch    234  total error     0.016039   avg weight        3.0757
#
# Epoch: 235
# epoch    235  total error     0.015402   avg weight        3.0759
#
# Epoch: 236
# epoch    236  total error     0.015193   avg weight        3.0913
#
# Epoch: 237
# epoch    237  total error      0.01554   avg weight        3.0919
#
# Epoch: 238
# epoch    238  total error     0.014988   avg weight        3.0926
#
# Epoch: 239
# epoch    239  total error     0.014809   avg weight        3.0927
#
# Epoch: 240
# epoch    240  total error     0.014971   avg weight        3.0932
#
# Epoch: 241
# epoch    241  total error     0.014483   avg weight        3.0937
#
# Epoch: 242
# epoch    242  total error     0.014786   avg weight        3.0937
#
# Epoch: 243
# epoch    243  total error     0.014354   avg weight        3.0946
#
# Epoch: 244
# epoch    244  total error     0.014408   avg weight        3.0947
#
# Epoch: 245
# epoch    245  total error     0.014221   avg weight        3.0957
#
# Epoch: 246
# epoch    246  total error     0.014111   avg weight        3.0962
#
# Epoch: 247
# epoch    247  total error     0.013935   avg weight        3.0973
#
# Epoch: 248
# epoch    248  total error     0.013817   avg weight        3.0987
#
# Epoch: 249
# epoch    249  total error     0.013687   avg weight        3.1004
#
# Epoch: 250
# epoch    250  total error     0.013447   avg weight        3.0994
#
# Epoch: 251
# epoch    251  total error     0.013278   avg weight        3.1006
#
# Epoch: 252
# epoch    252  total error     0.013848   avg weight        3.1015
#
# Epoch: 253
# epoch    253  total error     0.012997   avg weight        3.1026
#
# Epoch: 254
# epoch    254  total error     0.012849   avg weight        3.1013
#
# Epoch: 255
# epoch    255  total error     0.013465   avg weight        3.1024
#
# Epoch: 256
# epoch    256  total error     0.012926   avg weight         3.104
#
# Epoch: 257
# epoch    257  total error     0.012573   avg weight        3.1042
#
# Epoch: 258
# epoch    258  total error     0.013323   avg weight        3.1051
#
# Epoch: 259
# epoch    259  total error     0.012508   avg weight        3.1054
#
# Epoch: 260
# epoch    260  total error     0.012372   avg weight        3.1064
#
# Epoch: 261
# epoch    261  total error     0.012258   avg weight         3.108
#
# Epoch: 262
# epoch    262  total error     0.012176   avg weight        3.1103
#
# Epoch: 263
# epoch    263  total error     0.012011   avg weight        3.1099
#
# Epoch: 264
# epoch    264  total error     0.011855   avg weight         3.112
#
# Epoch: 265
# epoch    265  total error     0.011712   avg weight        3.1121
#
# Epoch: 266
# epoch    266  total error     0.011602   avg weight          3.13
#
# Epoch: 267
# epoch    267  total error     0.011379   avg weight        3.1329
#
# Epoch: 268
# epoch    268  total error     0.011224   avg weight        3.1346
#
# Epoch: 269
# epoch    269  total error     0.011351   avg weight        3.1357
#
# Epoch: 270
# epoch    270  total error      0.01118   avg weight        3.1381
#
# Epoch: 271
# epoch    271  total error     0.011033   avg weight        3.1402
#
# Epoch: 272
# epoch    272  total error      0.01142   avg weight        3.1435
#
# Epoch: 273
# epoch    273  total error     0.010939   avg weight        3.1436
#
# Epoch: 274
# epoch    274  total error     0.010737   avg weight        3.1453
#
# Epoch: 275
# epoch    275  total error     0.010635   avg weight        3.1458
#
# Epoch: 276
# epoch    276  total error     0.010629   avg weight        3.1498
#
# Epoch: 277
# epoch    277  total error     0.010346   avg weight         3.152
#
# Epoch: 278
# epoch    278  total error     0.010287   avg weight         3.155
#
# Epoch: 279
# epoch    279  total error     0.010105   avg weight        3.1572
#
# Epoch: 280
# epoch    280  total error    0.0099103   avg weight        3.1601
#
# Epoch: 281
# epoch    281  total error    0.0098611   avg weight        3.1612
#
# Epoch: 282
# epoch    282  total error    0.0097397   avg weight        3.1624
#
# Epoch: 283
# epoch    283  total error    0.0094877   avg weight        3.1632
#
# Epoch: 284
# epoch    284  total error    0.0095569   avg weight        3.1633
#
# Epoch: 285
# epoch    285  total error    0.0094169   avg weight        3.1646
#
# Epoch: 286
# epoch    286  total error    0.0092732   avg weight        3.1662
#
# Epoch: 287
# epoch    287  total error     0.009131   avg weight        3.1669
#
# Epoch: 288
# epoch    288  total error    0.0090181   avg weight        3.1679
#
# Epoch: 289
# epoch    289  total error    0.0088763   avg weight        3.1685
#
# Epoch: 290
# epoch    290  total error    0.0086719   avg weight        3.1693
#
# Epoch: 291
# epoch    291  total error    0.0084899   avg weight        3.1703
#
# Epoch: 292
# epoch    292  total error    0.0084137   avg weight        3.1714
#
# Epoch: 293
# epoch    293  total error    0.0086695   avg weight        3.1718
#
# Epoch: 294
# epoch    294  total error    0.0083701   avg weight        3.1721
#
# Epoch: 295
# epoch    295  total error    0.0082903   avg weight        3.1726
#
# Epoch: 296
# epoch    296  total error    0.0082213   avg weight        3.1737
#
# Epoch: 297
# epoch    297  total error    0.0082213   avg weight        3.1754
#
# Epoch: 298
# epoch    298  total error    0.0081046   avg weight        3.1772
#
# Epoch: 299
# epoch    299  total error     0.008058   avg weight        3.1796
#
# Epoch: 300
# epoch    300  total error    0.0079396   avg weight        3.1817
#
# Epoch: 301
# epoch    301  total error    0.0078212   avg weight        3.1844
#
# Epoch: 302
# epoch    302  total error    0.0076895   avg weight        3.1872
#
# Epoch: 303
# epoch    303  total error    0.0075806   avg weight        3.1884
#
# Epoch: 304
# epoch    304  total error    0.0074131   avg weight        3.1905
#
# Epoch: 305
# epoch    305  total error    0.0073393   avg weight        3.1911
#
# Epoch: 306
# epoch    306  total error    0.0071302   avg weight        3.1917
#
# Epoch: 307
# epoch    307  total error    0.0069269   avg weight         3.193
#
# Epoch: 308
# epoch    308  total error    0.0071809   avg weight        3.1932
#
# Epoch: 309
# epoch    309  total error     0.006933   avg weight        3.1941
#
# Epoch: 310
# epoch    310  total error    0.0068344   avg weight        3.1946
#
# Epoch: 311
# epoch    311  total error    0.0067878   avg weight        3.1947
#
# Epoch: 312
# epoch    312  total error    0.0066377   avg weight        3.1954
#
# Epoch: 313
# epoch    313  total error    0.0065145   avg weight        3.1963
#
# Epoch: 314
# epoch    314  total error     0.006438   avg weight        3.1967
#
# Epoch: 315
# epoch    315  total error    0.0066803   avg weight        3.1975
#
# Epoch: 316
# epoch    316  total error    0.0063996   avg weight         3.198
#
# Epoch: 317
# epoch    317  total error    0.0063425   avg weight        3.1981
#
# Epoch: 318
# epoch    318  total error    0.0062416   avg weight        3.1986
#
# Epoch: 319
# epoch    319  total error    0.0061338   avg weight        3.1991
#
# Epoch: 320
# epoch    320  total error    0.0060354   avg weight        3.2152
#
# Epoch: 321
# epoch    321  total error    0.0059245   avg weight         3.216
#
# Epoch: 322
# epoch    322  total error    0.0057712   avg weight        3.2169
#
# Epoch: 323
# epoch    323  total error    0.0058282   avg weight        3.2332
#
# Epoch: 324
# epoch    324  total error    0.0056694   avg weight        3.2339
#
# Epoch: 325
# epoch    325  total error    0.0056266   avg weight        3.2339
#
# Epoch: 326
# epoch    326  total error    0.0054064   avg weight        3.2347
#
# Epoch: 327
# epoch    327  total error    0.0054169   avg weight        3.2352
#
# Epoch: 328
# epoch    328  total error    0.0052865   avg weight         3.236
#
# Epoch: 329
# epoch    329  total error    0.0052558   avg weight        3.2367
#
# Epoch: 330
# epoch    330  total error    0.0051513   avg weight        3.2382
#
# Epoch: 331
# epoch    331  total error    0.0050573   avg weight        3.2391
#
# Epoch: 332
# epoch    332  total error    0.0049729   avg weight        3.2384
#
# Epoch: 333
# epoch    333  total error    0.0048939   avg weight        3.2392
#
# Epoch: 334
# epoch    334  total error    0.0047848   avg weight        3.2403
#
# Epoch: 335
# epoch    335  total error    0.0047068   avg weight        3.2415
#
# Epoch: 336
# epoch    336  total error    0.0045628   avg weight        3.2429
#
# Epoch: 337
# epoch    337  total error    0.0046346   avg weight        3.2442
#
# Epoch: 338
# epoch    338  total error    0.0044485   avg weight        3.2452
#
# Epoch: 339
# epoch    339  total error    0.0043696   avg weight        3.2465
#
# Epoch: 340
# epoch    340  total error    0.0042166   avg weight        3.2483
#
# Epoch: 341
# epoch    341  total error    0.0040793   avg weight        3.2506
#
# Epoch: 342
# epoch    342  total error    0.0039818   avg weight        3.2491
#
# Epoch: 343
# epoch    343  total error    0.0039044   avg weight        3.2499
#
# Epoch: 344
# epoch    344  total error    0.0039353   avg weight        3.2493
#
# Epoch: 345
# epoch    345  total error     0.003816   avg weight        3.2501
#
# Epoch: 346
# epoch    346  total error    0.0037814   avg weight        3.2493
#
# Epoch: 347
# epoch    347  total error    0.0036645   avg weight        3.2502
#
# Epoch: 348
# epoch    348  total error    0.0035866   avg weight         3.251
#
# Epoch: 349
# epoch    349  total error    0.0035143   avg weight        3.2518
#
# Epoch: 350
# epoch    350  total error    0.0034181   avg weight        3.2528
#
# Epoch: 351
# epoch    351  total error    0.0034275   avg weight        3.2539
#
# Epoch: 352
# epoch    352  total error    0.0033312   avg weight        3.2557
#
# Epoch: 353
# epoch    353  total error    0.0032767   avg weight        3.2573
#
# Epoch: 354
# epoch    354  total error    0.0032406   avg weight        3.2558
#
# Epoch: 355
# epoch    355  total error    0.0032161   avg weight        3.2577
#
# Epoch: 356
# epoch    356  total error    0.0031929   avg weight        3.2572
#
# Epoch: 357
# epoch    357  total error    0.0031195   avg weight        3.2588
#
# Epoch: 358
# epoch    358  total error    0.0031265   avg weight        3.2583
#
# Epoch: 359
# epoch    359  total error    0.0030528   avg weight        3.2594
#
# Epoch: 360
# epoch    360  total error     0.020256   avg weight        3.2591
#
# Epoch: 361
# epoch    361  total error    0.0031668   avg weight        3.2597
#
# Epoch: 362
# epoch    362  total error    0.0030396   avg weight        3.2594
#
# Epoch: 363
# epoch    363  total error    0.0030197   avg weight          3.26
#
# Epoch: 364
# epoch    364  total error    0.0029519   avg weight         3.261
#
# Epoch: 365
# epoch    365  total error    0.0032147   avg weight        3.2621
#
# Epoch: 366
# epoch    366  total error    0.0029373   avg weight        3.2626
#
# Epoch: 367
# epoch    367  total error    0.0028799   avg weight        3.2633
#
# Epoch: 368
# epoch    368  total error    0.0028986   avg weight        3.2643
#
# Epoch: 369
# epoch    369  total error    0.0028472   avg weight        3.2658
#
# Epoch: 370
# epoch    370  total error     0.003425   avg weight         3.268
#
# Epoch: 371
# epoch    371  total error    0.0027684   avg weight        3.2679
#
# Epoch: 372
# epoch    372  total error    0.0027901   avg weight         3.268
#
# Epoch: 373
# epoch    373  total error    0.0030315   avg weight        3.2689
#
# Epoch: 374
# epoch    374  total error    0.0027087   avg weight        3.2693
#
# Epoch: 375
# epoch    375  total error    0.0027134   avg weight         3.269
#
# Epoch: 376
# epoch    376  total error    0.0027927   avg weight        3.2694
#
# Epoch: 377
# epoch    377  total error    0.0026221   avg weight        3.2703
#
# Epoch: 378
# epoch    378  total error    0.0026294   avg weight        3.2702
#
# Epoch: 379
# epoch    379  total error    0.0026249   avg weight        3.2703
#
# Epoch: 380
# epoch    380  total error    0.0025589   avg weight        3.2708
#
# Epoch: 381
# epoch    381  total error    0.0025305   avg weight        3.2715
#
# Epoch: 382
# epoch    382  total error    0.0025197   avg weight        3.2724
#
# Epoch: 383
# epoch    383  total error    0.0025173   avg weight        3.2727
#
# Epoch: 384
# epoch    384  total error    0.0024748   avg weight        3.2737
#
# Epoch: 385
# epoch    385  total error    0.0024523   avg weight        3.2741
#
# Epoch: 386
# epoch    386  total error    0.0024342   avg weight        3.2747
#
# Epoch: 387
# epoch    387  total error    0.0023979   avg weight        3.2756
#
# Epoch: 388
# epoch    388  total error    0.0023599   avg weight        3.2761
#
# Epoch: 389
# epoch    389  total error     0.012954   avg weight        3.2778
#
# Epoch: 390
# epoch    390  total error    0.0023983   avg weight        3.2955
#
# Epoch: 391
# epoch    391  total error    0.0022906   avg weight        3.2951
#
# Epoch: 392
# epoch    392  total error    0.0023241   avg weight        3.2961
#
# Epoch: 393
# epoch    393  total error    0.0022508   avg weight        3.2968
#
# Epoch: 394
# epoch    394  total error    0.0022644   avg weight        3.2977
#
# Epoch: 395
# epoch    395  total error    0.0022514   avg weight        3.2987
#
# Epoch: 396
# epoch    396  total error    0.0021964   avg weight         3.316
#
# Epoch: 397
# epoch    397  total error    0.0021771   avg weight        3.3332
#
# Epoch: 398
# epoch    398  total error    0.0021366   avg weight        3.3325
#
# Epoch: 399
# epoch    399  total error    0.0021219   avg weight        3.3482
#
# Epoch: 400
# epoch    400  total error    0.0021212   avg weight         3.363
#
# Epoch: 401
# epoch    401  total error    0.0020676   avg weight        3.3791
#
# Epoch: 402
# epoch    402  total error    0.0020845   avg weight        3.3939
#
# Epoch: 403
# epoch    403  total error    0.0020255   avg weight        3.4094
#
# Epoch: 404
# epoch    404  total error    0.0020167   avg weight        3.4238
#
# Epoch: 405
# epoch    405  total error    0.0019853   avg weight        3.4424
#
# Epoch: 406
# epoch    406  total error    0.0019512   avg weight        3.4596
#
# Epoch: 407
# epoch    407  total error     0.001914   avg weight        3.4756
#
# Epoch: 408
# epoch    408  total error    0.0018786   avg weight        3.4773
#
# Epoch: 409
# epoch    409  total error    0.0018406   avg weight        3.4936
#
# Epoch: 410
# epoch    410  total error    0.0017981   avg weight        3.5112
#
# Epoch: 411
# epoch    411  total error    0.0017864   avg weight        3.5291
#
# Epoch: 412
# epoch    412  total error    0.0018068   avg weight        3.5473
#
# Epoch: 413
# epoch    413  total error    0.0017426   avg weight        3.5643
#
# Epoch: 414
# epoch    414  total error    0.0018237   avg weight        3.5834
#
# Epoch: 415
# epoch    415  total error     0.001721   avg weight        3.5852
#
# Epoch: 416
# epoch    416  total error    0.0017425   avg weight        3.5855
#
# Epoch: 417
# epoch    417  total error    0.0016907   avg weight         3.586
#
# Epoch: 418
# epoch    418  total error     0.001678   avg weight        3.5867
#
# Epoch: 419
# epoch    419  total error    0.0016504   avg weight        3.5897
#
# Epoch: 420
# epoch    420  total error     0.001619   avg weight        3.5902
#
# Epoch: 421
# epoch    421  total error    0.0015907   avg weight        3.6112
#
# Epoch: 422
# epoch    422  total error    0.0015623   avg weight         3.613
#
# Epoch: 423
# epoch    423  total error    0.0015804   avg weight        3.6349
#
# Epoch: 424
# epoch    424  total error    0.0015192   avg weight        3.6367
#
# Epoch: 425
# epoch    425  total error    0.0015706   avg weight        3.6391
#
# Epoch: 426
# epoch    426  total error      0.00151   avg weight        3.6418
#
# Epoch: 427
# epoch    427  total error    0.0015249   avg weight        3.6447
#
# Epoch: 428
# epoch    428  total error    0.0014907   avg weight        3.6471
#
# Epoch: 429
# epoch    429  total error    0.0014796   avg weight        3.6502
#
# Epoch: 430
# epoch    430  total error    0.0014585   avg weight        3.6536
#
# Epoch: 431
# epoch    431  total error     0.001435   avg weight        3.6575
#
# Epoch: 432
# epoch    432  total error    0.0014163   avg weight        3.6608
#
# Epoch: 433
# epoch    433  total error    0.0013969   avg weight        3.6645
#
# Epoch: 434
# epoch    434  total error    0.0013483   avg weight        3.6886
#
# Epoch: 435
# epoch    435  total error    0.0013572   avg weight        3.6923
#
# Epoch: 436
# epoch    436  total error    0.0013221   avg weight         3.689
#
# Epoch: 437
# epoch    437  total error    0.0013125   avg weight        3.6886
#
# Epoch: 438
# epoch    438  total error    0.0013684   avg weight         3.691
#
# Epoch: 439
# epoch    439  total error    0.0012881   avg weight        3.6931
#
# Epoch: 440
# epoch    440  total error    0.0013094   avg weight        3.6934
#
# Epoch: 441
# epoch    441  total error    0.0012641   avg weight        3.6956
#
# Epoch: 442
# epoch    442  total error     0.001244   avg weight        3.6993
#
# Epoch: 443
# epoch    443  total error    0.0012196   avg weight        3.7005
#
# Epoch: 444
# epoch    444  total error    0.0012136   avg weight        3.7046
#
# Epoch: 445
# epoch    445  total error    0.0011868   avg weight        3.7047
#
# Epoch: 446
# epoch    446  total error    0.0012173   avg weight        3.7077
#
# Epoch: 447
# epoch    447  total error    0.0011663   avg weight        3.7102
#
# Epoch: 448
# epoch    448  total error    0.0011651   avg weight        3.7144
#
# Epoch: 449
# epoch    449  total error    0.0011405   avg weight        3.7155
#
# Epoch: 450
# epoch    450  total error    0.0011142   avg weight        3.7197
#
# Epoch: 451
# epoch    451  total error     0.001086   avg weight        3.7251
#
# Epoch: 452
# epoch    452  total error    0.0010885   avg weight        3.7507
#
# Epoch: 453
# epoch    453  total error    0.0010471   avg weight        3.7583
#
# Epoch: 454
# epoch    454  total error    0.0010187   avg weight        3.7662
#
# Epoch: 455
# epoch    455  total error   0.00099674   avg weight        3.7628
#
# Epoch: 456
# epoch    456  total error    0.0009634   avg weight        3.7641
#
# Epoch: 457
# epoch    457  total error   0.00093419   avg weight        3.7695
#
# Epoch: 458
# epoch    458  total error   0.00094211   avg weight         3.776
#
# Epoch: 459
# epoch    459  total error    0.0011282   avg weight        3.7985
#
# Epoch: 460
# epoch    460  total error   0.00091295   avg weight        3.7939
#
# Epoch: 461
# epoch    461  total error   0.00096707   avg weight        3.7966
#
# Epoch: 462
# epoch    462  total error   0.00089945   avg weight        3.7977
#
# Epoch: 463
# epoch    463  total error   0.00092713   avg weight        3.8008
#
# Epoch: 464
# epoch    464  total error   0.00089408   avg weight        3.8038
#
# Epoch: 465
# epoch    465  total error   0.00089571   avg weight        3.8084
#
# Epoch: 466
# epoch    466  total error   0.00088525   avg weight         3.806
#
# Epoch: 467
# epoch    467  total error   0.00087371   avg weight        3.8097
#
# Epoch: 468
# epoch    468  total error   0.00086518   avg weight         3.811
#
# Epoch: 469
# epoch    469  total error   0.00085296   avg weight        3.8101
#
# Epoch: 470
# epoch    470  total error   0.00084238   avg weight        3.8118
#
# Epoch: 471
# epoch    471  total error   0.00082609   avg weight        3.8132
#
# Epoch: 472
# epoch    472  total error   0.00082571   avg weight        3.8118
#
# Epoch: 473
# epoch    473  total error   0.00082793   avg weight        3.8119
#
# Epoch: 474
# epoch    474  total error   0.00082116   avg weight        3.8125
#
# Epoch: 475
# epoch    475  total error   0.00082776   avg weight        3.8123
#
# Epoch: 476
# epoch    476  total error   0.00079913   avg weight        3.8128
#
# Epoch: 477
# epoch    477  total error   0.00080347   avg weight        3.8133
#
# Epoch: 478
# epoch    478  total error   0.00079002   avg weight        3.8131
#
# Epoch: 479
# epoch    479  total error   0.00078656   avg weight        3.8133
#
# Epoch: 480
# epoch    480  total error   0.00077977   avg weight        3.8128
#
# Epoch: 481
# epoch    481  total error   0.00077901   avg weight        3.8127
#
# Epoch: 482
# epoch    482  total error   0.00076827   avg weight        3.8126
#
# Epoch: 483
# epoch    483  total error   0.00076236   avg weight        3.8125
#
# Epoch: 484
# epoch    484  total error   0.00075207   avg weight        3.8115
#
# Epoch: 485
# epoch    485  total error   0.00075675   avg weight        3.8106
#
# Epoch: 486
# epoch    486  total error   0.00074498   avg weight        3.8095
#
# Epoch: 487
# epoch    487  total error   0.00074699   avg weight         3.809
#
# Epoch: 488
# epoch    488  total error   0.00073815   avg weight        3.8079
#
# Epoch: 489
# epoch    489  total error   0.00073723   avg weight        3.8069
#
# Epoch: 490
# epoch    490  total error   0.00073104   avg weight          3.81
#
# Epoch: 491
# epoch    491  total error     0.000725   avg weight        3.8089
#
# Epoch: 492
# epoch    492  total error   0.00072294   avg weight        3.8107
#
# Epoch: 493
# epoch    493  total error   0.00071784   avg weight        3.8105
#
# Epoch: 494
# epoch    494  total error   0.00071854   avg weight        3.8131
#
# Epoch: 495
# epoch    495  total error   0.00071185   avg weight        3.8143
#
# Epoch: 496
# epoch    496  total error   0.00071087   avg weight        3.8164
#
# Epoch: 497
# epoch    497  total error   0.00070397   avg weight        3.8182
#
# Epoch: 498
# epoch    498  total error   0.00070073   avg weight        3.8198
#
# Epoch: 499
# epoch    499  total error   0.00069722   avg weight         3.821
#
# Epoch: 500
# epoch    500  total error   0.00069811   avg weight          3.82
#
# Epoch: 501
# epoch    501  total error   0.00069132   avg weight        3.8216
#
# Epoch: 502
# epoch    502  total error   0.00068734   avg weight        3.8238
#
# Epoch: 503
# epoch    503  total error   0.00068298   avg weight        3.8248
#
# Epoch: 504
# epoch    504  total error   0.00067783   avg weight        3.8246
#
# Epoch: 505
# epoch    505  total error   0.00067372   avg weight        3.8263
#
# Epoch: 506
# epoch    506  total error   0.00067383   avg weight         3.828
#
# Epoch: 507
# epoch    507  total error    0.0006771   avg weight          3.83
#
# Epoch: 508
# epoch    508  total error   0.00067326   avg weight        3.8322
#
# Epoch: 509
# epoch    509  total error   0.00067036   avg weight        3.8324
#
# Epoch: 510
# epoch    510  total error    0.0006672   avg weight        3.8313
#
# Epoch: 511
# epoch    511  total error   0.00066249   avg weight        3.8333
#
# Epoch: 512
# epoch    512  total error   0.00066233   avg weight         3.835
#
# Epoch: 513
# epoch    513  total error   0.00065958   avg weight        3.8372
#
# Epoch: 514
# epoch    514  total error    0.0006581   avg weight          3.84
#
# Epoch: 515
# epoch    515  total error   0.00065519   avg weight        3.8432
#
# Epoch: 516
# epoch    516  total error   0.00065191   avg weight        3.8474
#
# Epoch: 517
# epoch    517  total error   0.00064938   avg weight        3.8526
#
# Epoch: 518
# epoch    518  total error   0.00064497   avg weight        3.8527
#
# Epoch: 519
# epoch    519  total error   0.00064106   avg weight        3.8532
#
# Epoch: 520
# epoch    520  total error   0.00063798   avg weight        3.8562
#
# Epoch: 521
# epoch    521  total error   0.00063598   avg weight        3.8591
#
# Epoch: 522
# epoch    522  total error    0.0006374   avg weight        3.8641
#
# Epoch: 523
# epoch    523  total error   0.00065347   avg weight        3.8645
#
# Epoch: 524
# epoch    524  total error   0.00063588   avg weight        3.8643
#
# Epoch: 525
# epoch    525  total error   0.00063388   avg weight        3.8684
#
# Epoch: 526
# epoch    526  total error    0.0006319   avg weight         3.869
#
# Epoch: 527
# epoch    527  total error   0.00062893   avg weight        3.8698
#
# Epoch: 528
# epoch    528  total error   0.00062733   avg weight        3.8695
#
# Epoch: 529
# epoch    529  total error    0.0006246   avg weight        3.8709
#
# Epoch: 530
# epoch    530  total error   0.00062264   avg weight        3.8723
#
# Epoch: 531
# epoch    531  total error    0.0006226   avg weight        3.8722
#
# Epoch: 532
# epoch    532  total error   0.00062578   avg weight        3.8727
#
# Epoch: 533
# epoch    533  total error   0.00062191   avg weight        3.8732
#
# Epoch: 534
# epoch    534  total error   0.00062055   avg weight        3.8744
#
# Epoch: 535
# epoch    535  total error   0.00061852   avg weight        3.8758
#
# Epoch: 536
# epoch    536  total error   0.00061698   avg weight        3.8778
#
# Epoch: 537
# epoch    537  total error   0.00061552   avg weight        3.8801
#
# Epoch: 538
# epoch    538  total error   0.00061446   avg weight         3.881
#
# Epoch: 539
# epoch    539  total error   0.00061226   avg weight        3.8835
#
# Epoch: 540
# epoch    540  total error   0.00061262   avg weight        3.8869
#
# Epoch: 541
# epoch    541  total error   0.00062502   avg weight        3.8905
#
# Epoch: 542
# epoch    542  total error   0.00061473   avg weight        3.8893
#
# Epoch: 543
# epoch    543  total error   0.00061118   avg weight        3.8874
#
# Epoch: 544
# epoch    544  total error   0.00061022   avg weight          3.89
#
# Epoch: 545
# epoch    545  total error   0.00060759   avg weight        3.8911
#
# Epoch: 546
# epoch    546  total error   0.00060685   avg weight        3.8923
#
# Epoch: 547
# epoch    547  total error   0.00060585   avg weight        3.8939
#
# Epoch: 548
# epoch    548  total error   0.00060452   avg weight        3.8962
#
# Epoch: 549
# epoch    549  total error   0.00060436   avg weight        3.8994
#
# Epoch: 550
# epoch    550  total error   0.00060547   avg weight        3.9022
#
# Epoch: 551
# epoch    551  total error   0.00060942   avg weight        3.9005
#
# Epoch: 552
# epoch    552  total error   0.00060441   avg weight        3.9024
#
# Epoch: 553
# epoch    553  total error   0.00060554   avg weight        3.9047
#
# Epoch: 554
# epoch    554  total error   0.00060194   avg weight        3.9055
#
# Epoch: 555
# epoch    555  total error   0.00060172   avg weight        3.9083
#
# Epoch: 556
# epoch    556  total error   0.00060123   avg weight        3.9066
#
# Epoch: 557
# epoch    557  total error   0.00060053   avg weight        3.9085
#
# Epoch: 558
# epoch    558  total error       0.0006   avg weight        3.9104
#
# Epoch: 559
# epoch    559  total error   0.00059896   avg weight          3.91
#
# Epoch: 560
# epoch    560  total error   0.00059981   avg weight        3.9116
#
# Epoch: 561
# epoch    561  total error   0.00060042   avg weight        3.9121
#
# Epoch: 562
# epoch    562  total error   0.00060138   avg weight        3.9123
#
# Epoch: 563
# epoch    563  total error   0.00059895   avg weight        3.9134
#
# Epoch: 564
# epoch    564  total error   0.00059762   avg weight        3.9142
#
# Epoch: 565
# epoch    565  total error   0.00059683   avg weight         3.915
#
# Epoch: 566
# epoch    566  total error   0.00059608   avg weight         3.916
#
# Epoch: 567
# epoch    567  total error   0.00059568   avg weight        3.9174
#
# Epoch: 568
# epoch    568  total error   0.00059483   avg weight        3.9191
#
# Epoch: 569
# epoch    569  total error   0.00059411   avg weight        3.9203
#
# Epoch: 570
# epoch    570  total error    0.0005934   avg weight        3.9225
#
# Epoch: 571
# epoch    571  total error   0.00059411   avg weight         3.925
#
# Epoch: 572
# epoch    572  total error    0.0005926   avg weight        3.9243
#
# Epoch: 573
# epoch    573  total error    0.0005932   avg weight        3.9254
#
# Epoch: 574
# epoch    574  total error    0.0006044   avg weight         3.927
#
# Epoch: 575
# epoch    575  total error   0.00059589   avg weight        3.9274
#
# Epoch: 576
# epoch    576  total error   0.00059573   avg weight        3.9288
#
# Epoch: 577
# epoch    577  total error   0.00059221   avg weight        3.9309
#
# Epoch: 578
# epoch    578  total error   0.00059209   avg weight        3.9333
#
# Epoch: 579
# epoch    579  total error   0.00059157   avg weight        3.9355
#
# Epoch: 580
# epoch    580  total error   0.00059113   avg weight        3.9384
#
# Epoch: 581
# epoch    581  total error   0.00059083   avg weight        3.9372
#
# Epoch: 582
# epoch    582  total error   0.00058996   avg weight        3.9391
#
# Epoch: 583
# epoch    583  total error   0.00058993   avg weight        3.9416
#
# Epoch: 584
# epoch    584  total error   0.00058926   avg weight        3.9438
#
# Epoch: 585
# epoch    585  total error    0.0005895   avg weight        3.9428
#
# Epoch: 586
# epoch    586  total error   0.00058817   avg weight        3.9452
#
# Epoch: 587
# epoch    587  total error   0.00059014   avg weight        3.9459
#
# Epoch: 588
# epoch    588  total error   0.00059277   avg weight        3.9481
#
# Epoch: 589
# epoch    589  total error   0.00058916   avg weight        3.9502
#
# Epoch: 590
# epoch    590  total error   0.00058756   avg weight        3.9496
#
# Epoch: 591
# epoch    591  total error   0.00058779   avg weight        3.9502
#
# Epoch: 592
# epoch    592  total error   0.00058883   avg weight        3.9519
#
# Epoch: 593
# epoch    593  total error   0.00058808   avg weight        3.9413
#
# Epoch: 594
# epoch    594  total error   0.00058716   avg weight        3.9299
#
# Epoch: 595
# epoch    595  total error   0.00058692   avg weight        3.9203
#
# Epoch: 596
# epoch    596  total error   0.00058664   avg weight        3.9117
#
# Epoch: 597
# epoch    597  total error   0.00058641   avg weight         3.904
#
# Epoch: 598
# epoch    598  total error    0.0005861   avg weight        3.8964
#
# Epoch: 599
# epoch    599  total error   0.00058593   avg weight        3.8899
#
# Epoch: 600
# epoch    600  total error   0.00058626   avg weight         3.882
#
# Epoch: 601
# epoch    601  total error   0.00058783   avg weight        3.8765
#
# Epoch: 602
# epoch    602  total error   0.00058646   avg weight        3.8724
#
# Epoch: 603
# epoch    603  total error   0.00058541   avg weight        3.8889
#
# Epoch: 604
# epoch    604  total error   0.00058499   avg weight        3.8892
#
# Epoch: 605
# epoch    605  total error   0.00058664   avg weight        3.9015
#
# Epoch: 606
# epoch    606  total error    0.0005849   avg weight        3.9059
#
# Epoch: 607
# epoch    607  total error   0.00058505   avg weight        3.9077
#
# Epoch: 608
# epoch    608  total error   0.00058456   avg weight         3.917
#
# Epoch: 609
# epoch    609  total error   0.00058441   avg weight        3.9213
#
# Epoch: 610
# epoch    610  total error   0.00058421   avg weight        3.9268
#
# Epoch: 611
# epoch    611  total error   0.00058405   avg weight        3.9274
#
# Epoch: 612
# epoch    612  total error   0.00058381   avg weight        3.9282
#
# Epoch: 613
# epoch    613  total error   0.00058363   avg weight        3.9286
#
# Epoch: 614
# epoch    614  total error   0.00058342   avg weight        3.9296
#
# Epoch: 615
# epoch    615  total error    0.0005872   avg weight        3.9295
#
# Epoch: 616
# epoch    616  total error    0.0005923   avg weight          3.93
#
# Epoch: 617
# epoch    617  total error   0.00058755   avg weight        3.9304
#
# Epoch: 618
# epoch    618  total error   0.00058589   avg weight         3.931
#
# Epoch: 619
# epoch    619  total error    0.0005842   avg weight        3.9317
#
# Epoch: 620
# epoch    620  total error   0.00058375   avg weight        3.9325
#
# Epoch: 621
# epoch    621  total error   0.00058339   avg weight        3.9333
#
# Epoch: 622
# epoch    622  total error   0.00058306   avg weight        3.9332
#
# Epoch: 623
# epoch    623  total error   0.00058285   avg weight        3.9335
#
# Epoch: 624
# epoch    624  total error   0.00058276   avg weight        3.9341
#
# Epoch: 625
# epoch    625  total error   0.00058264   avg weight        3.9346
#
# Epoch: 626
# epoch    626  total error   0.00058267   avg weight        3.9356
#
# Epoch: 627
# epoch    627  total error   0.00058273   avg weight        3.9359
#
# Epoch: 628
# epoch    628  total error   0.00058276   avg weight        3.9363
#
# Epoch: 629
# epoch    629  total error   0.00058248   avg weight         3.936
#
# Epoch: 630
# epoch    630  total error   0.00058246   avg weight        3.9367
#
# Epoch: 631
# epoch    631  total error   0.00058229   avg weight        3.9373
#
# Epoch: 632
# epoch    632  total error    0.0005822   avg weight        3.9382
#
# Epoch: 633
# epoch    633  total error   0.00058209   avg weight         3.939
#
# Epoch: 634
# epoch    634  total error   0.00058198   avg weight        3.9395
#
# Epoch: 635
# epoch    635  total error   0.00058185   avg weight        3.9405
#
# Epoch: 636
# epoch    636  total error   0.00058175   avg weight        3.9411
#
# Epoch: 637
# epoch    637  total error   0.00058282   avg weight        3.9416
#
# Epoch: 638
# epoch    638  total error   0.00059834   avg weight        3.9428
#
# Epoch: 639
# epoch    639  total error    0.0005817   avg weight        3.9439
#
# Epoch: 640
# epoch    640  total error   0.00058302   avg weight        3.9443
#
# Epoch: 641
# epoch    641  total error   0.00058344   avg weight        3.9456
#
# Epoch: 642
# epoch    642  total error   0.00058237   avg weight         3.946
#
# Epoch: 643
# epoch    643  total error   0.00058171   avg weight        3.9475
#
# Epoch: 644
# epoch    644  total error   0.00058143   avg weight        3.9466
#
# Epoch: 645
# epoch    645  total error   0.00058143   avg weight        3.9473
#
# Epoch: 646
# epoch    646  total error   0.00058139   avg weight        3.9478
#
# Epoch: 647
# epoch    647  total error   0.00058152   avg weight        3.9483
#
# Epoch: 648
# epoch    648  total error   0.00058143   avg weight        3.9487
#
# Epoch: 649
# epoch    649  total error   0.00058129   avg weight        3.9488
#
# Epoch: 650
# epoch    650  total error   0.00058116   avg weight        3.9493
#
# Epoch: 651
# epoch    651  total error   0.00058113   avg weight        3.9498
#
# Epoch: 652
# epoch    652  total error   0.00058105   avg weight        3.9501
#
# Epoch: 653
# epoch    653  total error   0.00058096   avg weight        3.9507
#
# Epoch: 654
# epoch    654  total error    0.0005809   avg weight        3.9515
#
# Epoch: 655
# epoch    655  total error   0.00058086   avg weight        3.9525
#
# Epoch: 656
# epoch    656  total error   0.00058086   avg weight        3.9532
#
# Epoch: 657
# epoch    657  total error   0.00058188   avg weight        3.9545
#
# Epoch: 658
# epoch    658  total error   0.00059028   avg weight        3.9557
#
# Epoch: 659
# epoch    659  total error   0.00058091   avg weight         3.957
#
# Epoch: 660
# epoch    660  total error   0.00058104   avg weight        3.9564
#
# Epoch: 661
# epoch    661  total error   0.00058218   avg weight        3.9578
#
# Epoch: 662
# epoch    662  total error   0.00058104   avg weight        3.9552
#
# Epoch: 663
# epoch    663  total error   0.00058076   avg weight        3.9611
#
# Epoch: 664
# epoch    664  total error   0.00058084   avg weight        3.9614
#
# Epoch: 665
# epoch    665  total error    0.0005806   avg weight        3.9624
#
# Epoch: 666
# epoch    666  total error   0.00058054   avg weight        3.9615
#
# Epoch: 667
# epoch    667  total error   0.00058051   avg weight        3.9623
#
# Epoch: 668
# epoch    668  total error   0.00058044   avg weight        3.9632
#
# Epoch: 669
# epoch    669  total error   0.00058043   avg weight        3.9649
#
# Epoch: 670
# epoch    670  total error   0.00058038   avg weight         3.966
#
# Epoch: 671
# epoch    671  total error   0.00058051   avg weight        3.9699
#
# Epoch: 672
# epoch    672  total error   0.00058053   avg weight        3.9751
#
# Epoch: 673
# epoch    673  total error   0.00058034   avg weight        3.9818
#
# Epoch: 674
# epoch    674  total error   0.00058026   avg weight        3.9867
#
# Epoch: 675
# epoch    675  total error   0.00058025   avg weight        3.9899
#
# Epoch: 676
# epoch    676  total error   0.00058042   avg weight        3.9971
#
# Epoch: 677
# epoch    677  total error   0.00058034   avg weight        4.0019
#
# Epoch: 678
# epoch    678  total error   0.00058009   avg weight        4.0083
#
# Epoch: 679
# epoch    679  total error   0.00058005   avg weight        4.0184
#
# Epoch: 680
# epoch    680  total error   0.00057999   avg weight        4.0227
#
# Epoch: 681
# epoch    681  total error    0.0005801   avg weight          4.03
#
# Epoch: 682
# epoch    682  total error   0.00057994   avg weight         4.037
#
# Epoch: 683
# epoch    683  total error   0.00057993   avg weight        4.0437
#
# Epoch: 684
# epoch    684  total error   0.00058611   avg weight        4.0526
#
# Epoch: 685
# epoch    685  total error   0.00059277   avg weight        4.0606
#
# Epoch: 686
# epoch    686  total error   0.00058125   avg weight        4.0663
#
# Epoch: 687
# epoch    687  total error   0.00058432   avg weight         4.074
#
# Epoch: 688
# epoch    688  total error   0.00057997   avg weight        4.0678
#
# Epoch: 689
# epoch    689  total error   0.00058137   avg weight        4.0715
#
# Epoch: 690
# epoch    690  total error   0.00057984   avg weight        4.0722
#
# Epoch: 691
# epoch    691  total error   0.00057979   avg weight        4.0725
#
# Epoch: 692
# epoch    692  total error    0.0005799   avg weight        4.0732
#
# Epoch: 693
# epoch    693  total error   0.00058002   avg weight         4.073
#
# Epoch: 694
# epoch    694  total error   0.00058045   avg weight        4.0735
#
# Epoch: 695
# epoch    695  total error   0.00057986   avg weight         4.074
#
# Epoch: 696
# epoch    696  total error   0.00057992   avg weight        4.0748
#
# Epoch: 697
# epoch    697  total error   0.00057975   avg weight        4.0751
#
# Epoch: 698
# epoch    698  total error   0.00057979   avg weight        4.0758
#
# Epoch: 699
# epoch    699  total error    0.0005797   avg weight        4.0766
#
# Epoch: 700
# epoch    700  total error   0.00057972   avg weight         4.077
#
# Epoch: 701
# epoch    701  total error   0.00057967   avg weight         4.078
#
# Epoch: 702
# epoch    702  total error   0.00057976   avg weight        4.0787
#
# Epoch: 703
# epoch    703  total error   0.00057965   avg weight        4.0804
#
# Epoch: 704
# epoch    704  total error   0.00057968   avg weight        4.0795
#
# Epoch: 705
# epoch    705  total error   0.00057958   avg weight        4.0803
#
# Epoch: 706
# epoch    706  total error   0.00057961   avg weight        4.0809
#
# Epoch: 707
# epoch    707  total error   0.00057952   avg weight        4.0814
#
# Epoch: 708
# epoch    708  total error   0.00057955   avg weight        4.0859
#
# Epoch: 709
# epoch    709  total error   0.00058004   avg weight        4.0901
#
# Epoch: 710
# epoch    710  total error   0.00058328   avg weight         4.097
#
# Epoch: 711
# epoch    711  total error   0.00057962   avg weight        4.1034
#
# Epoch: 712
# epoch    712  total error   0.00057952   avg weight        4.1083
#
# Epoch: 713
# epoch    713  total error   0.00058023   avg weight        4.1166
#
# Epoch: 714
# epoch    714  total error   0.00057958   avg weight        4.1245
#
# Epoch: 715
# ...
#
# Epoch: 795
# epoch    795  total error   0.00057896   avg weight        4.1979
#
# Epoch: 796
# epoch    796  total error   0.00057888   avg weight        4.1991
#
# Epoch: 797
# epoch    797  total error    0.0005789   avg weight        4.2012
#
# Epoch: 798
# epoch    798  total error   0.00057887   avg weight        4.2034
#
# Epoch: 799
# epoch    799  total error   0.00057888   avg weight        4.2032
#
# Epoch: 800
# epoch    800  total error   0.00057887   avg weight        4.2044
#
# Epoch: 801
# epoch    801  total error   0.00057894   avg weight        4.2049
#
# Epoch: 802
# epoch    802  total error   0.00057897   avg weight        4.2064
#
# Epoch: 803
# epoch    803  total error   0.00057895   avg weight         4.208
#
# Epoch: 804
# epoch    804  total error   0.00057887   avg weight        4.2105
#
# Epoch: 805
# epoch    805  total error   0.00057891   avg weight        4.2112
#
# Epoch: 806
# epoch    806  total error   0.00057883   avg weight        4.2123
#
# Epoch: 807
# epoch    807  total error   0.00057887   avg weight        4.2147
#
# Epoch: 808
# epoch    808  total error   0.00057884   avg weight        4.2159
#
# Epoch: 809
# epoch    809  total error   0.00057898   avg weight        4.2172
#
# Epoch: 810
# epoch    810  total error   0.00057883   avg weight        4.2187
#
# Epoch: 811
# epoch    811  total error   0.00057885   avg weight        4.2183
#
# Epoch: 812
# epoch    812  total error   0.00057885   avg weight        4.2203
#
# Epoch: 813
# epoch    813  total error   0.00057889   avg weight        4.2211
#
# Epoch: 814
# epoch    814  total error   0.00057882   avg weight        4.2223
#
# Epoch: 815
# epoch    815  total error   0.00057882   avg weight        4.2242
#
# Epoch: 816
# epoch    816  total error   0.00057893   avg weight        4.2266
#
# Epoch: 817
# epoch    817  total error   0.00057886   avg weight        4.2298
#
# Epoch: 818
# epoch    818  total error   0.00057887   avg weight        4.2332
#
# Epoch: 819
# epoch    819  total error   0.00057883   avg weight        4.2364
#
# Epoch: 820
# epoch    820  total error   0.00057884   avg weight         4.236
#
# Epoch: 821
# epoch    821  total error   0.00057882   avg weight        4.2364
#
# Epoch: 822
# epoch    822  total error   0.00057885   avg weight         4.238
#
# Epoch: 823
# epoch    823  total error   0.00057881   avg weight         4.239
#
# Epoch: 824
# epoch    824  total error   0.00057884   avg weight        4.2406
#
# Epoch: 825
# epoch    825  total error   0.00057882   avg weight        4.2425
#
# Epoch: 826
# epoch    826  total error   0.00057883   avg weight        4.2484
#
# Epoch: 827
# epoch    827  total error   0.00057881   avg weight        4.2513
#
# Epoch: 828
# epoch    828  total error   0.00057885   avg weight        4.2544
#
# Epoch: 829
# epoch    829  total error   0.00057879   avg weight        4.2535
#
# Epoch: 830
# epoch    830  total error   0.00057885   avg weight        4.2553
#
# Epoch: 831
# epoch    831  total error    0.0005788   avg weight        4.2568
#
# Epoch: 832
# epoch    832  total error   0.00057889   avg weight        4.2558
#
# Epoch: 833
# epoch    833  total error   0.00057882   avg weight         4.257
#
# Epoch: 834
# epoch    834  total error   0.00057882   avg weight         4.258
#
# Epoch: 835
# epoch    835  total error   0.00057881   avg weight        4.2576
#
# Epoch: 836
# epoch    836  total error   0.00057882   avg weight        4.2584
#
# Epoch: 837
# epoch    837  total error    0.0005788   avg weight        4.2592
#
# Epoch: 838
# epoch    838  total error   0.00057883   avg weight        4.2593
#
# Epoch: 839
# epoch    839  total error   0.00057879   avg weight        4.2606
#
# Epoch: 840
# epoch    840  total error   0.00057885   avg weight         4.262
#
# Epoch: 841
# epoch    841  total error   0.00057879   avg weight        4.2618
#
# Epoch: 842
# epoch    842  total error   0.00057882   avg weight        4.2627
#
# Epoch: 843
# epoch    843  total error   0.00057879   avg weight        4.2635
#
# Epoch: 844
# epoch    844  total error   0.00057882   avg weight        4.2645
#
# Epoch: 845
# epoch    845  total error   0.00057879   avg weight         4.266
#
# Epoch: 846
# epoch    846  total error   0.00057882   avg weight        4.2666
#
# Epoch: 847
# epoch    847  total error   0.00057878   avg weight        4.2677
#
# Epoch: 848
# epoch    848  total error   0.00057883   avg weight        4.2685
#
# Epoch: 849
# epoch    849  total error   0.00057878   avg weight        4.2699
#
# Epoch: 850
# epoch    850  total error   0.00057884   avg weight        4.2718
#
# Epoch: 851
# epoch    851  total error    0.0005788   avg weight         4.273
#
# Epoch: 852
# epoch    852  total error    0.0005788   avg weight        4.2752
#
# Epoch: 853
# epoch    853  total error   0.00057879   avg weight        4.2776
#
# Epoch: 854
# epoch    854  total error   0.00057879   avg weight        4.2803
#
# Epoch: 855
# epoch    855  total error   0.00057879   avg weight        4.2835
#
# Epoch: 856
# epoch    856  total error   0.00057883   avg weight        4.2866
#
# Epoch: 857
# epoch    857  total error   0.00057877   avg weight        4.2901
#
# Epoch: 858
# epoch    858  total error   0.00057882   avg weight        4.2915
#
# Epoch: 859
# epoch    859  total error   0.00057878   avg weight        4.2941
#
# Epoch: 860
# epoch    860  total error   0.00057881   avg weight         4.297
#
# Epoch: 861
# epoch    861  total error   0.00057883   avg weight        4.2959
#
# Epoch: 862
# epoch    862  total error   0.00057878   avg weight        4.2978
#
# Epoch: 863
# epoch    863  total error   0.00057879   avg weight        4.2978
#
# Epoch: 864
# epoch    864  total error    0.0005788   avg weight        4.2982
#
# Epoch: 865
# epoch    865  total error   0.00057878   avg weight        4.2987
#
# Epoch: 866
# epoch    866  total error   0.00057883   avg weight        4.2999
#
# Epoch: 867
# epoch    867  total error   0.00057879   avg weight        4.3009
#
# Epoch: 868
# epoch    868  total error    0.0005788   avg weight        4.3018
#
# Epoch: 869
# epoch    869  total error    0.0005788   avg weight        4.3032
#
# Epoch: 870
# epoch    870  total error   0.00057879   avg weight        4.3044
#
# Epoch: 871
# epoch    871  total error   0.00057878   avg weight        4.3046
#
# Epoch: 872
# epoch    872  total error   0.00057878   avg weight         4.305
#
# Epoch: 873
# epoch    873  total error   0.00057878   avg weight         4.306
#
# Epoch: 874
# epoch    874  total error   0.00057878   avg weight        4.3062
#
# Epoch: 875
# epoch    875  total error   0.00057878   avg weight        4.3068
#
# Epoch: 876
# epoch    876  total error   0.00057882   avg weight        4.3078
#
# Epoch: 877
# epoch    877  total error   0.00057877   avg weight         4.309
#
# Epoch: 878
# epoch    878  total error    0.0005788   avg weight          4.31
#
# Epoch: 879
# epoch    879  total error   0.00057877   avg weight        4.3116
#
# Epoch: 880
# epoch    880  total error   0.00057879   avg weight        4.3131
#
# Epoch: 881
# epoch    881  total error   0.00057878   avg weight        4.3147
#
# Epoch: 882
# epoch    882  total error   0.00057886   avg weight        4.3164
#
# Epoch: 883
# epoch    883  total error   0.00057878   avg weight        4.3164
#
# Epoch: 884
# epoch    884  total error   0.00057877   avg weight        4.3169
#
# Epoch: 885
# epoch    885  total error   0.00057878   avg weight        4.3174
#
# Epoch: 886
# epoch    886  total error   0.00057882   avg weight        4.3182
#
# Epoch: 887
# epoch    887  total error   0.00057877   avg weight        4.3192
#
# Epoch: 888
# epoch    888  total error    0.0005788   avg weight        4.3203
#
# Epoch: 889
# epoch    889  total error   0.00057876   avg weight        4.3216
#
# Epoch: 890
# epoch    890  total error   0.00057877   avg weight         4.324
#
# Epoch: 891
# epoch    891  total error   0.00057877   avg weight        4.3263
#
# Epoch: 892
# epoch    892  total error   0.00057879   avg weight        4.3256
#
# Epoch: 893
# epoch    893  total error   0.00057876   avg weight        4.3272
#
# Epoch: 894
# epoch    894  total error   0.00057877   avg weight        4.3292
#
# Epoch: 895
# epoch    895  total error   0.00057876   avg weight        4.3316
#
# Epoch: 896
# epoch    896  total error   0.00057876   avg weight        4.3342
#
# Epoch: 897
# epoch    897  total error   0.00057876   avg weight         4.337
#
# Epoch: 898
# epoch    898  total error   0.00057876   avg weight        4.3365
#
# Epoch: 899
# epoch    899  total error   0.00057874   avg weight        4.3385
#
# Epoch: 900
# epoch    900  total error    0.0005788   avg weight        4.3404
#
# Epoch: 901
# epoch    901  total error   0.00057875   avg weight        4.3405
#
# Epoch: 902
# epoch    902  total error    0.0005788   avg weight        4.3425
#
# Epoch: 903
# epoch    903  total error   0.00057875   avg weight        4.3437
#
# Epoch: 904
# epoch    904  total error   0.00057879   avg weight        4.3463
#
# Epoch: 905
# epoch    905  total error   0.00057875   avg weight        4.3492
#
# Epoch: 906
# epoch    906  total error   0.00057879   avg weight        4.3527
#
# Epoch: 907
# epoch    907  total error   0.00057874   avg weight        4.3561
#
# Epoch: 908
# epoch    908  total error   0.00057879   avg weight        4.3612
#
# Epoch: 909
# epoch    909  total error   0.00057875   avg weight        4.3667
#
# Epoch: 910
# epoch    910  total error   0.00057878   avg weight        4.3678
#
# Epoch: 911
# epoch    911  total error   0.00057876   avg weight        4.3691
#
# Epoch: 912
# epoch    912  total error   0.00057877   avg weight        4.3704
#
# Epoch: 913
# epoch    913  total error   0.00057875   avg weight        4.3713
#
# Epoch: 914
# epoch    914  total error   0.00057878   avg weight        4.3727
#
# Epoch: 915
# epoch    915  total error   0.00057875   avg weight        4.3724
#
# Epoch: 916
# epoch    916  total error   0.00057877   avg weight        4.3724
#
# Epoch: 917
# epoch    917  total error   0.00057874   avg weight         4.373
#
# Epoch: 918
# epoch    918  total error   0.00057878   avg weight        4.3734
#
# Epoch: 919
# epoch    919  total error   0.00057874   avg weight        4.3743
#
# Epoch: 920
# epoch    920  total error   0.00057879   avg weight        4.3755
#
# Epoch: 921
# epoch    921  total error   0.00057874   avg weight        4.3768
#
# Epoch: 922
# epoch    922  total error   0.00057879   avg weight        4.3779
#
# Epoch: 923
# epoch    923  total error   0.00057874   avg weight        4.3793
#
# Epoch: 924
# epoch    924  total error   0.00057878   avg weight        4.3796
#
# Epoch: 925
# epoch    925  total error   0.00057874   avg weight        4.3811
#
# Epoch: 926
# epoch    926  total error   0.00057877   avg weight        4.3826
#
# Epoch: 927
# epoch    927  total error   0.00057874   avg weight        4.3842
#
# Epoch: 928
# epoch    928  total error   0.00057877   avg weight        4.3858
#
# Epoch: 929
# epoch    929  total error   0.00057875   avg weight        4.3874
#
# Epoch: 930
# epoch    930  total error   0.00057876   avg weight        4.3888
#
# Epoch: 931
# epoch    931  total error   0.00057875   avg weight        4.3879
#
# Epoch: 932
# epoch    932  total error   0.00057876   avg weight         4.388
#
# Epoch: 933
# epoch    933  total error   0.00057875   avg weight        4.3881
#
# Epoch: 934
# epoch    934  total error   0.00057876   avg weight        4.3897
#
# Epoch: 935
# epoch    935  total error   0.00057874   avg weight        4.3911
#
# Epoch: 936
# epoch    936  total error   0.00057876   avg weight        4.3927
#
# Epoch: 937
# epoch    937  total error   0.00057874   avg weight         4.393
#
# Epoch: 938
# epoch    938  total error   0.00057876   avg weight        4.3945
#
# Epoch: 939
# epoch    939  total error   0.00057874   avg weight        4.3953
#
# Epoch: 940
# epoch    940  total error   0.00057876   avg weight        4.3957
#
# Epoch: 941
# epoch    941  total error   0.00057874   avg weight        4.3971
#
# Epoch: 942
# epoch    942  total error   0.00057876   avg weight        4.3978
#
# Epoch: 943
# epoch    943  total error   0.00057874   avg weight        4.3974
#
# Epoch: 944
# epoch    944  total error   0.00057877   avg weight        4.3978
#
# Epoch: 945
# epoch    945  total error   0.00057874   avg weight         4.398
#
# Epoch: 946
# epoch    946  total error   0.00057877   avg weight         4.399
#
# Epoch: 947
# epoch    947  total error   0.00057874   avg weight           4.4
#
# Epoch: 948
# epoch    948  total error   0.00057877   avg weight        4.4011
#
# Epoch: 949
# epoch    949  total error   0.00057874   avg weight        4.4022
#
# Epoch: 950
# epoch    950  total error   0.00057878   avg weight        4.4034
#
# Epoch: 951
# epoch    951  total error   0.00057874   avg weight        4.4043
#
# Epoch: 952
# epoch    952  total error   0.00057877   avg weight        4.4061
#
# Epoch: 953
# epoch    953  total error   0.00057874   avg weight        4.4081
#
# Epoch: 954
# epoch    954  total error   0.00057877   avg weight        4.4101
#
# Epoch: 955
# epoch    955  total error   0.00057873   avg weight        4.4094
#
# Epoch: 956
# epoch    956  total error   0.00057877   avg weight        4.4113
#
# Epoch: 957
# epoch    957  total error   0.00057873   avg weight        4.4118
#
# Epoch: 958
# epoch    958  total error   0.00057877   avg weight        4.4129
#
# Epoch: 959
# epoch    959  total error   0.00057873   avg weight        4.4136
#
# Epoch: 960
# epoch    960  total error   0.00057875   avg weight        4.4133
#
# Epoch: 961
# epoch    961  total error   0.00057875   avg weight         4.414
#
# Epoch: 962
# epoch    962  total error   0.00057875   avg weight        4.4145
#
# Epoch: 963
# epoch    963  total error   0.00057874   avg weight        4.4152
#
# Epoch: 964
# epoch    964  total error   0.00057875   avg weight        4.4155
#
# Epoch: 965
# epoch    965  total error   0.00057874   avg weight        4.4163
#
# Epoch: 966
# epoch    966  total error   0.00057875   avg weight        4.4173
#
# Epoch: 967
# epoch    967  total error   0.00057874   avg weight         4.418
#
# Epoch: 968
# epoch    968  total error   0.00057876   avg weight        4.4186
#
# Epoch: 969
# epoch    969  total error   0.00057873   avg weight        4.4191
#
# Epoch: 970
# epoch    970  total error   0.00057876   avg weight          4.42
#
# Epoch: 971
# epoch    971  total error   0.00057873   avg weight        4.4207
#
# Epoch: 972
# epoch    972  total error   0.00057875   avg weight        4.4207
#
# Epoch: 973
# epoch    973  total error   0.00057873   avg weight        4.4217
#
# Epoch: 974
# epoch    974  total error   0.00057875   avg weight        4.4226
#
# Epoch: 975
# epoch    975  total error   0.00057874   avg weight        4.4234
#
# Epoch: 976
# epoch    976  total error   0.00057875   avg weight        4.4249
#
# Epoch: 977
# epoch    977  total error   0.00057873   avg weight        4.4263
#
# Epoch: 978
# epoch    978  total error   0.00057875   avg weight        4.4277
#
# Epoch: 979
# epoch    979  total error   0.00057873   avg weight        4.4297
#
# Epoch: 980
# epoch    980  total error   0.00057875   avg weight        4.4311
#
# Epoch: 981
# epoch    981  total error   0.00057873   avg weight        4.4319
#
# Epoch: 982
# epoch    982  total error   0.00057875   avg weight        4.4335
#
# Epoch: 983
# epoch    983  total error   0.00057873   avg weight        4.4329
#
# Epoch: 984
# epoch    984  total error   0.00057875   avg weight        4.4341
#
# Epoch: 985
# epoch    985  total error   0.00057874   avg weight        4.4352
#
# Epoch: 986
# epoch    986  total error   0.00057875   avg weight         4.436
#
# Epoch: 987
# epoch    987  total error   0.00057873   avg weight        4.4377
#
# Epoch: 988
# epoch    988  total error   0.00057876   avg weight        4.4398
#
# Epoch: 989
# epoch    989  total error   0.00057873   avg weight        4.4424
#
# Epoch: 990
# epoch    990  total error   0.00057876   avg weight        4.4454
#
# Epoch: 991
# epoch    991  total error   0.00057873   avg weight         4.449
#
# Epoch: 992
# epoch    992  total error   0.00057876   avg weight        4.4515
#
# Epoch: 993
# epoch    993  total error   0.00057873   avg weight        4.4551
#
# Epoch: 994
# epoch    994  total error   0.00057876   avg weight        4.4585
#
# Epoch: 995
# epoch    995  total error   0.00057873   avg weight        4.4616
#
# Epoch: 996
# epoch    996  total error   0.00057876   avg weight        4.4656
#
# Epoch: 997
# epoch    997  total error   0.00057873   avg weight        4.4691
#
# Epoch: 998
# epoch    998  total error   0.00057876   avg weight        4.4735
#
# Epoch: 999
# epoch    999  total error   0.00057873   avg weight        4.4785

# %%
x=[i for i in range(len(error))]
plt.plot(x, error)
plt.show()

# %%
y_pred_train = [rnn.activate(point).argmax() for point in traindata['input']]
y_actual_train =[int(output[0]) for output in traindata['class']]

# %%
from sklearn.metrics import precision_recall_fscore_support
precision, recall, f1_score, _ = precision_recall_fscore_support(y_actual_train, y_pred_train, labels=[0,1,2])
print "Precision = "+str(precision)+"\nRecall = "+str(recall)+"\nF1 Score = "+str(f1_score)
# Out:
# Precision = [ 1.          1.          0.98850575]
# Recall = [ 0.98913043  1.          1.        ]
# F1 Score = [ 0.99453552  1.          0.99421965]

# %%
y_pred_test = [rnn.activate(point).argmax() for point in testdata['input']]
y_actual_test = [int(output[0]) for output in testdata['class']]
print y_pred_test
print y_actual_test
print len(alldata['input'])
# Out:
# [1, 0, 1, 0, 0, 1, 0, 1, 2, 2, 1, 1, 0, 0, 1, 0, 0, 0, 0, 2, 0, 2, 2, 1, 1, 1, 1, 1, 2, 2, 1, 1, 1, 2, 2, 0, 1, 1, 2, 1, 1, 0, 2, 0, 2, 1, 2, 0, 0, 2, 2, 0, 1, 1, 2, 0, 0, 2, 2, 1, 0, 2, 2, 2, 0, 0, 1, 1, 0, 1, 1, 1, 2, 1, 2, 0, 1, 2, 2, 1, 1, 0, 1, 0, 0, 2, 1, 1, 0, 0, 2, 1, 1, 0, 0, 1]
# [0, 1, 1, 0, 2, 1, 0, 1, 2, 2, 0, 1, 0, 2, 1, 0, 2, 1, 0, 0, 1, 1, 1, 1, 0, 1, 1, 0, 0, 2, 1, 0, 2, 2, 2, 0, 0, 2, 0, 1, 0, 0, 2, 2, 2, 1, 0, 2, 2, 1, 2, 1, 0, 2, 0, 0, 1, 0, 2, 1, 0, 0, 0, 0, 1, 1, 2, 1, 0, 2, 0, 1, 2, 0, 1, 1, 2, 0, 2, 1, 1, 1, 1, 0, 1, 0, 1, 0, 2, 0, 0, 1, 1, 0, 1, 1]
# 384

# %%
from sklearn.metrics import precision_recall_fscore_support
precision, recall, f1_score, _ = precision_recall_fscore_support(y_actual_test, y_pred_test, labels=[0,1,2])
print "Precision = "+str(precision)+"\nRecall = "+str(recall)+"\nF1 Score = "+str(f1_score)
# Out:
# Precision = [ 0.41935484  0.55263158  0.40740741]
# Recall = [ 0.36111111  0.58333333  0.45833333]
# F1 Score = [ 0.3880597   0.56756757  0.43137255]

# %%
y_pred_test = [rnn.activate(point).argmax() for point in inp[int(3/4*len(inp)):]]
y_actual_test = [lab_to_int[output] for output in lab[int(3/4*len(inp)):]]

# %%
from sklearn.metrics import precision_recall_fscore_support
precision, recall, f1_score, _ = precision_recall_fscore_support(y_actual_test, y_pred_test, labels=[0,1,2])
print "Precision = "+str(precision)+"\nRecall = "+str(recall)+"\nF1 Score = "+str(f1_score)
# Out:
# Precision = [ 0.38461538  0.45098039  0.46153846]
# Recall = [ 0.32608696  0.58974359  0.40909091]
# F1 Score = [ 0.35294118  0.51111111  0.43373494]

# %%
import feature_extractor
import scipy.io.wavfile as wav
import math

extractor = feature_extractor.FeatureExtractor()

file_name = raw_input("Enter the name of the call file name.\n> ")
rate_sig, sig = wav.read(file_name)

plt.plot(sig)
plt.plot((0,len(sig)),(0,0),'g')
plt.show()

complete_call_result = int_to_lab[rnn.activate(extractor.extract_features(audio_signal = (rate_sig, sig))).argmax()]
first_half_result = int_to_lab[rnn.activate(extractor.extract_features(audio_signal = (rate_sig, sig[:int(len(sig)/2)]))).argmax()]
second_half_result = int_to_lab[rnn.activate(extractor.extract_features(audio_signal = (rate_sig, sig[int(len(sig)/2):]))).argmax()]
segment_result = []
for i in range(int(math.ceil(len(sig)/(rate_sig*20)))):
    segment_result.append(int_to_lab[rnn.activate(extractor.extract_features(audio_signal = (rate_sig, sig[i*rate_sig*20:i*rate_sig*20+rate_sig*20]))).argmax()])
# Out:
# Enter the name of the call file name.
# >
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-32-db8cb24c457e> in <module>()
#       6
#       7 file_name = raw_input("Enter the name of the call file name.\n> ")
# ----> 8 rate_sig, sig = wav.read(file_name)
#       9
#      10 plt.plot(sig)
#
# C:\Anaconda2\lib\site-packages\scipy\io\wavfile.pyc in read(filename, mmap)
#     188         mmap = False
#     189     else:
# --> 190         fid = open(filename, 'rb')
#     191
#     192     try:
#
# IOError: [Errno 22] invalid mode ('rb') or filename: ''

# %%
import numpy as np
from __future__ import division
print "Overall call result: "+complete_call_result
print "Trainsition: "+first_half_result+" --> "+second_half_result
map_dict = {'negative':-1, 'neutral':0, 'positive':1}
mapped_segment_result = [map_dict[result] for result in segment_result]
index = [i for i in range(len(mapped_segment_result))]
index = np.asarray(index)
bar_width = 1
plt.plot((0,index[-1]+1),((0,0)), 'r')
plt.bar(index, mapped_segment_result, bar_width)
plt.xticks(index + bar_width/2 , (str(i*20)+'-'+str((i+1)*20) for i in index))
plt.xlabel('Time series with 20 seconds chunk')
#plt.axes([0, 100, -2, 2])
plt.ylabel('Emotion:\n1 = positive\n0 = neutral\n-1 = negative')
plt.title('Emotion per 20 second segment')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-93469713bf6c> in <module>()
#       1 import numpy as np
#       2 from __future__ import division
# ----> 3 print "Overall call result: "+complete_call_result
#       4 print "Trainsition: "+first_half_result+" --> "+second_half_result
#       5 map_dict = {'negative':-1, 'neutral':0, 'positive':1}
#
# NameError: name 'complete_call_result' is not defined

# %%
def plot_confusion_matrix(cm, title='Confusion matrix', cmap=plt.cm.Blues):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(cm))
    plt.xticks(tick_marks, ['neutral','positive','negative'], rotation=45)
    plt.yticks(tick_marks, ['neutral','positive','negative'])
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_actual_train, y_pred_train, labels=[0,1,2])
print cm
plot_confusion_matrix(cm)
# Out:
# [[ 91   0   1]
#  [  0 110   0]
#  [  0   0  86]]

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_actual_test, y_pred_test, labels=[0,1,2])
print cm
plot_confusion_matrix(cm)
# Out:
# [[15 18 13]
#  [ 8 23  8]
#  [16 10 18]]

# %%
len([1 for i in range(len(y_pred_train)) if y_pred_train[i]==y_actual_train[i]])/float(len(y_pred_train))
# Out:
# 0.9965277777777778

# %%
lab[1]
